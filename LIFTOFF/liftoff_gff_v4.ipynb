# %%
# from BCBio.GFF import GFFExaminer

# %% [markdown]
# https://gffpandas.readthedocs.io/en/latest/tutorial.html

# %%
import gffpandas.gffpandas as gffpd
import pandas as pd

# %%
annotation = gffpd.read_gff3('YPS1009_S288C_v4_polished.gff')
annot_s288c = gffpd.read_gff3('saccharomyces_cerevisiae_R64-3.gff')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\gffpandas\gffpandas.py:32: DtypeWarning: Columns (1,2,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_table(self._gff_file, comment='#',

# %%
annotation.df['type'].value_counts()
# Out:
# CDS                                7178
# gene                               6707
# mRNA                               6707
# noncoding_exon                      493
# tRNA_gene                           321
# tRNA                                321
# transposable_element_gene            99
# transposable_element                 99
# snoRNA                               77
# snoRNA_gene                          77
# plus_1_translational_frameshift      47
# five_prime_UTR_intron                24
# ncRNA_gene                           23
# ncRNA                                23
# snRNA_gene                            6
# snRNA                                 6
# uORF                                  6
# telomeric_repeat                      3
# intein_encoding_region                1
# Name: type, dtype: int64

# %%
annot_s288c.df['type'].value_counts()
# Out:
# mRNA                                  11119
# CDS                                    7066
# gene                                   6607
# ARS                                     543
# noncoding_exon                          489
# long_terminal_repeat                    384
# intron                                  378
# tRNA                                    299
# tRNA_gene                               299
# ARS_consensus_sequence                  196
# transposable_element_gene                91
# transposable_element                     91
# region                                   78
# snoRNA_gene                              77
# snoRNA                                   77
# telomere                                 64
# LTR_retrotransposon                      50
# plus_1_translational_frameshift          47
# X_element                                32
# centromere                               32
# telomeric_repeat                         31
# X_element_combinatorial_repeat           28
# rRNA                                     24
# rRNA_gene                                24
# five_prime_UTR_intron                    24
# ncRNA                                    23
# ncRNA_gene                               23
# Y_prime_element                          19
# chromosome                               17
# centromere_DNA_Element_III               16
# centromere_DNA_Element_II                16
# centromere_DNA_Element_I                 16
# pseudogene                               12
# blocked_reading_frame                    12
# uORF                                     11
# internal_transcribed_spacer_region        8
# external_transcribed_spacer_region        8
# origin_of_replication                     8
# matrix_attachment_site                    8
# snRNA                                     6
# snRNA_gene                                6
# silent_mating_type_cassette_array         4
# X_region                                  3
# Y_region                                  3
# non_transcribed_region                    3
# Z1_region                                 3
# W_region                                  2
# Z2_region                                 2
# mating_type_region                        2
# intein_encoding_region                    2
# recombination_enhancer                    1
# telomerase_RNA                            1
# telomerase_RNA_gene                       1
# Name: type, dtype: int64

# %% [markdown]
# ## Make df by features YPS1009

# %%
TE_df = annotation.filter_feature_of_type(['transposable_element_gene'])
sno_df = annotation.filter_feature_of_type(['snoRNA_gene'])
tRNA_df = annotation.filter_feature_of_type(['tRNA_gene'])
gene_df = annotation.filter_feature_of_type(['gene'])

# %%
gene_attr.columns
# Out:
# Index(['seq_id', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase',
#        'attributes', 'Alias', 'ID', 'Name', 'Note', 'Ontology_term',
#        'copy_num_ID', 'coverage', 'curie', 'dbxref', 'display',
#        'extra_copy_number', 'gene', 'low_identity', 'orf_classification',
#        'partial_mapping', 'sequence_ID', 'valid_ORFs'],
#       dtype='object')

# %%
gene_attr = gene_df.attributes_to_columns()
gene = gene_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'gene', 'low_identity', 'orf_classification',
       'partial_mapping', 'sequence_ID', 'valid_ORFs']]

# %%
gene_attr['valid_ORFs'].value_counts()
# so valid_ORFs in gene does count itself and I should look carefully at the 439 genes with no valid ORF
# Out:
# 1    6175
# 0     530
# Name: valid_ORFs, dtype: int64

# %%
TE_attr = TE_df.attributes_to_columns()
sno_attr = sno_df.attributes_to_columns()
tRNA_attr = tRNA_df.attributes_to_columns()

# %%
TE = TE_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'sequence_ID', 'valid_ORFs']]

sno = sno_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'gene', 'sequence_ID']]

tRNA = tRNA_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'gene', 'sequence_ID']]

# %%
# This code just convert the chromosome numbering to integer and remove mitochondrial genes.
def lat_to_arabic(DF):
    Latin_to_arabic = {'I': 1, 'II':2, 'III':3, 'IV':4, 'V':5, 'VI':6, 'VII':7, 'VIII':8, 'IX':9, 'X':10,
                      'XI':11, 'XII':12, 'XIII':13, 'XIV':14, 'XV':15, 'XVI':16, 'Mito': 'mitoch', 'MANY': 7}
    seq_id = DF['seq_id']
    ch = []
    contig = []
    for i in seq_id:
        chrom, cont = i.split('_')
        contig.append(cont)
        chrom = chrom.replace('chr', '')
        if '-' in chrom:
            chrom, e = chrom.split('-')
        ch.append(Latin_to_arabic[chrom])
    DF['Chromosome'] = ch
    DF['Contig'] = contig
    return DF

# %%
gene = lat_to_arabic(gene)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\3764198105.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\3764198105.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig

# %%
TE = lat_to_arabic(TE)
sno = lat_to_arabic(sno)
tRNA = lat_to_arabic(tRNA)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\3764198105.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\3764198105.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\3764198105.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\3764198105.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\3764198105.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\3764198105.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig

# %%
gene.head()
# Out:
#                  seq_id  start    end       Name  \
# 0   chrII-2_tig00004927   8297  10119    YBR298C
# 3   chrII-2_tig00004927  10675  10894  YBR298C-A
# 6   chrII-2_tig00004927  10985  12717    YBR299W
# 9   chrII-2_tig00004927  14242  14700    YGR293C
# 12  chrII-2_tig00004927  14660  15022    YGR294W
#
#                                          Alias  \
# 0          MAL31,MAL3T,MALT,maltose%20permease
# 3                                         None
# 6   MAL32,MAL3S,MALS,alpha-glucosidase%20MAL32
# 9                                         None
# 12                  PAU12,seripauperin%20PAU12
#
#                                                  Note  \
# 0   Maltose%20permease%3B%20high-affinity%20maltos...
# 3   Putative%20protein%20of%20unknown%20function%3...
# 6   Maltase%20%28alpha-D-glucosidase%29%3B%20induc...
# 9   Dubious%20open%20reading%20frame%3B%20unlikely...
# 12  Protein%20of%20unknown%20function%3B%20member%...
#
#                                         Ontology_term score strand phase  ...  \
# 0         GO:0000017,GO:0005352,GO:0071944,SO:0000704     .      -     .  ...
# 3         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .  ...
# 6   GO:0000025,GO:0004575,GO:0005886,GO:0005987,GO...     .      +     .  ...
# 9         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .  ...
# 12        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .  ...
#
#                                          display extra_copy_number   gene  \
# 0                             Maltose%20permease                 1  MAL31
# 3   Putative%20protein%20of%20unknown%20function                 1   None
# 6            Maltase%20%28alpha-D-glucosidase%29                 1  MAL32
# 9               Dubious%20open%20reading%20frame                 2   None
# 12             Protein%20of%20unknown%20function                 1  PAU12
#
#    low_identity orf_classification partial_mapping sequence_ID valid_ORFs  \
# 0          None           Verified            None       0.946          0
# 3          None    Uncharacterized            None       0.981          0
# 6          None           Verified            None       0.981          0
# 9          None            Dubious            None       0.989          0
# 12         None           Verified            None       0.983          1
#
#    Chromosome       Contig
# 0           2  tig00004927
# 3           2  tig00004927
# 6           2  tig00004927
# 9           2  tig00004927
# 12          2  tig00004927
#
# [5 rows x 23 columns]

# %%
gene['seq_id'].value_counts()
# Out:
# chrIV_tig00000001        838
# chrII_tig00000010        452
# chrVII_tig00004928       448
# chrXV_tig00000007        438
# chrXIV_tig00004929       418
# chrX_tig00001098         412
# chrXVI_tig00000013       403
# chrV_tig00000015         376
# chrXI_tig00004932        352
# chrXII_tig00000020       332
# chrVIII_tig00000017      316
# chrIX_tig00000023        255
# chrXIII-2_tig00000029    255
# chrXIII_tig00000018      247
# chrXII-2_tig00004934     230
# chrIII_tig00004936       186
# chrXV-2_tig00000035      155
# chrVI_tig00004938        132
# chrMANY_tig00000038      129
# chrI_tig00000033         129
# chrXVI-2_tig00000040     107
# chrMito_tig00000037       36
# chrXII-3_tig00004933      13
# chrX-2_tig00001099        11
# chrII-2_tig00004927        8
# chrXIV-2_tig00004930       8
# chrXI-2_tig00004931        7
# chrXV-3_tig00000066        6
# chrIII-2_tig00004935       3
# chrVI-2_tig00004937        3
# chrXV-4_tig00001046        2
# Name: seq_id, dtype: int64

# %%
def clean20(DF):
    note = DF['Note']
    dis = DF['display']
    clean = []
    display = []
    for n in note:
        clean.append(n.replace('%20', ' '))
    for d in dis:
        display.append(str(d).replace('%20', ' '))
    DF['Note'] = clean
    DF['display'] = display
    return DF

# %%
gene = clean20(gene)
TE = clean20(TE)
sno = clean20(sno)
tRNA = clean20(tRNA)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\741321415.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Note'] = clean
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\741321415.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['display'] = display

# %% [markdown]
# ## Blast TE

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/YGR038C-B_chrVII.fsa', out='Blast_results/YGR038C-B.tsv', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB', outfmt = 6)
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)
# Out:
# STDOUT:
# STDERR:

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/YGR038C-B_chrVII.fsa', out='Blast_results/YGR038C-B.tsv', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB', outfmt = 6)
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/YGR109W-B_chrVII.fsa', out='Blast_results/YGR109W-B.tsv', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB', outfmt = 6)
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)
# Out:
# STDOUT:
# STDERR:

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/YPL060C-A_chrXVI.fsa', out='Blast_results/YPL060C-A.tsv', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB', outfmt = 6)
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)
# Out:
# STDOUT:
# STDERR:

# %%
blast_TE = pd.read_csv('blast_res_3TEs.csv')

# %%
blast_TE.shape
# Out:
# (54, 12)

# %%
contig_chr = TE[['Chromosome', 'Contig']]
contig_chr.drop_duplicates(inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\3061328432.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   contig_chr.drop_duplicates(inplace = True)

# %%
contig_chr
# Out:
#        Chromosome       Contig
# 332             3  tig00004936
# 990             2  tig00000010
# 4441            4  tig00000001
# 5939            1  tig00000033
# 6252            7  tig00000038
# 7676            8  tig00000017
# 9567            6  tig00004938
# 10933           5  tig00000015
# 11895          12  tig00004934
# 17904          16  tig00000040
# 19653          15  tig00000007
# 21622          10  tig00001098

# %%
blast_TE = pd.merge(blast_TE, contig_chr, left_on='subject id', right_on='Contig' )

# %%
blast_TE = blast_TE.sort_values(by=['Chromosome', 's_start'], ascending=True)

# %%
blast_TE.to_excel('blast_TE_sorted.xlsx', index=False)

# %%
blast_TE['Chromosome'].value_counts()
# Out:
# 7     7
# 4     6
# 1     5
# 5     5
# 6     5
# 2     4
# 8     4
# 15    4
# 3     3
# 10    2
# 12    2
# 16    2
# Name: Chromosome, dtype: int64

# %%
TE = TE.sort_values(by=['Chromosome', 'start'], ascending=True)

# %%
TE.to_excel('TE_liftoffv4_sorted.xlsx', index=False)

# %% [markdown]
# ## Df by attribute for S288C

# %%
TE_df_s288c = annot_s288c.filter_feature_of_type(['transposable_element_gene'])
sno_df_s288c = annot_s288c.filter_feature_of_type(['snoRNA_gene'])
tRNA_df_s288c = annot_s288c.filter_feature_of_type(['tRNA_gene'])
gene_df_s288c = annot_s288c.filter_feature_of_type(['gene'])

# %%
gene_attr_s288c = gene_df_s288c.attributes_to_columns()
TE_attr_s288c = TE_df_s288c.attributes_to_columns()
sno_attr_s288c = sno_df_s288c.attributes_to_columns()
tRNA_attr_s288c = tRNA_df_s288c.attributes_to_columns()

# %%
TE_attr_s288c.columns
# Out:
# Index(['seq_id', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase',
#        'attributes', 'Alias', 'ID', 'Name', 'Note', 'Ontology_term', 'curie',
#        'dbxref', 'display'],
#       dtype='object')

# %%
gene_s288c = gene_attr_s288c[['seq_id', 'start', 'end', 'Name', 'gene',  'Alias',  'Note', 'Ontology_term', 'strand', 'phase', 'curie',
        'orf_classification', 'display']]

TE_s288c = TE_attr_s288c[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
      'curie', 'display']]

sno_s288c = sno_attr_s288c[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
      'curie', 'display']]

tRNA_s288c = tRNA_attr_s288c[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
      'curie', 'display']]

# %%
def lat_to_arabic_S288(df):
    # This code just convert the chromosome numbering to integer and remove mitochondrial genes.
    Latin_to_arabic = {'I': 1, 'II':2, 'III':3, 'IV':4, 'V':5, 'VI':6, 'VII':7, 'VIII':8, 'IX':9, 'X':10,
                      'XI':11, 'XII':12, 'XIII':13, 'XIV':14, 'XV':15, 'XVI':16, 'Mito': 'mitoch'}
    chLat = df['seq_id']
    ch = []
    for chrom in chLat:
        chrom = chrom.replace('chr', '')
        ch.append(Latin_to_arabic[chrom])
    df['Chromosome'] = ch
    return df

# %%
gene_s288c = lat_to_arabic_S288(gene_s288c)
TE_s288c = lat_to_arabic_S288(TE_s288c)
sno_s288c = lat_to_arabic_S288(sno_s288c)
tRNA_s288c = lat_to_arabic_S288(tRNA_s288c)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\760545625.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\760545625.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\760545625.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\760545625.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chromosome'] = ch

# %%
gene_s288c = clean20(gene_s288c)
TE_s288c = clean20(TE_s288c)
sno_s288c = clean20(sno_s288c)
tRNA_s288c = clean20(tRNA_s288c)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\741321415.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Note'] = clean
# C:\Users\user\AppData\Local\Temp\ipykernel_12224\741321415.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['display'] = display

# %% [markdown]
# # TE

# %%
TE.to_excel('TE_liftoff4_yps1009.xlsx')

# %%
TE['valid_ORFs'].value_counts()
# Out:
# 1    61
# 0    38
# Name: valid_ORFs, dtype: int64

# %%
TE_count = TE['Chromosome'].value_counts().to_frame()
TE_count = TE_count.rename(columns = {'Chromosome': 'yps1009 TE'})
TE_count_s = TE_s288c['Chromosome'].value_counts().to_frame()
TE_count_s = TE_count_s.rename(columns = {'Chromosome': 'S288C TE'})

# %%
TE_count = TE_count_s.join(TE_count)

# %%
TE_count.to_excel('TE_counts_v4.xlsx')

# %%
TE7_yps = list(TE[TE['Chromosome'] == 7]['Name'])
TE7_s288 = list(TE_s288c[TE_s288c['Chromosome'] == 7]['Name'])

# %%
set(TE7_s288) & set(TE7_yps)
# Out:
# {'YGR027W-A', 'YGR027W-B', 'YGR038C-A', 'YGR038C-B', 'YGR161C-C'}

# %%
TE['valid_ORFs'].value_counts()
# Out:
# 1    61
# 0    38
# Name: valid_ORFs, dtype: int64

# %%
TE[TE['Chromosome'] == 1]
# Out:
#                 seq_id   start     end       Name          Alias  \
# 5939  chrI_tig00000033  177837  179152  YDR034C-C  gag%20protein
#
#                                                    Note  \
# 5939  Retrotransposon TYA Gag gene co-transcribed wi...
#
#                                     Ontology_term score strand phase  \
# 5939  GO:0000943,GO:0003723,GO:0032197,SO:0000704     .      +     .
#
#       copy_num_ID coverage           curie  \
# 5939  YDR034C-C_4    0.999  SGD:S000007344
#
#                                                 display extra_copy_number  \
# 5939  Retrotransposon TYA Gag gene co-transcribed wi...                 4
#
#      sequence_ID valid_ORFs  Chromosome       Contig
# 5939       0.973          0           1  tig00000033

# %% [markdown]
# # snoRNA

# %%
sno_count = sno['Chromosome'].value_counts().to_frame()
sno_count = sno_count.rename(columns = {'Chromosome': 'yps1009 snoRNA'})
sno_count_s = sno_s288c['Chromosome'].value_counts().to_frame()
sno_count_s = sno_count_s.rename(columns = {'Chromosome': 'S288C snoRNA'})
sno_count = sno_count_s.join(sno_count)

# %%
sno_count.to_excel('snoRNA_count_v4.xlsx')

# %% [markdown]
# # tRNA

# %%
tRNA['extra_copy_number'].value_counts()
# Out:
# 0    299
# 1     22
# Name: extra_copy_number, dtype: int64

# %%
tRNA_count = tRNA['Chromosome'].value_counts().to_frame()
tRNA_count = tRNA_count.rename(columns = {'Chromosome': 'yps1009 tRNARNA'})
tRNA_count_s = tRNA_s288c['Chromosome'].value_counts().to_frame()
tRNA_count_s = tRNA_count_s.rename(columns = {'Chromosome': 'S288C tRNARNA'})
tRNA_count = tRNA_count_s.join(tRNA_count)

# %%
tRNA_count.to_excel('tRNA_count_v4.xlsx')

# %% [markdown]
# # GENE

# %%
gene['orf_classification'].value_counts()
# Out:
# Verified           5249
# Uncharacterized     737
# Dubious             719
# Name: orf_classification, dtype: int64

# %%
dubious = gene[gene['orf_classification'] == 'Dubious']
dubious['valid_ORFs'].value_counts()
# Out:
# 1    524
# 0    195
# Name: valid_ORFs, dtype: int64

# %%
uncharacterized = gene[gene['orf_classification'] == 'Uncharacterized']
uncharacterized['valid_ORFs'].value_counts()
# Out:
# 1    564
# 0    173
# Name: valid_ORFs, dtype: int64

# %% [markdown]
# # Verified ORF

# %%
verified = gene[gene['orf_classification'] == 'Verified']

# %%
verified['valid_ORFs'].value_counts()
# Out:
# 1    5087
# 0     162
# Name: valid_ORFs, dtype: int64

# %%
verified_s288c = gene_s288c[gene_s288c['orf_classification'] == 'Verified']

# %%
verified_s288c.shape
# Out:
# (5216, 14)

# %%
verified_valid = verified[verified['valid_ORFs'] == '1']
verified_unvalid = verified[verified['valid_ORFs'] == '0']

verified_valid_count = verified_valid['Chromosome'].value_counts().to_frame()
verified_valid_count = verified_valid_count.rename(columns={'Chromosome': 'Number valid genes'})
verified_unvalid_count = verified_unvalid['Chromosome'].value_counts().to_frame()
verified_unvalid_count = verified_unvalid_count.rename(columns={'Chromosome': 'Number unvalid genes'})

# %%
unval_dic = {}
for ind, row in verified_unvalid.iterrows():
    if row['Chromosome'] in unval_dic:
        unval_dic[row['Chromosome']] = unval_dic[row['Chromosome']] + [row['Name']]
    else:
        unval_dic[row['Chromosome']] = [row['Name']]

# %%
verified_sum = verified_valid_count.join(verified_unvalid_count)

# %%
tmp = []
for ind in verified_sum.index:
    tmp.append(unval_dic[ind])

# %%
verified_sum['unvalid genes'] = tmp

# %%
verified.head(2)
# Out:
#                 seq_id  start    end     Name  \
# 0  chrII-2_tig00004927   8297  10119  YBR298C
# 6  chrII-2_tig00004927  10985  12717  YBR299W
#
#                                         Alias  \
# 0         MAL31,MAL3T,MALT,maltose%20permease
# 6  MAL32,MAL3S,MALS,alpha-glucosidase%20MAL32
#
#                                                 Note  \
# 0  Maltose permease%3B high-affinity maltose tran...
# 6  Maltase %28alpha-D-glucosidase%29%3B inducible...
#
#                                        Ontology_term score strand phase  ...  \
# 0        GO:0000017,GO:0005352,GO:0071944,SO:0000704     .      -     .  ...
# 6  GO:0000025,GO:0004575,GO:0005886,GO:0005987,GO...     .      +     .  ...
#
#                              display extra_copy_number   gene low_identity  \
# 0                   Maltose permease                 1  MAL31         None
# 6  Maltase %28alpha-D-glucosidase%29                 1  MAL32         None
#
#   orf_classification partial_mapping sequence_ID valid_ORFs Chromosome  \
# 0           Verified            None       0.946          0          2
# 6           Verified            None       0.981          0          2
#
#         Contig
# 0  tig00004927
# 6  tig00004927
#
# [2 rows x 23 columns]

# %%
missed = []
moved = []
count_miss = []
count_move = []
for Ch in verified_sum.index:
    s288 = verified_s288c[verified_s288c['Chromosome'] == Ch]
    yps = verified[verified['Chromosome'] == Ch]
    tmp = list(set(s288['Name']) - set(yps['Name']))
    miss = []
    mov = []
    others = verified[verified['Chromosome'] != Ch]
    for g in tmp:
        search = others[others['Name'] == g]
        if search.shape[0] >= 1:
            mov.append((g, list(search['Chromosome']), list(search['valid_ORFs'])))
        else:
            miss.append(g)  
    moved.append(mov)
    missed.append(miss)
    count_miss.append(len(miss))
    count_move.append(len(mov))

# %%
verified_sum['Number of missing genes'] = count_miss
verified_sum['Missing genes'] = missed
verified_sum['Number of moved genes'] = count_move
verified_sum['Moved genes, new chromosome(s), orf validity'] = moved

# %%
verified_sum.to_excel('verified_genes_summary.xlsx')

# %% [markdown]
# # Missing genes dataset

# %%
flat_list = [item for sublist in missed for item in sublist]

# %%
missing_genes = verified_s288c[verified_s288c['Name'].isin(flat_list)]

# %%
missing_genes.to_excel('missing_verified_genes.xlsx')

# %% [markdown]
# # Blast

# %%
# Import Biopython tools for running local BLASTX
from Bio.Blast.Applications import NcbiblastnCommandline
from Bio import SeqIO

# %%
ids = []
seq = []
for seq_record in SeqIO.parse("fasta_file/orf_coding_all_R64-3-1_20210421.fasta", "fasta"):
    ids.append(str(seq_record.id))
    seq.append(str(seq_record.seq))

# %%
for g in flat_list:
    name = g + '.txt'
    with open(name , "w") as file:
        file.write('> ' + g + '\n')
        file.write(seq[ids.index(g)])
    outfile = 'Blast_results/' + g + '.tab'
    cmd_blastn = NcbiblastnCommandline(query= name, out= outfile, evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')
    stdout, stderr = cmd_blastn()
    print("STDOUT: %s" % stdout)
    print("STDERR: %s" % stderr)
# Out:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/S288C_YDR038C_ENA5_genomic.fsa', out='Blast_results/YDR038C.tab', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/S288C_YDR039C_ENA2_genomic.fsa', out='Blast_results/YDR039C.tab', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)

# %% [markdown]
# # Duplicated genes

# %%
# Many duplicated genes in this version
gene['extra_copy_number'].value_counts()
# Out:
# 0    6563
# 1      94
# 2      22
# 3      12
# 4       7
# 5       5
# 6       2
# Name: extra_copy_number, dtype: int64

# %%
gene[gene['extra_copy_number'] > '1']
# Out:
#                       seq_id   start     end       Name  \
# 9        chrII-2_tig00004927   14242   14700    YGR293C
# 21       chrII-2_tig00004927   17994   18290  YER188C-A
# 24      chrIII-2_tig00004935     767    1021    YNR077C
# 27      chrIII-2_tig00004935    1323    2063    YCL076W
# 30      chrIII-2_tig00004935    6426    8271    YCL073C
# 33        chrIII_tig00004936     760    1014    YNR077C
# 36        chrIII_tig00004936    1316    2055    YCL076W
# 651       chrIII_tig00004936  310848  311102    YNL337W
# 2097       chrII_tig00000010  789332  789467  YHL048C-A
# 2106       chrIV_tig00000001    1219    1356  YHL048C-A
# 4835       chrIX_tig00000023    2653    2790  YJL222W-B
# 4838       chrIX_tig00000023    2759    2986  YJL222W-A
# 4841       chrIX_tig00000023    3329    3525  YCR102W-A
# 5644        chrI_tig00000033     676     975    YDR543C
# 6054        chrI_tig00000033  238815  239136    YAL069W
# 6057     chrMANY_tig00000038     737    1036    YDR543C
# 6063     chrMANY_tig00000038    2728    2958  YJL222W-A
# 6917     chrVI-2_tig00004937   12581   12879    YDR543C
# 6920     chrVIII_tig00000017     680     934    YNR077C
# 7906     chrVIII_tig00000017  522253  522633  YAL064W-B
# 9422      chrVII_tig00004928  805604  806749    YGR295C
# 9425      chrVII_tig00004928  807356  807492  YHL048C-A
# 9428      chrVII_tig00004928  807660  807956  YER188C-A
# 9888       chrVI_tig00004938  298356  298655    YDR543C
# 11170     chrX-2_tig00001099     642     835    YCR108C
# 11173     chrX-2_tig00001099    2619    2756  YJL222W-B
# 11182     chrX-2_tig00001099    4754    5859    YCR102C
# 11185     chrX-2_tig00001099    7160   11768    YJL222W
# 11188     chrX-2_tig00001099   12417   14186    YIL172C
# 11221    chrXI-2_tig00004931   28713   28967    YNR077C
# 11224   chrXII-2_tig00004934     699     999    YDR543C
# 12027   chrXII-3_tig00004933    6551    6679  YBL108C-A
# 12030   chrXII-3_tig00004933    7121    7351    YGL260W
# 12060  chrXIII-2_tig00000029    1228    1363  YHL048C-A
# 13703    chrXIII_tig00000018  467347  467484  YHL048C-A
# 13709    chrXIII_tig00000018  467923  468106  YOR394C-A
# 14775     chrXII_tig00000020  554706  554903  YCR102W-A
# 14790     chrXII_tig00000020  557160  557459  YER188C-A
# 16142     chrXIV_tig00004929  728468  728695  YJL222W-A
# 16145     chrXIV_tig00004929  728662  728801  YJL222W-B
# 16158      chrXI_tig00004932     726     980    YNL337W
# 17809   chrXVI-2_tig00000040     743     997    YNL337W
# 19446     chrXVI_tig00000013  719024  719337    YAL069W
# 19500      chrXV_tig00000007   24888   25351  YIL171W-A
# 20876       chrX_tig00001098    2582    2719  YJL222W-B
# 20879       chrX_tig00001098    2688    2915  YJL222W-A
# 20885       chrX_tig00001098    4721    5826    YCR102C
# 20897       chrX_tig00001098   13824   14287  YIL171W-A
#
#                                           Alias  \
# 9                                          None
# 21                                         None
# 24                                         None
# 27                                         None
# 30                 GEX1,glutathione%20exchanger
# 33                                         None
# 36                                         None
# 651                                        None
# 2097                                       None
# 2106                                       None
# 4835                                       None
# 4838                                       None
# 4841                                       None
# 5644                                       None
# 6054                                       None
# 6057                                       None
# 6063                                       None
# 6917                                       None
# 6920                                       None
# 7906                                       None
# 9422                                       COS6
# 9425                                       None
# 9428                                       None
# 9888                                       None
# 11170                                      None
# 11173                                      None
# 11182                                      None
# 11185  VTH2,signal%20sequence-binding%20protein
# 11188       IMA3,oligo-1%2C6-glucosidase%20IMA3
# 11221                                      None
# 11224                                      None
# 12027                  PAU9,seripauperin%20PAU9
# 12030                                      None
# 12060                                      None
# 13703                                      None
# 13709                                      None
# 14775                                      None
# 14790                                      None
# 16142                                      None
# 16145                                      None
# 16158                                      None
# 17809                                      None
# 19446                                      None
# 19500                                      None
# 20876                                      None
# 20879                                      None
# 20885                                      None
# 20897                                      None
#
#                                                     Note  \
# 9      Dubious open reading frame%3B unlikely to enco...
# 21                  Putative protein of unknown function
# 24     Protein of unknown function%2C abundance chang...
# 27     Dubious open reading frame%3B unlikely to enco...
# 30     Proton:glutathione antiporter%3B localized to ...
# 33     Protein of unknown function%2C abundance chang...
# 36     Dubious open reading frame%3B unlikely to enco...
# 651    Dubious open reading frame%3B unlikely to enco...
# 2097   Putative protein of unknown function%3B identi...
# 2106   Putative protein of unknown function%3B identi...
# 4835   Dubious open reading frame%3B unlikely to enco...
# 4838   Dubious open reading frame%3B unlikely to enco...
# 4841   Dubious open reading frame%3B unlikely to enco...
# 5644   Dubious open reading frame%3B unlikely to enco...
# 6054   Dubious open reading frame%3B unlikely to enco...
# 6057   Dubious open reading frame%3B unlikely to enco...
# 6063   Dubious open reading frame%3B unlikely to enco...
# 6917   Dubious open reading frame%3B unlikely to enco...
# 6920   Protein of unknown function%2C abundance chang...
# 7906         Fungal-specific protein of unknown function
# 9422   Endosomal protein involved in turnover of plas...
# 9425   Putative protein of unknown function%3B identi...
# 9428                Putative protein of unknown function
# 9888   Dubious open reading frame%3B unlikely to enco...
# 11170  Putative protein of unknown function%3B identi...
# 11173  Dubious open reading frame%3B unlikely to enco...
# 11182  Putative quinone oxidoreductase%3B overexpress...
# 11185  Putative membrane glycoprotein%3B has strong s...
# 11188  Alpha-glucosidase%3B weak%2C but broad substra...
# 11221  Protein of unknown function%2C abundance chang...
# 11224  Dubious open reading frame%3B unlikely to enco...
# 12027  Protein of unknown function%3B member of the s...
# 12030  Putative protein of unknown function%3B transc...
# 12060  Putative protein of unknown function%3B identi...
# 13703  Putative protein of unknown function%3B identi...
# 13709  Protein of unknown function%3B identified by g...
# 14775  Dubious open reading frame%3B unlikely to enco...
# 14790               Putative protein of unknown function
# 16142  Dubious open reading frame%3B unlikely to enco...
# 16145  Dubious open reading frame%3B unlikely to enco...
# 16158  Dubious open reading frame%3B unlikely to enco...
# 17809  Dubious open reading frame%3B unlikely to enco...
# 19446  Dubious open reading frame%3B unlikely to enco...
# 19500  Dubious open reading frame%3B unlikely to enco...
# 20876  Dubious open reading frame%3B unlikely to enco...
# 20879  Dubious open reading frame%3B unlikely to enco...
# 20885  Putative quinone oxidoreductase%3B overexpress...
# 20897  Dubious open reading frame%3B unlikely to enco...
#
#                                            Ontology_term score strand phase  \
# 9            GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 21           GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 24           GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 27           GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 30     GO:0005774,GO:0005886,GO:0015299,GO:0034775,GO...     .      -     .
# 33           GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 36           GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 651          GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 2097         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 2106         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 4835         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 4838         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 4841         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 5644         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 6054         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 6057         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 6063         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 6917         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 6920         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 7906         GO:0003674,GO:0005783,GO:0008150,SO:0000704     .      -     .
# 9422   GO:0000324,GO:0000324,GO:0003674,GO:0005768,GO...     .      -     .
# 9425         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 9428         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 9888         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 11170        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 11173        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 11182  GO:0003674,GO:0005575,GO:0046688,GO:0071468,SO...     .      +     .
# 11185  GO:0000324,GO:0005048,GO:0005048,GO:0006623,GO...     .      +     .
# 11188  GO:0004574,GO:0004574,GO:0004575,GO:0005737,GO...     .      -     .
# 11221        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 11224        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 12027        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 12030        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 12060        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 13703        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 13709        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 14775        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 14790        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 16142        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 16145        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 16158        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 17809        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 19446        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .
# 19500        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 20876        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 20879        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
# 20885  GO:0003674,GO:0005575,GO:0046688,GO:0071468,SO...     .      +     .
# 20897        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .
#
#        ...                                            display  \
# 9      ...                         Dubious open reading frame
# 21     ...               Putative protein of unknown function
# 24     ...  Protein of unknown function%2C abundance chang...
# 27     ...                         Dubious open reading frame
# 30     ...                      Proton:glutathione antiporter
# 33     ...  Protein of unknown function%2C abundance chang...
# 36     ...                         Dubious open reading frame
# 651    ...                         Dubious open reading frame
# 2097   ...               Putative protein of unknown function
# 2106   ...               Putative protein of unknown function
# 4835   ...                         Dubious open reading frame
# 4838   ...                         Dubious open reading frame
# 4841   ...                         Dubious open reading frame
# 5644   ...                         Dubious open reading frame
# 6054   ...                         Dubious open reading frame
# 6057   ...                         Dubious open reading frame
# 6063   ...                         Dubious open reading frame
# 6917   ...                         Dubious open reading frame
# 6920   ...  Protein of unknown function%2C abundance chang...
# 7906   ...        Fungal-specific protein of unknown function
# 9422   ...  Endosomal protein involved in turnover of plas...
# 9425   ...               Putative protein of unknown function
# 9428   ...               Putative protein of unknown function
# 9888   ...                         Dubious open reading frame
# 11170  ...               Putative protein of unknown function
# 11173  ...                         Dubious open reading frame
# 11182  ...                    Putative quinone oxidoreductase
# 11185  ...                     Putative membrane glycoprotein
# 11188  ...                                  Alpha-glucosidase
# 11221  ...  Protein of unknown function%2C abundance chang...
# 11224  ...                         Dubious open reading frame
# 12027  ...                        Protein of unknown function
# 12030  ...               Putative protein of unknown function
# 12060  ...               Putative protein of unknown function
# 13703  ...               Putative protein of unknown function
# 13709  ...                        Protein of unknown function
# 14775  ...                         Dubious open reading frame
# 14790  ...               Putative protein of unknown function
# 16142  ...                         Dubious open reading frame
# 16145  ...                         Dubious open reading frame
# 16158  ...                         Dubious open reading frame
# 17809  ...                         Dubious open reading frame
# 19446  ...                         Dubious open reading frame
# 19500  ...                         Dubious open reading frame
# 20876  ...                         Dubious open reading frame
# 20879  ...                         Dubious open reading frame
# 20885  ...                    Putative quinone oxidoreductase
# 20897  ...                         Dubious open reading frame
#
#       extra_copy_number  gene low_identity orf_classification partial_mapping  \
# 9                     2  None         None            Dubious            None
# 21                    3  None         None    Uncharacterized            None
# 24                    3  None         None    Uncharacterized            None
# 27                    2  None         None            Dubious            None
# 30                    2  GEX1         None           Verified            None
# 33                    2  None         None    Uncharacterized            None
# 36                    3  None         None            Dubious            None
# 651                   4  None         None            Dubious            None
# 2097                  6  None         None    Uncharacterized            None
# 2106                  4  None         None    Uncharacterized            None
# 4835                  4  None         None            Dubious            None
# 4838                  2  None         None            Dubious            None
# 4841                  3  None         None            Dubious            None
# 5644                  4  None         None            Dubious            None
# 6054                  2  None         None            Dubious            None
# 6057                  2  None         None            Dubious            None
# 6063                  5  None         None            Dubious            None
# 6917                  3  None         None            Dubious            None
# 6920                  5  None         None    Uncharacterized            None
# 7906                  2  None         None    Uncharacterized            None
# 9422                  2  COS6         None           Verified            None
# 9425                  5  None         None    Uncharacterized            None
# 9428                  4  None         None    Uncharacterized            None
# 9888                  5  None         None            Dubious            None
# 11170                 2  None         None    Uncharacterized            None
# 11173                 5  None         None            Dubious            None
# 11182                 2  None         None    Uncharacterized            None
# 11185                 2  VTH2         None           Verified            None
# 11188                 2  IMA3         None           Verified            None
# 11221                 4  None         None    Uncharacterized            None
# 11224                 6  None         None            Dubious            None
# 12027                 2  PAU9         None           Verified            None
# 12030                 2  None         None    Uncharacterized            None
# 12060                 2  None         None    Uncharacterized            None
# 13703                 3  None         None    Uncharacterized            None
# 13709                 2  None         None    Uncharacterized            None
# 14775                 2  None         None            Dubious            None
# 14790                 2  None         None    Uncharacterized            None
# 16142                 3  None         None            Dubious            None
# 16145                 3  None         None            Dubious            None
# 16158                 2  None         None            Dubious            None
# 17809                 3  None         None            Dubious            None
# 19446                 3  None         None            Dubious            None
# 19500                 2  None         None            Dubious            None
# 20876                 2  None         None            Dubious            None
# 20879                 4  None         None            Dubious            None
# 20885                 3  None         None    Uncharacterized            None
# 20897                 3  None         None            Dubious            None
#
#       sequence_ID valid_ORFs Chromosome       Contig
# 9           0.989          0          2  tig00004927
# 21          0.943          1          2  tig00004927
# 24          0.918          1          3  tig00004935
# 27          0.981          0          3  tig00004935
# 30          0.990          0          3  tig00004935
# 33          0.918          1          3  tig00004936
# 36          0.979          0          3  tig00004936
# 651         0.949          1          3  tig00004936
# 2097        0.890          0          2  tig00000010
# 2106        0.920          0          4  tig00000001
# 4835        0.942          1          9  tig00000023
# 4838        0.947          1          9  tig00000023
# 4841        0.949          0          9  tig00000023
# 5644        0.946          0          1  tig00000033
# 6054        0.867          0          1  tig00000033
# 6057        0.936          0          7  tig00000038
# 6063        0.917          0          7  tig00000038
# 6917        0.943          0          6  tig00004937
# 6920        0.917          0          8  tig00000017
# 7906        0.934          1          8  tig00000017
# 9422        0.961          1          7  tig00004928
# 9425        0.927          0          7  tig00004928
# 9428         0.93          1          7  tig00004928
# 9888        0.936          0          6  tig00004938
# 11170       0.917          0         10  tig00001099
# 11173       0.949          1         10  tig00001099
# 11182       0.981          0         10  tig00001099
# 11185       0.972          0         10  tig00001099
# 11188       0.989          1         10  tig00001099
# 11221       0.918          1         11  tig00004931
# 11224       0.926          0         12  tig00004934
# 12027         1.0          1         12  tig00004933
# 12030       0.948          1         12  tig00004933
# 12060       0.948          0         13  tig00000029
# 13703       0.920          0         13  tig00000018
# 13709       0.822          0         13  tig00000018
# 14775       0.954          0         12  tig00000020
# 14790       0.956          1         12  tig00000020
# 16142       0.929          1         14  tig00004929
# 16145       0.921          0         14  tig00004929
# 16158       0.956          1         11  tig00004932
# 17809       0.941          1         16  tig00000040
# 19446       0.895          0         16  tig00000013
# 19500       0.956          0         15  tig00000007
# 20876       0.956          1         10  tig00001098
# 20879       0.939          0         10  tig00001098
# 20885       0.979          0         10  tig00001098
# 20897       0.952          0         10  tig00001098
#
# [48 rows x 23 columns]

# %%
dupl = gene[gene.duplicated(subset=['Name'], keep=False) == True]

# %%
dupl = dupl.sort_values(by = 'Name')

# %%
dupl.to_excel('duplicated_verified_genes.xlsx')

# %% [markdown]
# Duplicated genes:
#
# ATP8/Q0080: Subunit 8 of the F0 sector of mitochondrial F1F0 ATP synthase; encoded on the mitochondrial genome; ATP8 and ATP6 mRNAs are not translated in the absence of the F1 sector of ATPase
#
# OLI1/Q0130: F0-ATP synthase subunit c (ATPase-associated proteolipid); encoded on the mitochondrial genome; mutation confers oligomycin resistance; expression is specifically dependent on the nuclear genes AEP1 and AEP2 1 2 3 4
# Name Description
# OLIgomycin resistance 1
#
# Both on mitochondria so not that relevant to my project.
#
# PAU9/YBL108C-A: Protein of unknown function; member of the seripauperin multigene family encoded mainly in subtelomeric regions; SWAT-GFP and mCherry fusion proteins localize to the endoplasmic reticulum and vacuole respectively
#
# YHR213W-A: Putative protein of unknown function; identified by gene-trapping, microarray-based expression analysis, and genome-wide homology searching

# %% [markdown]
# # Analyse unvalid genes

# %% [markdown]
# 6 partial mapping genes:
#     YDL227C near telomere
#     YMR106C middle of chromosome arm
#     YNL322C near telomere and missing genes, suggesting GAP but could also be a fragment deletion.
#     YOR244W middle of chromosome arm
#     YOR245C middle of chromosome arm

# %%
mRNA_df = annotation.filter_feature_of_type(['mRNA'])
mRNA_attr = mRNA_df.attributes_to_columns()
mRNA_attr.columns
mRNA = mRNA_attr[['seq_id', 'start', 'end', 'score', 'strand', 'phase',
       'attributes', 'ID', 'Name', 'Parent',
       'extra_copy_number', 'inframe_stop_codon', 'matches_ref_protein',
       'missing_start_codon', 'missing_stop_codon',
       'valid_ORF']]

# %%
mRNA.head()
# Out:
#                  seq_id  start    end score strand phase  \
# 1   chrII-2_tig00004927   8297  10119     .      -     .
# 4   chrII-2_tig00004927  10675  10894     .      -     .
# 7   chrII-2_tig00004927  10985  12717     .      +     .
# 10  chrII-2_tig00004927  14242  14700     .      -     .
# 13  chrII-2_tig00004927  14660  15022     .      +     .
#
#                                            attributes                ID  \
# 1   ID=YBR298C_id001_1;Name=YBR298C_id001;Parent=Y...   YBR298C_id001_1
# 4   ID=YBR298C-A_mRNA_1;Name=YBR298C-A_mRNA;Parent...  YBR298C-A_mRNA_1
# 7   ID=YBR299W_id001_1;Name=YBR299W_id001;Parent=Y...   YBR299W_id001_1
# 10  ID=YGR293C_mRNA_2;Name=YGR293C_mRNA;Parent=YGR...    YGR293C_mRNA_2
# 13  ID=YGR294W_id001_1;Name=YGR294W_id001;Parent=Y...   YGR294W_id001_1
#
#               Name       Parent extra_copy_number inframe_stop_codon  \
# 1    YBR298C_id001    YBR298C_1                 1               None
# 4   YBR298C-A_mRNA  YBR298C-A_1                 1               None
# 7    YBR299W_id001    YBR299W_1                 1               None
# 10    YGR293C_mRNA    YGR293C_2                 2               True
# 13   YGR294W_id001    YGR294W_1                 1               None
#
#    matches_ref_protein missing_start_codon missing_stop_codon valid_ORF
# 1                False                None               True     False
# 4                False                None               True     False
# 7                False                None               True     False
# 10               False                None               None     False
# 13                True                None               None      True

# %%
verified_unvalid['extra_copy_number'].value_counts()
# Out:
# 0    128
# 1     32
# 2      2
# Name: extra_copy_number, dtype: int64

# %%
verified_unvalid['low_identity'].value_counts()
# Out:
# True    6
# Name: low_identity, dtype: int64

# %%
verified_unvalid
# Out:
#                      seq_id   start     end     Name  \
# 0       chrII-2_tig00004927    8297   10119  YBR298C
# 6       chrII-2_tig00004927   10985   12717  YBR299W
# 15      chrII-2_tig00004927   15948   17085  YGR295C
# 30     chrIII-2_tig00004935    6426    8271  YCL073C
# 42       chrIII_tig00004936    9270   11015  YKR105C
# ...                     ...     ...     ...      ...
# 22073      chrX_tig00001098  642512  646643  YJR127C
# 22200      chrX_tig00001098  718565  719724  YBR302C
# 22203      chrX_tig00001098  718565  719724  YFL062W
# 22206      chrX_tig00001098  718565  719724  YML132W
# 22209      chrX_tig00001098  718565  719724  YNL336W
#
#                                             Alias  \
# 0             MAL31,MAL3T,MALT,maltose%20permease
# 6      MAL32,MAL3S,MALS,alpha-glucosidase%20MAL32
# 15                                           COS6
# 30                   GEX1,glutathione%20exchanger
# 42        VBA5,basic%20amino%20acid%20transporter
# ...                                           ...
# 22073                                   RSF2,ZMS1
# 22200                                        COS2
# 22203                                        COS4
# 22206                                        COS3
# 22209                                        COS1
#
#                                                     Note  \
# 0      Maltose permease%3B high-affinity maltose tran...
# 6      Maltase %28alpha-D-glucosidase%29%3B inducible...
# 15     Endosomal protein involved in turnover of plas...
# 30     Proton:glutathione antiporter%3B localized to ...
# 42     Plasma membrane protein of the Major Facilitat...
# ...                                                  ...
# 22073  Zinc-finger protein%3B involved in transcripti...
# 22200  Endosomal protein involved in turnover of plas...
# 22203  Endosomal protein involved in turnover of plas...
# 22206  Endosomal protein involved in turnover of plas...
# 22209  Endosomal protein involved in turnover of plas...
#
#                                            Ontology_term score strand phase  \
# 0            GO:0000017,GO:0005352,GO:0071944,SO:0000704     .      -     .
# 6      GO:0000025,GO:0004575,GO:0005886,GO:0005987,GO...     .      +     .
# 15     GO:0000324,GO:0000324,GO:0003674,GO:0005768,GO...     .      -     .
# 30     GO:0005774,GO:0005886,GO:0015299,GO:0034775,GO...     .      -     .
# 42     GO:0003674,GO:0005886,GO:0015809,GO:0015809,SO...     .      +     .
# ...                                                  ...   ...    ...   ...
# 22073  GO:0003700,GO:0005634,GO:0005634,GO:0005737,GO...     .      -     .
# 22200  GO:0000324,GO:0000324,GO:0003674,GO:0005768,GO...     .      -     .
# 22203  GO:0000324,GO:0000324,GO:0000329,GO:0003674,GO...     .      -     .
# 22206  GO:0000324,GO:0000324,GO:0000324,GO:0003674,GO...     .      -     .
# 22209  GO:0000324,GO:0000324,GO:0000329,GO:0003674,GO...     .      -     .
#
#        ...                                            display  \
# 0      ...                                   Maltose permease
# 6      ...                  Maltase %28alpha-D-glucosidase%29
# 15     ...  Endosomal protein involved in turnover of plas...
# 30     ...                      Proton:glutathione antiporter
# 42     ...  Plasma membrane protein of the Major Facilitat...
# ...    ...                                                ...
# 22073  ...                                Zinc-finger protein
# 22200  ...  Endosomal protein involved in turnover of plas...
# 22203  ...  Endosomal protein involved in turnover of plas...
# 22206  ...  Endosomal protein involved in turnover of plas...
# 22209  ...  Endosomal protein involved in turnover of plas...
#
#       extra_copy_number   gene low_identity orf_classification  \
# 0                     1  MAL31         None           Verified
# 6                     1  MAL32         None           Verified
# 15                    1   COS6         None           Verified
# 30                    2   GEX1         None           Verified
# 42                    0   VBA5         None           Verified
# ...                 ...    ...          ...                ...
# 22073                 0   RSF2         None           Verified
# 22200                 0   COS2         None           Verified
# 22203                 0   COS4         None           Verified
# 22206                 0   COS3         None           Verified
# 22209                 0   COS1         None           Verified
#
#       partial_mapping sequence_ID valid_ORFs Chromosome       Contig
# 0                None       0.946          0          2  tig00004927
# 6                None       0.981          0          2  tig00004927
# 15               None       0.955          0          2  tig00004927
# 30               None       0.990          0          3  tig00004935
# 42               None       0.993          0          3  tig00004936
# ...               ...         ...        ...        ...          ...
# 22073            None       0.990          0         10  tig00001098
# 22200            None       0.923          0         10  tig00001098
# 22203            None       0.948          0         10  tig00001098
# 22206            None       0.923          0         10  tig00001098
# 22209            None       0.955          0         10  tig00001098
#
# [162 rows x 23 columns]
