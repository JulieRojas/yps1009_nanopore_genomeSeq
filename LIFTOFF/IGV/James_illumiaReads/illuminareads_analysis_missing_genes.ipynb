# %%
import pandas as pd

# %% [markdown]
# ## Task
#
# The best thing to do for the alignment gaps as I outlined yesterday - as I was typing I realized we already have mapped reads to S288c so we just need the bam files.  For a given gap / chunk of S288c we’re trying to assess:
#
# 1) pull the mapped reads for the aneuploid correspond to that gap we’re assessing (e.g. for a gap on Chr7, get reads for the Dis7 aneuploid)
# 2) We could look at the read pileup, I might need to see some before assessing if we need to get fancier - I bet for most regions, the sequence is actually there with coverage across the whole gap.  If so:
# 3) calculate the median reads in that chunk (normalized to the length of the chunk) and compare to the median reads from chunks (or could be all genes) that are NOT on that chromosome.  We expect that if that gap is in YPS1009 AND it’s on the chromosomes in question, the read count should be ~2X the genome sequence NOT on that chromosome (since the chunk should be duplicated in this particular aneuploids strain).

# %%
rpkm = pd.read_csv('James_220427_KC5T7-RPKM.results', sep = '\t', index_col=0)

# %%
rpkm.columns
# Out:
# Index(['Gasch-1240_S29', 'Gasch-1234_S23', 'Gasch-1235_S24', 'Gasch-1214_S3',
#        'Gasch-1221_S10', 'Gasch-1218_S7', 'Gasch-1237_S26', 'Gasch-1222_S11',
#        'Gasch-1215_S4', 'Gasch-1223_S12', 'Gasch-1220_S9', 'Gasch-1219_S8',
#        'Gasch-1236_S25', 'Gasch-1224_S13', 'Gasch-1216_S5', 'Gasch-1249_S38',
#        'Gasch-1225_S14', 'Gasch-1258_S47', 'Gasch-1231_S20', 'Gasch-1248_S37',
#        'Gasch-1227_S16', 'Gasch-1232_S21', 'Gasch-1217_S6', 'Gasch-1259_S48',
#        'Gasch-1233_S22', 'Gasch-1226_S15', 'Gasch-1250_S39', 'Gasch-1254_S43',
#        'Gasch-1246_S35', 'Gasch-1230_S19', 'Gasch-1260_S49', 'Gasch-1255_S44',
#        'Gasch-1228_S17', 'Gasch-1247_S36', 'Gasch-1257_S46', 'Gasch-1229_S18',
#        'Gasch-1245_S34', 'Gasch-1256_S45', 'Gasch-1244_S33', 'Gasch-1212_S1',
#        'Gasch-1243_S32', 'Gasch-1242_S31', 'Gasch-1251_S40', 'Gasch-1238_S27',
#        'Gasch-1241_S30', 'Gasch-1252_S41', 'Gasch-1213_S2', 'Gasch-1253_S42',
#        'Gasch-1239_S28'],
#       dtype='object')

# %%
samples = pd.read_csv('YPS1009-Disomes_GenomicSeq.txt', sep = '\t')

# %%
dic = {}
for ind, row in samples.iterrows():
    code = row['Next-Gen Gasch #'].replace(' ', '-')
    dic[code] = row['Strain']

# %%
for c in list(rpkm.columns):
    cs, t = c.split('_')
    rpkm = rpkm.rename(columns={c: dic[cs]})

# %%
missing = pd.read_csv('missing_genes_v5.txt', sep='\t')

# %%
rpkm_missing_val = []
rpkm_missing = []
for ind, row in missing.iterrows():
    tmp = rpkm[rpkm.index == row['Name']]
    rpkm_missing_val.append(tmp.sum().sum())
    if tmp.sum().sum() == 0:
        rpkm_missing.append(True)
    else:
        rpkm_missing.append(False)

# %%
missing['rpkm sum'] = rpkm_missing_val
missing['no illumina reads'] = rpkm_missing

# %%
sum(rpkm_missing)
# Out:
# 20

# %%
g = list(missing['Name'])
col = list(rpkm)
avg_all_but = []
avg_dis = []
for ind, row in missing.iterrows():
    res = list(filter(lambda x: 'Dis' + str(row['Chromosome']) + ' ' in x, col))
    tmp = rpkm[rpkm.index == row['Name']]
    avg_dis.append(tmp[res].mean(axis=1)[0])
    avg_all_but.append(tmp.loc[:, ~tmp.columns.isin(res)].mean(axis=1)[0])

# %%
missing['AVG rpmk Disome'] = avg_dis
missing['AVG rpkm all but Dis'] = avg_all_but

# %%
missing
# Out:
#     Unnamed: 0   seq_id    start      end       Name    gene  \
# 0          459     chrI   201467   201787    YAR047C     NaN
# 1         3257   chrIII   309070   310155    YCR105W    ADH7
# 2         4509    chrIV   520516   520692  YDR034C-A     NaN
# 3         7947     chrV   449474   449578  YER138W-A     NaN
# 4         8862    chrVI   269061   269516    YFR057W     NaN
# 5         9420   chrVII   249869   252738    YGL137W   SEC27
# 6         9426   chrVII   252897   253859    YGL136C    MRM2
# 7         9434   chrVII   255663   256964    YGL134W   PCL10
# 8         9438   chrVII   257707   261501    YGL133W    ITC1
# 9         9441   chrVII   261580   261915    YGL132W     NaN
# 10       10632   chrVII   735630   735758  YGR122C-A     NaN
# 11       13445    chrIX   300829   301257    YIL029C   EMA17
# 12       17922   chrXII   454392   454556  YLR154W-B     NaN
# 13       17925   chrXII   454696   455070  YLR154W-C    TAR1
# 14       17934   chrXII   455433   455636  YLR154W-E     NaN
# 15       18000   chrXII   469317   470405    YLR155C  ASP3-1
# 16       18003   chrXII   472113   472457    YLR156W     NaN
# 17       18012   chrXII   472969   474057    YLR157C  ASP3-2
# 18       18015   chrXII   475764   475976  YLR157W-D     NaN
# 19       18029   chrXII   481873   482037  YLR157W-E     NaN
# 20       18038   chrXII   482549   483637    YLR158C  ASP3-3
# 21       18041   chrXII   485345   485689    YLR159W     NaN
# 22       18050   chrXII   486201   487289    YLR160C  ASP3-4
# 23       18053   chrXII   488997   489341    YLR161W     NaN
# 24       19453   chrXII  1071594  1071710  YLR466C-B     NaN
# 25       20356  chrXIII   362702   362830  YMR046W-A     NaN
# 26       20617  chrXIII   478064   478258  YMR105W-A     NaN
# 27       21669   chrXIV     6561     6719    YNL338W     NaN
# 28       21695   chrXIV    18001    19302    YNL330C    RPD3
# 29       21699   chrXIV    19541    22633    YNL329C    PEX6
# 30       21702   chrXIV    22834    23274    YNL328C    MDJ2
# 31       21706   chrXIV    24048    27173    YNL327W    EGT2
# 32       21710   chrXIV    27337    28347    YNL326C    PFA3
# 33       21717   chrXIV    28739    31378    YNL325C    FIG4
# 34       21721   chrXIV    31050    31445    YNL324W     NaN
# 35       21724   chrXIV    31944    33188    YNL323W    LEM3
# 36       25309    chrXV   795801   796793    YOR246C    ENV9
# 37       25313    chrXV   797676   798308    YOR247W    SRL1
# 38       25316    chrXV   798013   798315    YOR248W     NaN
# 39       25343    chrXV   807271   808107    YOR255W    OSW1
# 40       26081   chrXVI    63279    63860    YPL257W     NaN
# 41       28299  chrMito    61022    61729      Q0160    SCEI
#
#                                                 Alias  \
# 0                                                 NaN
# 1   ADH7,ADHVII,NADP-dependent%20alcohol%20dehydro...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                    SEC27,coatomer%20subunit%20beta'
# 6   MRM2,21S%20rRNA%20%28uridine2791-2'-O%29%20met...
# 7                                               PCL10
# 8                                                ITC1
# 9                                                 NaN
# 10                                                NaN
# 11                                              EMA17
# 12                                                NaN
# 13                                     TAR1,YLR154W-A
# 14                                                NaN
# 15                  ASP3-1,ASP3,asparaginase%20ASP3-1
# 16                                                NaN
# 17                  ASP3-2,ASP3,asparaginase%20ASP3-2
# 18                                          YLR157W-A
# 19                                YLR157W-B,YLR157W-C
# 20                  ASP3-3,ASP3,asparaginase%20ASP3-3
# 21                                                NaN
# 22                  ASP3-4,ASP3,asparaginase%20ASP3-4
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  RPD3,MOF6,REC3,SDI2,SDS6,histone%20deacetylase...
# 29      PEX6,AAA%20family%20ATPase%20peroxin%206,PAS8
# 30                                               MDJ2
# 31                                               EGT2
# 32                   PFA3,palmitoyltransferase%20PFA3
# 33  FIG4,phosphatidylinositol-3%2C5-bisphosphate%2...
# 34                                                NaN
# 35                                     LEM3,BRE3,ROS3
# 36                                               ENV9
# 37                                               SRL1
# 38                                                NaN
# 39                                               OSW1
# 40                                                NaN
# 41  SCEI,I-SceIV,OMEGA,intron-encoded%20endonuclea...
#
#                                                  Note  \
# 0   Dubious open reading frame%3B unlikely to enco...
# 1   NADPH-dependent medium chain alcohol dehydroge...
# 2   Putative protein of unknown function%3B contai...
# 3   Putative protein of unknown function%3B YER138...
# 4                Putative protein of unknown function
# 5   Essential beta'-coat protein of the COPI coato...
# 6   Mitochondrial 2' O-ribose methyltransferase%3B...
# 7   Pho85p cyclin%3B recruits%2C activates%2C and ...
# 8   Subunit of ATP-dependent Isw2p-Itc1p chromatin...
# 9   Dubious open reading frame%3B unlikely to enco...
# 10  Dubious open reading frame%3B unlikely to enco...
# 11  Protein involved in targeting mitochondrial me...
# 12  Dubious open reading frame%3B unlikely to enco...
# 13  Protein potentially involved in regulation of ...
# 14  Dubious open reading frame%3B unlikely to enco...
# 15  Cell-wall L-asparaginase II involved in aspara...
# 16  Putative protein of unknown function%3B exhibi...
# 17  Cell-wall L-asparaginase II involved in aspara...
# 18  Putative protein of unknown function%3B identi...
# 19  Putative protein of unknown function identifie...
# 20  Cell-wall L-asparaginase II involved in aspara...
# 21  Putative protein of unknown function%3B YLR156...
# 22  Cell-wall L-asparaginase II involved in aspara...
# 23  Putative protein of unknown function%3B YLR156...
# 24  Dubious open reading frame%3B unlikely to enco...
# 25  Dubious open reading frame%3B unlikely to enco...
# 26               Putative protein of unknown function
# 27  Dubious open reading frame%3B unlikely to enco...
# 28  Histone deacetylase%2C component of both the R...
# 29  AAA-peroxin%3B heterodimerizes with AAA-peroxi...
# 30  Constituent of the mitochondrial import motor%...
# 31  Glycosylphosphatidylinositol %28GPI%29-anchore...
# 32  Palmitoyltransferase for Vac8p%3B required for...
# 33  Phosphatidylinositol 3%2C5-bisphosphate %28Ptd...
# 34  Dubious open reading frame%3B unlikely to enco...
# 35  Membrane protein of the plasma membrane and ER...
# 36  Conserved oxidoreductase involved in lipid dro...
# 37  Mannoprotein that exhibits a tight association...
# 38  Dubious open reading frame%3B unlikely to enco...
# 39  Protein involved in sporulation%3B required fo...
# 40  Putative protein of unknown function%3B homozy...
# 41  I-SceI DNA endonuclease%3B encoded by the mito...
#
#                                         Ontology_term strand phase  \
# 0         GO:0003674,GO:0005575,GO:0008150,SO:0000704      -     .
# 1         GO:0005575,GO:0006066,GO:0008106,SO:0000704      +     .
# 2         GO:0003674,GO:0005575,GO:0008150,SO:0000704      -     .
# 3         GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 4         GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 5   GO:0006888,GO:0006890,GO:0008298,GO:0030126,GO...      +     .
# 6   GO:0005739,GO:0008650,GO:0008650,GO:0008650,GO...      -     .
# 7   GO:0000079,GO:0000307,GO:0016538,GO:0045719,GO...      +     .
# 8   GO:0003674,GO:0005634,GO:0006348,GO:0008623,GO...      +     .
# 9         GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 10        GO:0003674,GO:0005575,GO:0008150,SO:0000704      -     .
# 11        GO:0003674,GO:0008150,GO:0016021,SO:0000704      -     .
# 12        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 13        GO:0003674,GO:0005739,GO:0043457,SO:0000704      +     .
# 14        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 15  GO:0004067,GO:0005635,GO:0005783,GO:0006530,GO...      -     .
# 16        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 17  GO:0004067,GO:0006530,GO:0006995,GO:0030287,SO...      -     .
# 18        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 19        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 20  GO:0004067,GO:0006530,GO:0006995,GO:0030287,SO...      -     .
# 21        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 22  GO:0004067,GO:0006530,GO:0006995,GO:0030287,GO...      -     .
# 23        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 24        GO:0003674,GO:0005575,GO:0008150,SO:0000704      -     .
# 25        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 26        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 27        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 28  GO:0000083,GO:0000083,GO:0000117,GO:0000118,GO...      -     .
# 29  GO:0005777,GO:0005777,GO:0005829,GO:0016562,GO...      -     .
# 30  GO:0001405,GO:0001671,GO:0005743,GO:0030150,GO...      -     .
# 31  GO:0000324,GO:0000920,GO:0005621,GO:0005933,GO...      +     .
# 32  GO:0000324,GO:0000324,GO:0000324,GO:0000324,GO...      -     .
# 33  GO:0000329,GO:0019898,GO:0034399,GO:0043813,GO...      -     .
# 34        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 35  GO:0005737,GO:0005783,GO:0005783,GO:0005886,GO...      +     .
# 36  GO:0005739,GO:0005811,GO:0005811,GO:0006624,GO...      -     .
# 37  GO:0000324,GO:0003674,GO:0005737,GO:0005934,GO...      +     .
# 38        GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
# 39  GO:0003674,GO:0005628,GO:0030437,GO:0030476,SO...      +     .
# 40                   GO:0003674,GO:0008150,SO:0000704      +     .
# 41  GO:0004519,GO:0004519,GO:0005739,GO:0006314,SO...      +     .
#
#              curie orf_classification  \
# 0   SGD:S000000083            Dubious
# 1   SGD:S000000702           Verified
# 2   SGD:S000007233    Uncharacterized
# 3   SGD:S000007239    Uncharacterized
# 4   SGD:S000001953    Uncharacterized
# 5   SGD:S000003105           Verified
# 6   SGD:S000003104           Verified
# 7   SGD:S000003102           Verified
# 8   SGD:S000003101           Verified
# 9   SGD:S000003100            Dubious
# 10  SGD:S000007240            Dubious
# 11  SGD:S000001291    Uncharacterized
# 12  SGD:S000028563            Dubious
# 13  SGD:S000028422           Verified
# 14  SGD:S000028676            Dubious
# 15  SGD:S000004145           Verified
# 16  SGD:S000004146    Uncharacterized
# 17  SGD:S000004147           Verified
# 18  SGD:S000028677    Uncharacterized
# 19  SGD:S000028678    Uncharacterized
# 20  SGD:S000004148           Verified
# 21  SGD:S000004149    Uncharacterized
# 22  SGD:S000004150           Verified
# 23  SGD:S000004151    Uncharacterized
# 24  SGD:S000028686            Dubious
# 25  SGD:S000007248            Dubious
# 26  SGD:S000028692    Uncharacterized
# 27  SGD:S000005282            Dubious
# 28  SGD:S000005274           Verified
# 29  SGD:S000005273           Verified
# 30  SGD:S000005272           Verified
# 31  SGD:S000005271           Verified
# 32  SGD:S000005270           Verified
# 33  SGD:S000005269           Verified
# 34  SGD:S000005268            Dubious
# 35  SGD:S000005267           Verified
# 36  SGD:S000005772           Verified
# 37  SGD:S000005773           Verified
# 38  SGD:S000005774            Dubious
# 39  SGD:S000005781           Verified
# 40  SGD:S000006178    Uncharacterized
# 41  SGD:S000007279           Verified
#
#                                               display Chromosome Unnamed: 15  \
# 0                          Dubious open reading frame          1     No hits
# 1   NADPH-dependent medium chain alcohol dehydroge...          3     No hits
# 2                Putative protein of unknown function          4        Hits
# 3                Putative protein of unknown function          5        Hits
# 4                Putative protein of unknown function          6     No hits
# 5   Essential beta'-coat protein of the COPI coatomer          7     No hits
# 6         Mitochondrial 2' O-ribose methyltransferase          7     No hits
# 7                                       Pho85p cyclin          7     No hits
# 8   Subunit of ATP-dependent Isw2p-Itc1p chromatin...          7     No hits
# 9                          Dubious open reading frame          7     No hits
# 10                         Dubious open reading frame          7        Hits
# 11  Protein involved in targeting mitochondrial me...          9     No hits
# 12                         Dubious open reading frame         12     No hits
# 13  Protein potentially involved in regulation of ...         12     No hits
# 14                         Dubious open reading frame         12     No hits
# 15  Cell-wall L-asparaginase II involved in aspara...         12     No hits
# 16               Putative protein of unknown function         12     No hits
# 17  Cell-wall L-asparaginase II involved in aspara...         12     No hits
# 18               Putative protein of unknown function         12     No hits
# 19  Putative protein of unknown function identifie...         12     No hits
# 20  Cell-wall L-asparaginase II involved in aspara...         12     No hits
# 21               Putative protein of unknown function         12     No hits
# 22  Cell-wall L-asparaginase II involved in aspara...         12     No hits
# 23               Putative protein of unknown function         12     No hits
# 24                         Dubious open reading frame         12     No hits
# 25                         Dubious open reading frame         13        Hits
# 26               Putative protein of unknown function         13     No hits
# 27                         Dubious open reading frame         14     No hits
# 28  Histone deacetylase%2C component of both the R...         14     No hits
# 29                                        AAA-peroxin         14     No hits
# 30      Constituent of the mitochondrial import motor         14     No hits
# 31  Glycosylphosphatidylinositol %28GPI%29-anchore...         14     No hits
# 32                     Palmitoyltransferase for Vac8p         14     No hits
# 33  Phosphatidylinositol 3%2C5-bisphosphate %28Ptd...         14     No hits
# 34                         Dubious open reading frame         14     No hits
# 35     Membrane protein of the plasma membrane and ER         14     No hits
# 36  Conserved oxidoreductase involved in lipid dro...         15     No hits
# 37  Mannoprotein that exhibits a tight association...         15     No hits
# 38                         Dubious open reading frame         15     No hits
# 39                    Protein involved in sporulation         15     No hits
# 40               Putative protein of unknown function         16     No hits
# 41                            I-SceI DNA endonuclease     mitoch     No hits
#
#        rpkm sum  no illumina reads  AVG rpmk Disome  AVG rpkm all but Dis
# 0      0.000000               True         0.000000              0.000000
# 1      0.000000               True         0.000000              0.000000
# 2      0.000000               True         0.000000              0.000000
# 3     56.037312              False         0.000000              1.192283
# 4      0.000000               True              NaN              0.000000
# 5   1839.993915              False        75.560709             34.172246
# 6   2084.380818              False        58.191421             41.147003
# 7   1916.747909              False        64.940069             36.821947
# 8   1882.690663              False        71.756721             35.459195
# 9   2015.775295              False        59.302206             39.523699
# 10  2685.177012              False        76.855465             52.839003
# 11     0.000000               True         0.000000              0.000000
# 12     0.000000               True         0.000000              0.000000
# 13     0.000000               True         0.000000              0.000000
# 14     0.000000               True         0.000000              0.000000
# 15     0.000000               True         0.000000              0.000000
# 16     0.000000               True         0.000000              0.000000
# 17     0.000000               True         0.000000              0.000000
# 18     0.000000               True         0.000000              0.000000
# 19     0.000000               True         0.000000              0.000000
# 20     0.000000               True         0.000000              0.000000
# 21     0.000000               True         0.000000              0.000000
# 22     0.000000               True         0.000000              0.000000
# 23     0.000000               True         0.000000              0.000000
# 24     0.000000               True         0.000000              0.000000
# 25  1265.871343              False        26.246934             25.797413
# 26  2760.896830              False        93.371848             53.053543
# 27   394.263874              False         6.040910              8.224450
# 28  2139.997683              False        82.362725             40.234373
# 29  1883.018518              False        67.255645             35.866576
# 30  2177.304275              False        72.640463             41.927609
# 31  2010.481887              False        77.510704             37.787535
# 32  1961.394264              False        80.417882             36.438283
# 33  2030.247280              False        80.223354             37.985641
# 34  2346.767640              False        99.436392             43.311602
# 35  2060.728231              False        70.508790             39.526513
# 36  1838.986886              False        64.314518             35.149529
# 37   804.051944              False        28.568110             15.328433
# 38    42.888796              False         1.225471              0.844154
# 39  1790.423275              False        58.682220             34.570987
# 40     0.000000               True         0.000000              0.000000
# 41     0.000000               True              NaN              0.000000

# %%
missing.to_excel('missing_genes_v5_illuminaReads.xlsx')

# %% [markdown]
# ## Gene that doesn't seems on the right chromosome

# %%
rpkm[rpkm.index == 'YNL338W']
# Out:
#          Dis16 wild-type  Dis13 wild-type  Dis13 ssd1-  Dis1 wild-type  \
# Gene
# YNL338W              0.0              0.0          0.0             0.0
#
#          Dis4 ssd1-/ssd1-  Dis3 wild-type  Dis14 ssd1-  Dis5 wild-type  \
# Gene
# YNL338W          28.18245             0.0          0.0             0.0
#
#          Dis1 ssd1-  Dis5 ssd1-  ...  Euploid wild-type  Dis4 ssd1-/ssd1-  \
# Gene                             ...
# YNL338W    9.249908   20.073339  ...           17.45493               0.0
#
#          Dis4 wild-type  Euploid ssd1-  Dis15 wild-type  \
# Gene
# YNL338W          6.4652      15.930688              0.0
#
#          Euploid CEN15 wild-type  Dis12 wild-type  Euploid ssd1-  \
# Gene
# YNL338W                40.506276              0.0            0.0
#
#          Dis12 wild-type rDNA hemizygous clone #3  Dis15 ssd1-
# Gene
# YNL338W                                       0.0          0.0
#
# [1 rows x 49 columns]

# %% [markdown]
# # Chromosome 7

# %%
# select genes missing on chromosome 7
c7 = missing[missing['Chromosome'] == '7']
g7 = list(c7['Name'])
rpkm7 = rpkm[rpkm.index.isin(g7)]

# %%
rpkm7_copy = rpkm7.copy()
rpkm7_copy['avg Dis7'] = rpkm7[['Dis7 wild-type', 'Dis7 ssd1-']].mean(axis=1)
rpkm7_copy['avg al but dis7'] = rpkm7.loc[:, ~rpkm7.columns.isin(['Dis7 wild-type', 'Dis7 ssd1-'])].mean(axis=1)

# %%
rpkm7_copy
# Out:
#          Dis16 wild-type  Dis13 wild-type  Dis13 ssd1-  Dis1 wild-type  \
# Gene
# YGL133W        41.183188        29.619028    38.016258       36.639278
# YGL134W        32.318073        40.038010    50.466899       44.360671
# YGL136C        41.197992        54.132388    47.466091       51.091291
# YGL137W        28.367279        31.116620    33.169598       40.860553
#
#          Dis4 ssd1-/ssd1-  Dis3 wild-type  Dis14 ssd1-  Dis5 wild-type  \
# Gene
# YGL133W         31.290317       40.906661    34.801975       35.343815
# YGL134W         29.253902       31.710785    44.137552       37.461187
# YGL136C         37.225416       49.733574    46.064966       20.575936
# YGL137W         36.922176       29.689846    41.158506       37.676904
#
#          Dis1 ssd1-  Dis5 ssd1-  ...  Dis4 wild-type  Euploid ssd1-  \
# Gene                             ...
# YGL133W   39.917190   46.676463  ...       35.213621      32.037684
# YGL134W   35.017507   23.287848  ...       41.845041      27.236338
# YGL136C   29.017623   33.142895  ...       59.777928      49.975710
# YGL137W   40.761952   38.252115  ...       25.025411      32.255168
#
#          Dis15 wild-type  Euploid CEN15 wild-type  Dis12 wild-type  \
# Gene
# YGL133W        35.615184                47.518825        29.617613
# YGL134W        20.533695                33.389678        37.302151
# YGL136C        37.016089                46.815665        37.464839
# YGL137W        26.701493                38.594744        38.978652
#
#          Euploid ssd1-  Dis12 wild-type rDNA hemizygous clone #3  Dis15 ssd1-  \
# Gene
# YGL133W      38.876403                                 31.078331    27.122084
# YGL134W      33.994458                                 22.318156    33.202681
# YGL136C      47.354123                                 35.499651    40.615533
# YGL137W      36.670495                                 30.088946    40.862925
#
#           avg Dis7  avg al but dis7
# Gene
# YGL133W  71.756721        36.248272
# YGL134W  64.940069        37.433211
# YGL136C  58.191421        41.517534
# YGL137W  75.560709        35.071995
#
# [4 rows x 51 columns]

# %% [markdown]
# The 4 missing genes of chromosome 7 are 2x higher values in Dis7 strains than in other strains, so gap in assembly

# %% [markdown]
# # Chromosome 12

# %%
c12 = missing[missing['Chromosome'] == '12']
g12 = list(c12['Name'])
rpkm12 = rpkm[rpkm.index.isin(g12)]
rpkm12_copy = rpkm12.copy()
rpkm12_copy['avg Dis12'] = rpkm12[['Dis12 wild-type', 'Dis12 ssd1-']].mean(axis=1)
rpkm12_copy['avg al but dis12'] = rpkm12.loc[:, ~rpkm12.columns.isin(['Dis12 wild-type', 'Dis12 ssd1-'])].mean(axis=1)

# %%
rpkm12_copy
# Out:
#            Dis16 wild-type  Dis13 wild-type  Dis13 ssd1-  Dis1 wild-type  \
# Gene
# YLR154W-C              0.0              0.0          0.0             0.0
# YLR155C                0.0              0.0          0.0             0.0
# YLR157C                0.0              0.0          0.0             0.0
# YLR158C                0.0              0.0          0.0             0.0
# YLR160C                0.0              0.0          0.0             0.0
#
#            Dis4 ssd1-/ssd1-  Dis3 wild-type  Dis14 ssd1-  Dis5 wild-type  \
# Gene
# YLR154W-C               0.0             0.0          0.0             0.0
# YLR155C                 0.0             0.0          0.0             0.0
# YLR157C                 0.0             0.0          0.0             0.0
# YLR158C                 0.0             0.0          0.0             0.0
# YLR160C                 0.0             0.0          0.0             0.0
#
#            Dis1 ssd1-  Dis5 ssd1-  ...  Dis4 wild-type  Euploid ssd1-  \
# Gene                               ...
# YLR154W-C         0.0         0.0  ...             0.0            0.0
# YLR155C           0.0         0.0  ...             0.0            0.0
# YLR157C           0.0         0.0  ...             0.0            0.0
# YLR158C           0.0         0.0  ...             0.0            0.0
# YLR160C           0.0         0.0  ...             0.0            0.0
#
#            Dis15 wild-type  Euploid CEN15 wild-type  Dis12 wild-type  \
# Gene
# YLR154W-C              0.0                      0.0              0.0
# YLR155C                0.0                      0.0              0.0
# YLR157C                0.0                      0.0              0.0
# YLR158C                0.0                      0.0              0.0
# YLR160C                0.0                      0.0              0.0
#
#            Euploid ssd1-  Dis12 wild-type rDNA hemizygous clone #3  \
# Gene
# YLR154W-C            0.0                                       0.0
# YLR155C              0.0                                       0.0
# YLR157C              0.0                                       0.0
# YLR158C              0.0                                       0.0
# YLR160C              0.0                                       0.0
#
#            Dis15 ssd1-  avg Dis12  avg al but dis12
# Gene
# YLR154W-C          0.0        0.0               0.0
# YLR155C            0.0        0.0               0.0
# YLR157C            0.0        0.0               0.0
# YLR158C            0.0        0.0               0.0
# YLR160C            0.0        0.0               0.0
#
# [5 rows x 51 columns]

# %%
real gap, no reads whatsoever

# %% [markdown]
# # Chromosome 14

# %%
c14 = missing[missing['Chromosome'] == '14']
g14 = list(c14['Name'])
rpkm14 = rpkm[rpkm.index.isin(g14)]
rpkm14_copy = rpkm14.copy()
rpkm14_copy['avg Dis14'] = rpkm14[['Dis14 wild-type', 'Dis14 ssd1-']].mean(axis=1)
rpkm14_copy['avg al but dis14'] = rpkm14.loc[:, ~rpkm14.columns.isin(['Dis14 wild-type', 'Dis14 ssd1-'])].mean(axis=1)

# %%
rpkm14_copy
# Out:
#          Dis16 wild-type  Dis13 wild-type  Dis13 ssd1-  Dis1 wild-type  \
# Gene
# YNL323W        33.797695        39.254134    29.830722       56.700895
# YNL325C        41.440583        39.492038    35.710817       58.341004
# YNL326C        43.998611        33.837762    38.148053       40.202010
# YNL327W        39.997492        36.478969    38.840939       40.374612
# YNL328C        16.356902        36.939831    29.151687      111.566696
# YNL329C        32.650344        36.868173    33.713412       34.580830
# YNL330C        43.398555        41.289198    38.398728       52.575610
#
#          Dis4 ssd1-/ssd1-  Dis3 wild-type  Dis14 ssd1-  Dis5 wild-type  \
# Gene
# YNL323W         25.194431       37.142116    79.359897       42.849053
# YNL325C         41.585126       38.159605    82.106758       32.908908
# YNL326C         33.241910       26.136461    73.794660       18.091419
# YNL327W         33.686412       38.566644    87.725186       51.684394
# YNL328C         30.483058       18.724463    91.446223       58.756088
# YNL329C         36.218958       41.647856    73.992944       28.581868
# YNL330C         30.974720       32.979216    86.726418       42.143835
#
#          Dis1 ssd1-  Dis5 ssd1-  ...  Dis4 wild-type  Euploid ssd1-  \
# Gene                             ...
# YNL323W   61.428302   51.271660  ...       38.806781      30.517824
# YNL325C   46.239027   38.686798  ...       46.336385      53.729866
# YNL326C   33.458865   22.098542  ...       42.704855      20.043358
# YNL327W   43.755081   52.071242  ...       31.569040      41.325000
# YNL328C   76.705016   50.661283  ...       25.640897      28.718587
# YNL329C   37.089348   35.084535  ...       34.564680      49.136361
# YNL330C   41.795089   28.190553  ...       38.686925      58.363580
#
#          Dis15 wild-type  Euploid CEN15 wild-type  Dis12 wild-type  \
# Gene
# YNL323W        40.561606                40.091452        49.041093
# YNL325C        18.565882                42.692694        27.332303
# YNL326C        19.098435                41.407751        37.058635
# YNL327W        28.983207                46.356750        34.624415
# YNL328C        23.575723                51.115062        44.052064
# YNL329C        28.332028                41.645638        42.172053
# YNL330C        27.378259                43.282916        27.710169
#
#          Euploid ssd1-  Dis12 wild-type rDNA hemizygous clone #3  Dis15 ssd1-  \
# Gene
# YNL323W      47.401108                                 20.594075    31.415870
# YNL325C      36.579161                                 34.315657    29.630877
# YNL326C      22.552928                                 45.649181    38.687199
# YNL327W      37.328062                                 35.542237    34.243584
# YNL328C      51.702971                                 42.635806    42.011555
# YNL329C      48.133587                                 34.816171    25.956703
# YNL330C      38.114999                                 49.887644    36.364841
#
#          avg Dis14  avg al but dis14
# Gene
# YNL323W  70.508790         39.526513
# YNL325C  80.223354         37.985641
# YNL326C  80.417882         36.438283
# YNL327W  77.510704         37.787535
# YNL328C  72.640463         41.927609
# YNL329C  67.255645         35.866576
# YNL330C  82.362725         40.234373
#
# [7 rows x 51 columns]

# %% [markdown]
# # Chromosome 15

# %%
c15 = missing[missing['Chromosome'] == '15']
g15 = list(c15['Name'])
rpkm15 = rpkm[rpkm.index.isin(g15)]
rpkm15_copy = rpkm15.copy()
rpkm15_copy['avg Dis15'] = rpkm15[['Dis15 wild-type', 'Dis15 ssd1-']].mean(axis=1)
rpkm15_copy['avg al but dis15'] = rpkm15.loc[:, ~rpkm15.columns.isin(['Dis15 wild-type', 'Dis15 ssd1-'])].mean(axis=1)

# %%
rpkm15_copy
# Out:
#          Dis16 wild-type  Dis13 wild-type  Dis13 ssd1-  Dis1 wild-type  \
# Gene
# YOR246C        29.056974        42.653787    50.347576       34.467998
# YOR247W         9.496306         7.720600    18.052862       23.655910
# YOR255W        31.599893        31.140675    29.012372       35.780623
#
#          Dis4 ssd1-/ssd1-  Dis3 wild-type  Dis14 ssd1-  Dis5 wild-type  \
# Gene
# YOR246C         33.844482       33.262793    39.596767       52.188187
# YOR247W         21.237012       39.135016    22.298143       14.447413
# YOR255W         32.121932       39.462310    38.545075       36.420598
#
#          Dis1 ssd1-  Dis5 ssd1-  ...  Dis4 wild-type  Euploid ssd1-  \
# Gene                             ...
# YOR246C   57.763018   38.569919  ...       47.619815      30.610023
# YOR247W   11.617183   15.126355  ...       14.615643      20.007736
# YOR255W   31.628716   26.692504  ...       40.529160      36.315117
#
#          Dis15 wild-type  Euploid CEN15 wild-type  Dis12 wild-type  \
# Gene
# YOR246C        34.402037                40.536870        34.935549
# YOR247W        39.888783                17.805484        15.345150
# YOR255W        70.980672                25.007907        24.868101
#
#          Euploid ssd1-  Dis12 wild-type rDNA hemizygous clone #3  Dis15 ssd1-  \
# Gene
# YOR246C      31.065887                                 25.820366    62.192333
# YOR247W      14.831993                                  8.100987    19.512476
# YOR255W      24.036486                                 18.379658    51.648615
#
#          avg Dis15  avg al but dis15
# Gene
# YOR246C  64.314518         35.149529
# YOR247W  28.568110         15.328433
# YOR255W  58.682220         34.570987
#
# [3 rows x 51 columns]

# %% [markdown]
# Values are 2x higher in dis15 strains than in the other strains, so gap in alignement

# %% [markdown]
# # Mitochondria
# One gene really missing

# %%
cmito = missing[missing['Chromosome'] == 'mitoch']
gmito = list(cmito['Name'])
rpkm[rpkm.index.isin(gmito)]
# Out:
#        Dis16 wild-type  Dis13 wild-type  Dis13 ssd1-  Dis1 wild-type  \
# Gene
# Q0160              0.0              0.0          0.0             0.0
#
#        Dis4 ssd1-/ssd1-  Dis3 wild-type  Dis14 ssd1-  Dis5 wild-type  \
# Gene
# Q0160               0.0             0.0          0.0             0.0
#
#        Dis1 ssd1-  Dis5 ssd1-  ...  Euploid wild-type  Dis4 ssd1-/ssd1-  \
# Gene                           ...
# Q0160         0.0         0.0  ...                0.0               0.0
#
#        Dis4 wild-type  Euploid ssd1-  Dis15 wild-type  \
# Gene
# Q0160             0.0            0.0              0.0
#
#        Euploid CEN15 wild-type  Dis12 wild-type  Euploid ssd1-  \
# Gene
# Q0160                      0.0              0.0            0.0
#
#        Dis12 wild-type rDNA hemizygous clone #3  Dis15 ssd1-
# Gene
# Q0160                                       0.0          0.0
#
# [1 rows x 49 columns]
