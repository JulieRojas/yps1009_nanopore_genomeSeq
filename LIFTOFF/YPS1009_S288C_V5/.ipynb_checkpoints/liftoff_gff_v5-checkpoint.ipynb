# %%
# from BCBio.GFF import GFFExaminer

# %% [markdown]
# https://gffpandas.readthedocs.io/en/latest/tutorial.html

# %%
import gffpandas.gffpandas as gffpd
import pandas as pd
# Import Biopython tools for running local BLASTX
from Bio.Blast.Applications import NcbiblastnCommandline
from Bio import SeqIO

# %%
annotation = gffpd.read_gff3('YPS1009_S288C_v5_polished.gff')
annot_s288c = gffpd.read_gff3('saccharomyces_cerevisiae_R64-3.gff')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\gffpandas\gffpandas.py:32: DtypeWarning: Columns (1,2,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_table(self._gff_file, comment='#',

# %%
features = annotation.df['type'].value_counts().to_frame()
features = features.rename(columns = {'type': 'yps1009'})

# %%
features = features.join(annot_s288c.df['type'].value_counts().to_frame())
features = features.rename(columns={'type': 'S288C'})

# %%
features
# Out:
#                                     yps1009  S288C
# CDS                                    7164   7066
# gene                                   6691   6607
# mRNA                                   6691  11119
# ARS                                     554    543
# noncoding_exon                          512    489
# long_terminal_repeat                    361    384
# tRNA                                    323    299
# tRNA_gene                               323    299
# ARS_consensus_sequence                  199    196
# telomere                                 98     64
# transposable_element                     95     91
# transposable_element_gene                95     91
# region                                   82     78
# snoRNA                                   77     77
# snoRNA_gene                              77     77
# LTR_retrotransposon                      53     50
# plus_1_translational_frameshift          47     47
# telomeric_repeat                         42     31
# X_element                                35     32
# X_element_combinatorial_repeat           33     28
# centromere                               30     32
# pseudogene                               25     12
# five_prime_UTR_intron                    24     24
# ncRNA_gene                               23     23
# ncRNA                                    23     23
# rRNA_gene                                20     24
# rRNA                                     20     24
# chromosome                               17     17
# Y_prime_element                          17     19
# centromere_DNA_Element_II                15     16
# centromere_DNA_Element_III               15     16
# centromere_DNA_Element_I                 15     16
# blocked_reading_frame                    12     12
# origin_of_replication                    10      8
# external_transcribed_spacer_region        6      8
# uORF                                      6     11
# snRNA_gene                                6      6
# snRNA                                     6      6
# silent_mating_type_cassette_array         4      4
# internal_transcribed_spacer_region        4      8
# X_region                                  3      3
# Y_region                                  3      3
# Z1_region                                 3      3
# non_transcribed_region                    3      3
# intein_encoding_region                    2      2
# W_region                                  2      2
# mating_type_region                        2      2
# Z2_region                                 2      2
# telomerase_RNA                            1      1
# telomerase_RNA_gene                       1      1
# recombination_enhancer                    1      1

# %%
# find genes with major overlap (I only round the last digit of start and end position to zero, 
# so not perfect but will cover the biggest overlaps)
def overlap_feat(df):
    id_overlap = []
    dupl = {}
    for ind, row in df.iterrows():
        start = str(row['start'])
        start = start.replace(start[len(start) - 1:], '0')
        end = str(row['end'])
        end = end.replace(end[len(end) - 1:], '0')

        tmp = str(row['seq_id']) + start + end
        id_overlap.append(tmp)
        if tmp in dupl:
            dupl[tmp] += 1
        else:
            dupl[tmp] = 1
    df['overlap id'] = id_overlap
    filtered_dict = {k:v for (k,v) in dupl.items() if v > 1}
    print('Number of site annotated several time: ' + str(len(filtered_dict)))
    return df, filtered_dict

def drop_overlap(df, filtered_dict):
    df['sequence_ID'] = df['sequence_ID'].astype(float)
    ind = []
    for k in filtered_dict.keys():
        tmp = df[df['overlap id'] == k]
        ind.append(tmp.nsmallest(1,"sequence_ID").index[0])
    df.drop(index=ind, inplace=True)
    return df

# %%
# This code just convert the chromosome numbering to integer and remove mitochondrial genes.
def lat_to_arabic(DF):
    Latin_to_arabic = {'I': 1, 'II':2, 'III':3, 'IV':4, 'V':5, 'VI':6, 'VII':7, 'VIII':8, 'IX':9, 'X':10,
                      'XI':11, 'XII':12, 'XIII':13, 'XIV':14, 'XV':15, 'XVI':16, 'Mito': 'mitoch', 'MANY': 7}
    seq_id = DF['seq_id']
    ch = []
    contig = []
    for i in seq_id:
        chrom, cont = i.split('_')
        contig.append(cont)
        chrom = chrom.replace('chr', '')
        if '-' in chrom:
            chrom, e = chrom.split('-')
        ch.append(Latin_to_arabic[chrom])
    DF['Chromosome'] = ch
    DF['Contig'] = contig
    return DF

def lat_to_arabic_S288(df):
    # This code just convert the chromosome numbering to integer and remove mitochondrial genes.
    Latin_to_arabic = {'I': 1, 'II':2, 'III':3, 'IV':4, 'V':5, 'VI':6, 'VII':7, 'VIII':8, 'IX':9, 'X':10,
                      'XI':11, 'XII':12, 'XIII':13, 'XIV':14, 'XV':15, 'XVI':16, 'Mito': 'mitoch'}
    chLat = df['seq_id']
    ch = []
    for chrom in chLat:
        chrom = chrom.replace('chr', '')
        ch.append(Latin_to_arabic[chrom])
    df['Chromosome'] = ch
    return df

# %% [markdown]
# # ARS
# Actual number in s288c should be 352

# %%
ARS_df = annotation.filter_feature_of_type(['ARS'])
ARS_attr = ARS_df.attributes_to_columns()

# %%
ARS_s288c_df = annot_s288c.filter_feature_of_type(['ARS'])
ARS_s288c_attr = ARS_s288c_df.attributes_to_columns()

# %%
ARS_s288c_attr = ARS_s288c_attr[ARS_s288c_attr['dbxref'].notna()]
# Hurray, right number

# %%
ARS_attr = ARS_attr[ARS_attr['dbxref'].notna()]

# %%
ARS_attr, ARS_dupl = overlap_feat(ARS_attr)
# Out:
# Number of site annotated several time: 2

# %%
ARS_attr = drop_overlap(ARS_attr, ARS_dupl)

# %%
ARS_attr
# Out:
#                      seq_id   source type   start     end score strand phase  \
# 18      chrII-2_tig00004927  Liftoff  ARS   17490   18088     .      .     .
# 21      chrII-2_tig00004927  Liftoff  ARS   17496   18717     .      -     .
# 48     chrIII-2_tig00004935  Liftoff  ARS   11705   11883     .      .     .
# 111      chrIII_tig00004936  Liftoff  ARS   15042   15315     .      .     .
# 114      chrIII_tig00004936  Liftoff  ARS   15337   15680     .      .     .
# ...                     ...      ...  ...     ...     ...   ...    ...   ...
# 23613      chrX_tig00001098  Liftoff  ARS  596429  596946     .      .     .
# 23710      chrX_tig00001098  Liftoff  ARS  637949  638237     .      .     .
# 23757      chrX_tig00001098  Liftoff  ARS  667581  667688     .      .     .
# 23801      chrX_tig00001098  Liftoff  ARS  695435  695731     .      .     .
# 23859      chrX_tig00001098  Liftoff  ARS  720126  720729     .      .     .
#
#                                               attributes               Alias  \
# 18     ID=ARS1025;Name=ARS1025;Note=Autonomously%20Re...                None
# 21     ID=ARS400;Name=ARS400;Alias=ARSIV-1;Note=Auton...             ARSIV-1
# 48     ID=ARS301;Name=ARS301;gene=ARS301;Alias=ARS301...  ARS301,HML-E%20ARS
# 111    ID=ARS302;Name=ARS302;gene=ARS302;Alias=ARS302...  ARS302,HML-I%20ARS
# 114    ID=ARS303;Name=ARS303;gene=ARS303;Alias=ARS303...              ARS303
# ...                                                  ...                 ...
# 23613  ID=ARS1019;Name=ARS1019;Note=Autonomously%20Re...                None
# 23710  ID=ARS1020;Name=ARS1020;Alias=ARSX-654;Note=Au...            ARSX-654
# 23757  ID=ARS1021;Name=ARS1021;Alias=ARS121;Note=Auto...              ARS121
# 23801  ID=ARS1022;Name=ARS1022;Alias=ARSX-712;Note=Au...            ARSX-712
# 23859  ID=ARS1025_2;Name=ARS1025;Note=Autonomously%20...                None
#
#        ... copy_num_ID coverage           curie          dbxref  \
# 18     ...   ARS1025_0    0.990  SGD:S000028461  SGD:S000028461
# 21     ...    ARS400_0    0.963  SGD:S000121226  SGD:S000121226
# 48     ...    ARS301_0    0.711  SGD:S000028477  SGD:S000028477
# 111    ...    ARS302_0    0.996  SGD:S000028478  SGD:S000028478
# 114    ...    ARS303_0      1.0  SGD:S000028479  SGD:S000028479
# ...    ...         ...      ...             ...             ...
# 23613  ...   ARS1019_0    0.998  SGD:S000028456  SGD:S000028456
# 23710  ...   ARS1020_0      1.0  SGD:S000028457  SGD:S000028457
# 23757  ...   ARS1021_0      1.0  SGD:S000007553  SGD:S000007553
# 23801  ...   ARS1022_0      1.0  SGD:S000028458  SGD:S000028458
# 23859  ...   ARS1025_2    0.990  SGD:S000028461  SGD:S000028461
#
#                                                  display extra_copy_number  \
# 18                 Autonomously%20Replicating%20Sequence                 0
# 21                 Autonomously%20Replicating%20Sequence                 0
# 48     Inactive%20replication%20origin%20linked%20to%...                 0
# 111    Inactive%20replication%20origin%20linked%20to%...                 0
# 114    Autonomously%20Replicating%20Sequence%20on%20C...                 0
# ...                                                  ...               ...
# 23613              Autonomously%20Replicating%20Sequence                 0
# 23710              Autonomously%20Replicating%20Sequence                 0
# 23757              Autonomously%20Replicating%20Sequence                 0
# 23801              Autonomously%20Replicating%20Sequence                 0
# 23859              Autonomously%20Replicating%20Sequence                 2
#
#          gene low_identity sequence_ID                      overlap id
# 18       None         None       0.905   chrII-2_tig000049271749010000
# 21       None         None       0.890   chrII-2_tig000049271749018010
# 48     ARS301         None       0.670  chrIII-2_tig000049351170011880
# 111    ARS302         None       0.968    chrIII_tig000049361504010310
# 114    ARS303         None       0.969    chrIII_tig000049361533015680
# ...       ...          ...         ...                             ...
# 23613    None         None       0.990    chrX_tig00001098506420590940
# 23710    None         None       0.975    chrX_tig00001098637040638230
# 23757    None         None       0.953    chrX_tig00001098667580667600
# 23801    None         None       0.993    chrX_tig00001098690430695730
# 23859    None         None       0.889    chrX_tig00001098720120720720
#
# [358 rows x 24 columns]

# %%
ARS_attr = lat_to_arabic(ARS_attr)
ARS_s288c_attr = lat_to_arabic_S288(ARS_s288c_attr)

# %%
ARS_count = ARS_attr['Chromosome'].value_counts().to_frame()
ARS_count = ARS_count.rename(columns = {'Chromosome': 'yps1009 ARS'})
ARS_count_s = ARS_s288c_attr['Chromosome'].value_counts().to_frame()
ARS_count_s = ARS_count_s.rename(columns = {'Chromosome': 'S288C ARS'})
ARS_count = ARS_count_s.join(ARS_count)

# %%
ARS_count
# Out:
#     S288C ARS  yps1009 ARS
# 4          41           44
# 12         29           29
# 7          28           28
# 16         27           28
# 13         26           25
# 10         25           24
# 2          23           24
# 5          21           24
# 14         21           20
# 3          19           17
# 15         19           21
# 8          16           15
# 9          16           16
# 11         16           18
# 6          14           14
# 1          11           11

# %% [markdown]
# # Long terminal repeats
# 384 in s288c

# %%
ltr_df = annotation.filter_feature_of_type(['long_terminal_repeat'])
ltr_attr = ltr_df.attributes_to_columns()

ltr_s288c_df = annot_s288c.filter_feature_of_type(['long_terminal_repeat'])
ltr_s288c_attr = ltr_s288c_df.attributes_to_columns()

# %%
ltr_attr, ltr_dupl = overlap_feat(ltr_attr)
# Out:
# Number of site annotated several time: 28

# %%
ltr_attr = drop_overlap(ltr_attr, ltr_dupl)

# %%
ltr_attr = lat_to_arabic(ltr_attr)
ltr_s288c_attr = lat_to_arabic_S288(ltr_s288c_attr)

# %%
ltr_count = ltr_attr['Chromosome'].value_counts().to_frame()
ltr_count = ltr_count.rename(columns = {'Chromosome': 'yps1009 ltr'})
ltr_count_s = ltr_s288c_attr['Chromosome'].value_counts().to_frame()
ltr_count_s = ltr_count_s.rename(columns = {'Chromosome': 'S288C ltr'})
ltr_count = ltr_count_s.join(ltr_count)

# %%
ltr_count
# Out:
#     S288C ltr  yps1009 ltr
# 7          44           85
# 4          36           12
# 5          34           31
# 12         32           24
# 15         32           25
# 16         32           16
# 8          24           24
# 10         24           16
# 13         24           14
# 2          22           13
# 3          20           18
# 14         16            9
# 11         14           12
# 6          11           16
# 9          10            6
# 1           9           12

# %%
FEATS = ARS_count.join(ltr_count)

# %% [markdown]
# # ncRNA

# %%
ncRNA_df = annotation.filter_feature_of_type(['ncRNA'])
ncRNA_attr = ncRNA_df.attributes_to_columns()

ncRNA_s288c_df = annot_s288c.filter_feature_of_type(['ncRNA'])
ncRNA_s288c_attr = ncRNA_s288c_df.attributes_to_columns()

# %%
ncRNA_attr, ncRNA_dupl = overlap_feat(ncRNA_attr)
# Out:
# Number of site annotated several time: 1

# %%
ncRNA_attr[ncRNA_attr['overlap id'].isin(ncRNA_dupl)]
# Out:
#                    seq_id   source   type   start     end score strand phase  \
# 7919  chrVIII_tig00000017  Liftoff  ncRNA  201330  202036     .      +     .
# 7922  chrVIII_tig00000017  Liftoff  ncRNA  201330  202036     .      +     .
#
#                                              attributes               ID  \
# 7919  ID=YNCH0007W_ncRNA;Name=YNCH0007W_ncRNA;Parent...  YNCH0007W_ncRNA
# 7922  ID=YNCH0008W_ncRNA;Name=YNCH0008W_ncRNA;Parent...  YNCH0008W_ncRNA
#
#                  Name     Parent extra_copy_number  \
# 7919  YNCH0007W_ncRNA  YNCH0007W                 0
# 7922  YNCH0008W_ncRNA  YNCH0008W                 0
#
#                            overlap id
# 7919  chrVIII_tig00000017201330202030
# 7922  chrVIII_tig00000017201330202030

# %%
ncRNA_attr = lat_to_arabic(ncRNA_attr)
ncRNA_s288c_attr = lat_to_arabic_S288(ncRNA_s288c_attr)

# %%
# no sequence identity so let's just drop one
ncRNA_attr.drop(index=7922, inplace=True)

# %%
ncRNA_count = ncRNA_attr['Chromosome'].value_counts().to_frame()
ncRNA_count = ncRNA_count.rename(columns = {'Chromosome': 'yps1009 ncRNA'})
ncRNA_count_s = ncRNA_s288c_attr['Chromosome'].value_counts().to_frame()
ncRNA_count_s = ncRNA_count_s.rename(columns = {'Chromosome': 'S288C ncRNA'})
ncRNA_count = ncRNA_count_s.join(ncRNA_count)

# %%
FEATS = FEATS.join(ncRNA_count)

# %% [markdown]
# # rRNA

# %%
rRNA_df = annotation.filter_feature_of_type(['rRNA'])
rRNA_attr = rRNA_df.attributes_to_columns()

rRNA_s288c_df = annot_s288c.filter_feature_of_type(['rRNA'])
rRNA_s288c_attr = rRNA_s288c_df.attributes_to_columns()

rRNA_attr = lat_to_arabic(rRNA_attr)
rRNA_s288c_attr = lat_to_arabic_S288(rRNA_s288c_attr)

# %%
rRNA_attr, rRNA_dupl = overlap_feat(rRNA_attr)
# Out:
# Number of site annotated several time: 7

# %%
rRNA_attr = rRNA_attr.drop([13055, 14878, 14884, 14901, 14904, 14907, 14910])

# %%
rRNA_count = rRNA_attr['Chromosome'].value_counts().to_frame()
rRNA_count = rRNA_count.rename(columns = {'Chromosome': 'yps1009 rRNA'})
rRNA_count_s = rRNA_s288c_attr['Chromosome'].value_counts().to_frame()
rRNA_count_s = rRNA_count_s.rename(columns = {'Chromosome': 'S288C rRNA'})
rRNA_count = rRNA_count_s.join(rRNA_count)

# %%
 FEATS = FEATS.join(rRNA_count)

# %% [markdown]
# # snRNA

# %%
snRNA_df = annotation.filter_feature_of_type(['snRNA'])
snRNA_attr = snRNA_df.attributes_to_columns()

snRNA_s288c_df = annot_s288c.filter_feature_of_type(['snRNA'])
snRNA_s288c_attr = snRNA_s288c_df.attributes_to_columns()

snRNA_attr = lat_to_arabic(snRNA_attr)
snRNA_s288c_attr = lat_to_arabic_S288(snRNA_s288c_attr)

# %%
snRNA_attr, snRNA_dupl = overlap_feat(snRNA_attr)
# Out:
# Number of site annotated several time: 0

# %%
snRNA_count = snRNA_attr['Chromosome'].value_counts().to_frame()
snRNA_count = snRNA_count.rename(columns = {'Chromosome': 'yps1009 snRNA'})
snRNA_count_s = snRNA_s288c_attr['Chromosome'].value_counts().to_frame()
snRNA_count_s = snRNA_count_s.rename(columns = {'Chromosome': 'S288C snRNA'})
snRNA_count = snRNA_count_s.join(snRNA_count)

# %%
FEATS = FEATS.join(snRNA_count)

# %% [markdown]
# # Coding sequence

# %%
CDS_df = annotation.filter_feature_of_type(['CDS'])
CDS_attr = CDS_df.attributes_to_columns()

# %%
CDS_attr['Name short'] = CDS_attr['Name'].str.replace('_CDS', '')

# %% [markdown]
# # Centromere

# %%
CEN_df = annotation.filter_feature_of_type(['centromere'])
CEN_attr = CEN_df.attributes_to_columns()

# %%
CEN_attr = CEN_attr[CEN_attr['Alias'].notna()]
CEN_attr = CEN_attr.sort_values(by=['Alias'])

# %% [markdown]
# # Telomere

# %%
telomere_df = annotation.filter_feature_of_type(['telomere'])
telomere_attr = telomere_df.attributes_to_columns()

# %%
telomere_attr = telomere_attr[telomere_attr['Parent'].notna()]
telomere_attr = telomere_attr.sort_values(by=['ID', 'start'])

# %%
telomere_attr['lenght'] = telomere_attr['end'] - telomere_attr['start']

# %%
# messy, forget it for now
telomere_attr
# Out:
#                       seq_id   source      type    start      end score  \
# 12145       chrV_tig00000015  Liftoff  telomere   566679   567486     .
# 6770     chrVI-2_tig00004937  Liftoff  telomere    12572    13373     .
# 10765       chrV_tig00000015  Liftoff  telomere      407     7092     .
# 22440       chrX_tig00001098  Liftoff  telomere      235     1011     .
# 14849    chrXIII_tig00000018  Liftoff  telomere   467643   468731     .
# 5169       chrIX_tig00000023  Liftoff  telomere      215     1074     .
# 6043        chrI_tig00000033  Liftoff  telomere      176      984     .
# 6775    chrVII-2_tig00000038  Liftoff  telomere      219     1045     .
# 19201   chrXVI-2_tig00000040  Liftoff  telomere      162     1006     .
# 17476     chrXIV_tig00004929  Liftoff  telomere   730365   731164     .
# 768       chrIII_tig00004936  Liftoff  telomere   310839   311669     .
# 22435       chrX_tig00001098  Liftoff  telomere      125     1011     .
# 10780       chrV_tig00000015  Liftoff  telomere      464     7092     .
# 10775       chrV_tig00000015  Liftoff  telomere      423     7340     .
# 10755       chrV_tig00000015  Liftoff  telomere      335     7092     .
# 10846       chrV_tig00000015  Liftoff  telomere      991     7092     .
# 6027       chrIX_tig00000023  Liftoff  telomere   429036   429814     .
# 12221   chrXII-2_tig00004934  Liftoff  telomere      228     1008     .
# 13066   chrXII-3_tig00004933  Liftoff  telomere      243     1027     .
# 12216    chrXI-2_tig00004931  Liftoff  telomere    28704    29461     .
# 35      chrIII-2_tig00004935  Liftoff  telomere      273     1030     .
# 55        chrIII_tig00004936  Liftoff  telomere      257     1023     .
# 18671      chrXI_tig00004932  Liftoff  telomere   668361   669130     .
# 10759       chrV_tig00000015  Liftoff  telomere      335     7340     .
# 10744       chrV_tig00000015  Liftoff  telomere      242     7340     .
# 10717       chrV_tig00000015  Liftoff  telomere       94     7092     .
# 10725       chrV_tig00000015  Liftoff  telomere      200     7092     .
# 6032       chrIX_tig00000023  Liftoff  telomere   429036   429846     .
# 23868       chrX_tig00001098  Liftoff  telomere   720627   721423     .
# 10733       chrV_tig00000015  Liftoff  telomere      219     7092     .
# 30       chrII-2_tig00004927  Liftoff  telomere    17985    18806     .
# 10177     chrVII_tig00004928  Liftoff  telomere   807651   808483     .
# 2296       chrII_tig00000010  Liftoff  telomere   789625   790471     .
# 20939                 0         None            None        None    809
# 5154                  1         None            None        None    827
# 5164                  0         None            None        None    971
# 10729                 0         None            None        None   6888
# 10768                 0         None            None        None   6685
# 10737                 0         None            None        None   6862
# 16045                 0         None            None        None    898
# 10752                 0         None            None        None   6772
# 5159                  0         None            None        None   1069
# 10705                 1         None            None        None   1008
# 20933                 0         None            None        None    850
# 10748                 0         None            None        None   6832
# 10771                 0         None            None        None   6685
# 10762                 0         None            None        None   6603
#
# [49 rows x 23 columns]

# %% [markdown]
# ## Make df by features YPS1009

# %%
TE_df = annotation.filter_feature_of_type(['transposable_element_gene'])
sno_df = annotation.filter_feature_of_type(['snoRNA_gene'])
tRNA_df = annotation.filter_feature_of_type(['tRNA_gene'])
gene_df = annotation.filter_feature_of_type(['gene'])
LTR_retroP_df = annotation.filter_feature_of_type(['LTR_retrotransposon'])

# %%
gene_attr = gene_df.attributes_to_columns()
gene = gene_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'gene', 'low_identity', 'orf_classification',
       'partial_mapping', 'sequence_ID', 'valid_ORFs']]

# %%
gene_attr.columns
# Out:
# Index(['seq_id', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase',
#        'attributes', 'Alias', 'ID', 'Name', 'Note', 'Ontology_term',
#        'copy_num_ID', 'coverage', 'curie', 'dbxref', 'display',
#        'extra_copy_number', 'gene', 'low_identity', 'orf_classification',
#        'partial_mapping', 'sequence_ID', 'valid_ORFs'],
#       dtype='object')

# %%
gene_attr['valid_ORFs'].value_counts()
# so valid_ORFs in gene does count itself and I should look carefully at the 439 genes with no valid ORF
# Out:
# 1    6165
# 0     524
# Name: valid_ORFs, dtype: int64

# %%
# number of annotated genes without potential duplicates
# Doesn't works, we want duplicates
len(set(gene['Name']))
# Out:
# 6565

# %%
gene.shape
# Out:
# (6691, 21)

# %%
TE_attr = TE_df.attributes_to_columns()
sno_attr = sno_df.attributes_to_columns()
tRNA_attr = tRNA_df.attributes_to_columns()
LTR_retroP_attr = LTR_retroP_df.attributes_to_columns()

# %%
LTR_retroP_attr.columns
# Out:
# Index(['seq_id', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase',
#        'attributes', 'Alias', 'ID', 'Name', 'Note', 'copy_num_ID', 'coverage',
#        'curie', 'dbxref', 'display', 'extra_copy_number', 'low_identity',
#        'sequence_ID'],
#       dtype='object')

# %%
TE = TE_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'sequence_ID', 'valid_ORFs']]

sno = sno_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'gene', 'sequence_ID']]

tRNA = tRNA_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'gene', 'sequence_ID']]

LTR_retroP = LTR_retroP_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'sequence_ID']]

# %%
gene = lat_to_arabic(gene)
TE = lat_to_arabic(TE)
sno = lat_to_arabic(sno)
tRNA = lat_to_arabic(tRNA)
LTR_retroP = lat_to_arabic(LTR_retroP)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig

# %%
def clean20(DF):
    note = DF['Note']
    dis = DF['display']
    clean = []
    display = []
    for n in note:
        clean.append(n.replace('%20', ' '))
    for d in dis:
        display.append(str(d).replace('%20', ' '))
    DF['Note'] = clean
    DF['display'] = display
    return DF

# %%
gene = clean20(gene)
TE = clean20(TE)
sno = clean20(sno)
tRNA = clean20(tRNA)
LTR_retroP = clean20(LTR_retroP)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\741321415.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Note'] = clean
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\741321415.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['display'] = display

# %% [markdown]
# ## Df by attribute for S288C

# %%
TE_df_s288c = annot_s288c.filter_feature_of_type(['transposable_element_gene'])
sno_df_s288c = annot_s288c.filter_feature_of_type(['snoRNA_gene'])
tRNA_df_s288c = annot_s288c.filter_feature_of_type(['tRNA_gene'])
gene_df_s288c = annot_s288c.filter_feature_of_type(['gene'])
LTR_retroP_df_s288c = annot_s288c.filter_feature_of_type(['LTR_retrotransposon'])

# %%
gene_attr_s288c = gene_df_s288c.attributes_to_columns()
TE_attr_s288c = TE_df_s288c.attributes_to_columns()
sno_attr_s288c = sno_df_s288c.attributes_to_columns()
tRNA_attr_s288c = tRNA_df_s288c.attributes_to_columns()
LTR_retroP_attr_s288c = LTR_retroP_df_s288c.attributes_to_columns()

# %%
LTR_retroP_attr_s288c.columns
# Out:
# Index(['seq_id', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase',
#        'attributes', 'Alias', 'ID', 'Name', 'Note', 'curie', 'dbxref',
#        'display'],
#       dtype='object')

# %%
gene_s288c = gene_attr_s288c[['seq_id', 'start', 'end', 'Name', 'gene',  'Alias',  'Note', 'Ontology_term', 'strand', 'phase', 'curie',
        'orf_classification', 'display']]

TE_s288c = TE_attr_s288c[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
      'curie', 'display']]

sno_s288c = sno_attr_s288c[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
      'curie', 'display']]

tRNA_s288c = tRNA_attr_s288c[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
      'curie', 'display']]

LTR_retroP_s288c = LTR_retroP_attr_s288c[['seq_id', 'start', 'end',  'ID', 'Name',  'Alias', 'score', 'strand', 'phase',
       'attributes', 'Note', 'curie', 'display']]

# %%
gene_s288c = lat_to_arabic_S288(gene_s288c)
TE_s288c = lat_to_arabic_S288(TE_s288c)
sno_s288c = lat_to_arabic_S288(sno_s288c)
tRNA_s288c = lat_to_arabic_S288(tRNA_s288c)
LTR_retroP_s288c = lat_to_arabic_S288(LTR_retroP_s288c)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2888190848.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Chromosome'] = ch

# %%
gene_s288c = clean20(gene_s288c)
TE_s288c = clean20(TE_s288c)
sno_s288c = clean20(sno_s288c)
tRNA_s288c = clean20(tRNA_s288c)
LTR_retroP_s288c = clean20(LTR_retroP_s288c)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\741321415.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Note'] = clean
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\741321415.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['display'] = display

# %% [markdown]
# # TE
#
# ### IMPORTANT:
#
# There are several TE mapped to the exact same location. Probably because map to 2 genes that have a very similar sequence!
# That's bad, I need to remove them. DO MANUALLY. --> Only 17 unique TE found!!!!

# %%
TE.to_excel('TE_liftoff_v5_yps1009.xlsx')

# %% [markdown]
# ## LTR Retrotransposons

# %%
LTR_RP_count = LTR_retroP['Chromosome'].value_counts().to_frame()
LTR_RP_count = LTR_RP_count.rename(columns = {'Chromosome' : 'yps1009 LTR retrotransposon'})
LTR_RP_count_s288 = LTR_retroP_s288c['Chromosome'].value_counts().to_frame()
LTR_RP_count_s288 = LTR_RP_count_s288.rename(columns= {'Chromosome': 'S288C LTR retroposon'})
LTR_RP_count = LTR_RP_count_s288.join(LTR_RP_count)

# %% [markdown]
# # IMPORTANT
# Overlapping features, to filter manually

# %%
LTR_retroP.sort_values(by=['Chromosome', 'start'])
# Out:
#                      seq_id    start      end       Name Alias  \
# 6374       chrI_tig00000033   177542   183707  YDRWTy2-3   Ty2
# 6375       chrI_tig00000033   177544   183707  YGRWTy2-2   Ty2
# 6376       chrI_tig00000033   177545   183707  YDRWTy2-2   Ty2
# 37     chrIII-2_tig00004935      423     4934  YCLWTy5-1   Ty5
# 57       chrIII_tig00004936      790     4554  YCLWTy5-1   Ty5
# 407      chrIII_tig00004936   136337   142463  YBLWTy2-1   Ty2
# 4750      chrIV_tig00000001  1297667  1303627  YLRWTy2-1   Ty2
# 4751      chrIV_tig00000001  1297674  1309617  YNLWTy1-2   Ty1
# 4752      chrIV_tig00000001  1297677  1303627  YDRCTy2-1   Ty2
# 4753      chrIV_tig00000001  1297677  1304036  YFLWTy2-1   Ty2
# 4754      chrIV_tig00000001  1297677  1303630  YNLCTy2-1   Ty2
# 4755      chrIV_tig00000001  1297677  1303627  YORWTy2-2   Ty2
# 4806      chrIV_tig00000001  1303049  1309617  YJRWTy1-1   Ty1
# 4808      chrIV_tig00000001  1303305  1309617  YPLWTy1-1   Ty1
# 12092      chrV_tig00000015   543496   548928  YILWTy3-1   Ty3
# 12097      chrV_tig00000015   543497   548928  YGRWTy3-1   Ty3
# 6975   chrVII-2_tig00000038   106301   112481  YERCTy1-1   Ty1
# 6980   chrVII-2_tig00000038   106477   112460  YMRCTy1-4   Ty1
# 6981   chrVII-2_tig00000038   106488   112460  YDRCTy1-3   Ty1
# 6982   chrVII-2_tig00000038   106565   112460  YDRCTy1-1   Ty1
# 6984   chrVII-2_tig00000038   106565   112485  YPRCTy1-2   Ty1
# 6986   chrVII-2_tig00000038   106566   112460  YBRWTy1-2   Ty1
# 6987   chrVII-2_tig00000038   106567   112460  YPRWTy1-3   Ty1
# 6989   chrVII-2_tig00000038   106569   112460  YDRWTy1-4   Ty1
# 6990   chrVII-2_tig00000038   106569   112460  YGRCTy1-3   Ty1
# 6991   chrVII-2_tig00000038   106569   112460  YHRCTy1-1   Ty1
# 6992   chrVII-2_tig00000038   106569   112459  YMLWTy1-2   Ty1
# 6995   chrVII-2_tig00000038   106569   112460  YORWTy1-2   Ty1
# 6996   chrVII-2_tig00000038   106570   112480  YARCTy1-1   Ty1
# 6998   chrVII-2_tig00000038   106570   112481  YDRWTy1-5   Ty1
ty1 element%2C LTR retrotransposon of the Copi...                 0
# 21161  Ty2 element%2C LTR retrotransposon of the Copi...                 0
# 21162  Ty2 element%2C LTR retrotransposon of the Copi...                 0
# 21359  Ty1 element%2C LTR retrotransposon of the Copi...                 0
# 19303  Ty2 element%2C LTR retrotransposon of the Copi...                 0
#
#       sequence_ID  Chromosome       Contig
# 6374        0.835           1  tig00000033
# 6375        0.834           1  tig00000033
# 6376        0.833           1  tig00000033
# 37          0.948           3  tig00004935
# 57          0.954           3  tig00004936
# 407         0.823           3  tig00004936
# 4750        0.812           4  tig00000001
# 4751        0.426           4  tig00000001
# 4752        0.812           4  tig00000001
# 4753        0.826           4  tig00000001
# 4754        0.913           4  tig00000001
# 4755        0.810           4  tig00000001
# 4806        0.757           4  tig00000001
# 4808        0.808           4  tig00000001
# 12092       0.827           5  tig00000015
# 12097       0.818           5  tig00000015
# 6975        0.807           7  tig00000038
# 6980        0.790           7  tig00000038
# 6981        0.733           7  tig00000038
# 6982        0.757           7  tig00000038
# 6984        0.761           7  tig00000038
# 6986        0.792           7  tig00000038
# 6987        0.776           7  tig00000038
# 6989        0.776           7  tig00000038
# 6990        0.793           7  tig00000038
# 6991        0.769           7  tig00000038
# 6992        0.771           7  tig00000038
# 6995        0.787           7  tig00000038
# 6996        0.769           7  tig00000038
# 6998        0.766           7  tig00000038
# 7001        0.759           7  tig00000038
# 7002        0.793           7  tig00000038
# 7004        0.787           7  tig00000038
# 7006        0.772           7  tig00000038
# 7008        0.763           7  tig00000038
# 7010        0.778           7  tig00000038
# 7011        0.814           7  tig00000038
# 7013        0.777           7  tig00000038
# 7015        0.779           7  tig00000038
# 7397        0.821           7  tig00000038
# 7399        0.819           7  tig00000038
# 7401        0.821           7  tig00000038
# 8302        0.815           8  tig00000017
# 12205       0.945          11  tig00004931
# 18660       0.945          11  tig00004932
# 12925       0.826          12  tig00004934
# 12926       0.825          12  tig00004934
# 12927       0.755          12  tig00004934
# 12928       0.791          12  tig00004934
# 21161       0.813          15  tig00000007
# 21162       0.751          15  tig00000007
# 21359       0.793          15  tig00000007
# 19303       0.843          16  tig00000040

# %%
LTR_retroP.to_excel('Liftoff_LTR_retrop.xlsx')

# %%
LTR_retroP_F, LTR_dic = overlap_feat(LTR_retroP)
# Out:
# Number of site annotated several time: 10
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\33627071.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overlap id'] = id_overlap

# %%
LTR_retroP_F = drop_overlap(LTR_retroP_F, LTR_dic)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\33627071.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sequence_ID'] = df['sequence_ID'].astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\33627071.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index=ind, inplace=True)

# %% [markdown]
# How do I reconciliate these results? it somehow feels not right
# compare to the TE Ultimate results. See TE_annotation jupyter notebook

# %%
filteredRetroP = pd.read_excel('Liftoff_LTR_retrop_filtered.xlsx', index_col=0)

# %%
filteredRetroP.shape
# Out:
# (16, 13)

# %%
RetroP_count = filteredRetroP['Chromosome'].value_counts().to_frame()
RetroP_count = RetroP_count.rename(columns = {'Chromosome': 'yps1009 RetroP'})
RetroP_count_s = LTR_retroP_s288c['Chromosome'].value_counts().to_frame()
RetroP_count_s = RetroP_count_s.rename(columns = {'Chromosome': 'S288C RetroP'})

# %%
RetroP_count = pd.concat((RetroP_count_s, RetroP_count), axis=1)

# %%
RetroP_count.sort_index()
# Out:
#     S288C RetroP  yps1009 RetroP
# 1            1.0             1.0
# 2            3.0             NaN
# 3            2.0             3.0
# 4            8.0             2.0
# 5            2.0             1.0
# 6            1.0             NaN
# 7            6.0             2.0
# 8            2.0             1.0
# 9            1.0             NaN
# 10           3.0             NaN
# 11           NaN             2.0
# 12           5.0             1.0
# 13           4.0             NaN
# 14           3.0             NaN
# 15           4.0             2.0
# 16           5.0             1.0

# %%
RetroP_count.sum()
# Out:
# S288C RetroP      50.0
# yps1009 RetroP    16.0
# dtype: float64

# %% [markdown]
# # Compared to the filtered ReasonaTE

# %%
Reasona = pd.read_csv('ReasonaTE_filteredblast.txt', sep = '\t')

# %%
Reasona_count = Reasona['chromosome'].value_counts().to_frame()

# %%
Reasona_count.rename(columns={'chromosome': 'ReasonaTE yps RetroP'}, inplace=True)

# %%
RetroP_count = RetroP_count.join(Reasona_count)

# %%
RetroP_count
# Out:
#     S288C RetroP  yps1009 RetroP  ReasonaTE yps RetroP
# 4            8.0             2.0                   4.0
# 7            6.0             2.0                   2.0
# 12           5.0             1.0                   1.0
# 16           5.0             1.0                   1.0
# 13           4.0             NaN                   NaN
# 15           4.0             2.0                   2.0
# 2            3.0             NaN                   1.0
# 10           3.0             NaN                   1.0
# 14           3.0             NaN                   NaN
# 3            2.0             3.0                   1.0
# 5            2.0             1.0                   2.0
# 8            2.0             1.0                   1.0
# 1            1.0             1.0                   2.0
# 6            1.0             NaN                   2.0
# 9            1.0             NaN                   NaN
# 11           NaN             2.0                   NaN

# %%
RetroP_count.sum()
# Out:
# S288C RetroP            50.0
# yps1009 RetroP          16.0
# ReasonaTE yps RetroP    20.0
# dtype: float64

# %%
combiTE = pd.read_csv('TE_liftoffv5_reasonaTE_combined.txt', sep='\t')

# %%
combi_count = combiTE['chromosome'].value_counts().to_frame()

# %%
combi_count.rename(columns={'chromosome': 'Reasona+Liftoff'}, inplace=True)

# %%
RetroP_count = RetroP_count.join(combi_count)

# %%
RetroP_count.sort_index()
# Out:
#     S288C RetroP  yps1009 RetroP  ReasonaTE yps RetroP  Reasona+Liftoff
# 1            1.0             1.0                   2.0              2.0
# 2            3.0             NaN                   1.0              1.0
# 3            2.0             3.0                   1.0              3.0
# 4            8.0             2.0                   4.0              4.0
# 5            2.0             1.0                   2.0              2.0
# 6            1.0             NaN                   2.0              2.0
# 7            6.0             2.0                   2.0              2.0
# 8            2.0             1.0                   1.0              1.0
# 9            1.0             NaN                   NaN              NaN
# 10           3.0             NaN                   1.0              1.0
# 11           NaN             2.0                   NaN              2.0
# 12           5.0             1.0                   1.0              1.0
# 13           4.0             NaN                   NaN              NaN
# 14           3.0             NaN                   NaN              NaN
# 15           4.0             2.0                   2.0              2.0
# 16           5.0             1.0                   1.0              1.0

# %%
FEATS = FEATS.join(RetroP_count[['Reasona+Liftoff']])
FEATS = FEATS.rename(columns={'Reasona+Liftoff': 'yps1009 LTR RetroP'})

# %%
FEATS.sum()
# Out:
# S288C ARS             352.0
# yps1009 ARS           358.0
# S288C ltr             384.0
# yps1009 ltr           333.0
# S288C ncRNA            22.0
# yps1009 ncRNA          21.0
# S288C snRNA             6.0
# yps1009 snRNA           6.0
# yps1009 LTR RetroP     24.0
# dtype: float64

# %% [markdown]
# # snoRNA

# %%
sno, sno_dupl = overlap_feat(sno)
# Out:
# Number of site annotated several time: 0
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\33627071.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overlap id'] = id_overlap

# %%
sno_count = sno['Chromosome'].value_counts().to_frame()
sno_count = sno_count.rename(columns = {'Chromosome': 'yps1009 snoRNA'})
sno_count_s = sno_s288c['Chromosome'].value_counts().to_frame()
sno_count_s = sno_count_s.rename(columns = {'Chromosome': 'S288C snoRNA'})
sno_count = sno_count_s.join(sno_count)

# %%
sno_count.to_excel('snoRNA_count_v5.xlsx')

# %%
FEATS = FEATS.join(sno_count)

# %% [markdown]
# # tRNA

# %%
tRNA, dupl_tRNA = overlap_feat(tRNA)
# Out:
# Number of site annotated several time: 21
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\33627071.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overlap id'] = id_overlap

# %%
tRNA = drop_overlap(tRNA, dupl_tRNA)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\33627071.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sequence_ID'] = df['sequence_ID'].astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\33627071.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index=ind, inplace=True)

# %%
tRNA.shape
# Out:
# (302, 20)

# %%
tRNA['extra_copy_number'].value_counts()
# Out:
# 0    278
# 1     24
# Name: extra_copy_number, dtype: int64

# %%
tRNA_count = tRNA['Chromosome'].value_counts().to_frame()
tRNA_count = tRNA_count.rename(columns = {'Chromosome': 'yps1009 tRNA'})
tRNA_count_s = tRNA_s288c['Chromosome'].value_counts().to_frame()
tRNA_count_s = tRNA_count_s.rename(columns = {'Chromosome': 'S288C tRNA'})
tRNA_count = tRNA_count_s.join(tRNA_count)

# %%
tRNA_count.sum()
# Out:
# S288C tRNA      299
# yps1009 tRNA    302
# dtype: int64

# %%
tRNA_count.to_excel('tRNA_count_v5.xlsx')

# %%
FEATS = FEATS.join(tRNA_count)

# %% [markdown]
# # GENE

# %%
# First removed ORF that were assigned to 2 different genes,
# keep the highest identity 
gene, gene_dic = overlap_feat(gene)
# Out:
# Number of site annotated several time: 56
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\33627071.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['overlap id'] = id_overlap

# %%
gene = drop_overlap(gene, gene_dic)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\33627071.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sequence_ID'] = df['sequence_ID'].astype(float)
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\33627071.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index=ind, inplace=True)

# %%
gene['orf_classification'].value_counts()
# Out:
# Verified           5217
# Uncharacterized     717
# Dubious             699
# Name: orf_classification, dtype: int64

# %%
dubious = gene[gene['orf_classification'] == 'Dubious']
dubious['valid_ORFs'].value_counts()
# Out:
# 1    511
# 0    188
# Name: valid_ORFs, dtype: int64

# %%
uncharacterized = gene[gene['orf_classification'] == 'Uncharacterized']
uncharacterized['valid_ORFs'].value_counts()
# Out:
# 1    552
# 0    165
# Name: valid_ORFs, dtype: int64

# %%
gene_valid = gene[gene['valid_ORFs'] == '1']
gene_unvalid = gene[gene['valid_ORFs'] == '0']

gene_valid_count = gene_valid['Chromosome'].value_counts().to_frame()
gene_valid_count = gene_valid_count.rename(columns={'Chromosome': 'Number valid genes'})
gene_unvalid_count = gene_unvalid['Chromosome'].value_counts().to_frame()
gene_unvalid_count = gene_unvalid_count.rename(columns={'Chromosome': 'Number unvalid genes'})

# %%
unval_dic = {}
for ind, row in gene_unvalid.iterrows():
    if row['Chromosome'] in unval_dic:
        unval_dic[row['Chromosome']] = unval_dic[row['Chromosome']] + [row['Name']]
    else:
        unval_dic[row['Chromosome']] = [row['Name']]
        
gene_sum = gene_valid_count.join(gene_unvalid_count)
tmp = []
for ind in gene_sum.index:
    tmp.append(unval_dic[ind])
gene_sum['unvalid genes'] = tmp

# %%
# summing what are the missings genes on chromosome and if moved to other chromosomes
missed = []
moved = []
count_miss = []
count_move = []
for Ch in gene_sum.index:
    s288 = gene_s288c[gene_s288c['Chromosome'] == Ch]
    yps = gene[gene['Chromosome'] == Ch]
    tmp = list(set(s288['Name']) - set(yps['Name']))
    miss = []
    mov = []
    others = gene[gene['Chromosome'] != Ch]
    for g in tmp:
        search = others[others['Name'] == g]
        if search.shape[0] >= 1:
            mov.append((g, list(search['Chromosome']), list(search['valid_ORFs'])))
        else:
            miss.append(g)  
    moved.append(mov)
    missed.append(miss)
    count_miss.append(len(miss))
    count_move.append(len(mov))

# %%
gene_sum['Number of missing genes'] = count_miss
gene_sum['Missing genes'] = missed
gene_sum['Number of moved genes'] = count_move
gene_sum['Moved genes, new chromosome(s), orf validity'] = moved

# %%
flat_list = [item for sublist in missed for item in sublist]
missing_genes = gene_s288c[gene_s288c['Name'].isin(flat_list)]
missing_genes.to_excel('missing_genes_v5.xlsx')

# %%
# Blast
ids = []
seq = []
for seq_record in SeqIO.parse("fasta_file/orf_coding_all_R64-3-1_20210421.fasta", "fasta"):
    ids.append(str(seq_record.id))
    seq.append(str(seq_record.seq))

# %%
for g in flat_list:
    name = g + '.txt'
    with open(name , "w") as file:
        file.write('> ' + g + '\n')
        file.write(seq[ids.index(g)])
    outfile = 'Blast_results/' + g + '.tab'
    cmd_blastn = NcbiblastnCommandline(query= name, out= outfile, evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')
    stdout, stderr = cmd_blastn()
    #print("STDOUT: %s" % stdout)
    #print("STDERR: %s" % stderr)

# %%
# Used to be 42 missing genes, but after removing genes mapped to the same ORF, that's more
# Meaning that the 47 extra missing are copies of genes mapped and can therefore be ignored.
len(flat_list)
# Out:
# 89

# %% [markdown]
# # Verified ORF

# %%
verified = gene[gene['orf_classification'] == 'Verified']

# %%
verified['valid_ORFs'].value_counts()
# Out:
# 1    5060
# 0     157
# Name: valid_ORFs, dtype: int64

# %%
verified_s288c = gene_s288c[gene_s288c['orf_classification'] == 'Verified']

# %%
verified_s288c.shape
# Out:
# (5216, 14)

# %%
verified_valid = verified[verified['valid_ORFs'] == '1']
verified_unvalid = verified[verified['valid_ORFs'] == '0']

verified_valid_count = verified_valid['Chromosome'].value_counts().to_frame()
verified_valid_count = verified_valid_count.rename(columns={'Chromosome': 'Number valid genes'})
verified_unvalid_count = verified_unvalid['Chromosome'].value_counts().to_frame()
verified_unvalid_count = verified_unvalid_count.rename(columns={'Chromosome': 'Number unvalid genes'})

# %%
unval_dic = {}
for ind, row in verified_unvalid.iterrows():
    if row['Chromosome'] in unval_dic:
        unval_dic[row['Chromosome']] = unval_dic[row['Chromosome']] + [row['Name']]
    else:
        unval_dic[row['Chromosome']] = [row['Name']]

# %%
verified_sum = verified_valid_count.join(verified_unvalid_count)

# %%
tmp = []
for ind in verified_sum.index:
    tmp.append(unval_dic[ind])

# %%
verified_sum['unvalid genes'] = tmp

# %%
missed = []
moved = []
count_miss = []
count_move = []
for Ch in verified_sum.index:
    s288 = verified_s288c[verified_s288c['Chromosome'] == Ch]
    yps = verified[verified['Chromosome'] == Ch]
    tmp = list(set(s288['Name']) - set(yps['Name']))
    miss = []
    mov = []
    others = verified[verified['Chromosome'] != Ch]
    for g in tmp:
        search = others[others['Name'] == g]
        if search.shape[0] >= 1:
            mov.append((g, list(search['Chromosome']), list(search['valid_ORFs'])))
        else:
            miss.append(g)  
    moved.append(mov)
    missed.append(miss)
    count_miss.append(len(miss))
    count_move.append(len(mov))

# %%
verified_sum['Number of missing genes'] = count_miss
verified_sum['Missing genes'] = missed
verified_sum['Number of moved genes'] = count_move
verified_sum['Moved genes, new chromosome(s), orf validity'] = moved

# %%
verified_sum.to_excel('Liftoff_v5_verified_genes_summary.xlsx')

# %% [markdown]
# # Verified missing genes dataset

# %%
flat_list = [item for sublist in missed for item in sublist]

# %%
missing_genes = verified_s288c[verified_s288c['Name'].isin(flat_list)]

# %%
missing_genes.shape
# Out:
# (50, 14)

# %%
missing_genes.to_excel('missing_verified_genes_v5.xlsx')

# %% [markdown]
# # Duplicated genes

# %%
# Many duplicated genes in this version
gene['extra_copy_number'].value_counts()
# Out:
# 0    6507
# 1      91
# 2      19
# 3      10
# 4       3
# 5       2
# 6       1
# Name: extra_copy_number, dtype: int64

# %%
gene[gene['extra_copy_number'] > '1']
# Out:
#                       seq_id   start     end       Name  \
# 9        chrII-2_tig00004927   14242   14700    YGR293C
# 39      chrIII-2_tig00004935    1323    2063    YCL076W
# 45      chrIII-2_tig00004935    6426    8271    YCL073C
# 59        chrIII_tig00004936    1316    2055    YCL076W
# 770       chrIII_tig00004936  310848  311102    YNL337W
# 2290       chrII_tig00000010  789332  789467  YHL048C-A
# 2313       chrIV_tig00000001    1219    1356  YHL048C-A
# 5183       chrIX_tig00000023    3329    3525  YCR102W-A
# 6045        chrI_tig00000033     676     975    YDR543C
# 6506        chrI_tig00000033  238815  239136    YAL069W
# 6778    chrVII-2_tig00000038     737    1036    YDR543C
# 8550     chrVIII_tig00000017  522253  522633  YAL064W-B
# 10168     chrVII_tig00004928  805604  806749    YGR295C
# 10171     chrVII_tig00004928  807356  807492  YHL048C-A
# 10179     chrVII_tig00004928  807660  807956  YER188C-A
# 10707      chrVI_tig00004938  298356  298655    YDR543C
# 12156     chrX-2_tig00001099     642     835    YCR108C
# 12167     chrX-2_tig00001099    4754    5859    YCR102C
# 12170     chrX-2_tig00001099    7160   11768    YJL222W
# 12174     chrX-2_tig00001099   12417   14186    YIL172C
# 12202    chrXI-2_tig00004931   21483   23330    YCL073C
# 12223   chrXII-2_tig00004934     699     999    YDR543C
# ATP8/Q0080: Subunit 8 of the F0 sector of mitochondrial F1F0 ATP synthase; encoded on the mitochondrial genome; ATP8 and ATP6 mRNAs are not translated in the absence of the F1 sector of ATPase
#
# OLI1/Q0130: F0-ATP synthase subunit c (ATPase-associated proteolipid); encoded on the mitochondrial genome; mutation confers oligomycin resistance; expression is specifically dependent on the nuclear genes AEP1 and AEP2 1 2 3 4
# Name Description
# OLIgomycin resistance 1
#
# Both on mitochondria so not that relevant to my project.
#
# PAU9/YBL108C-A: Protein of unknown function; member of the seripauperin multigene family encoded mainly in subtelomeric regions; SWAT-GFP and mCherry fusion proteins localize to the endoplasmic reticulum and vacuole respectively
#
# YHR213W-A: Putative protein of unknown function; identified by gene-trapping, microarray-based expression analysis, and genome-wide homology searching

# %% [markdown]
# # Analyse unvalid genes

# %% [markdown]
# 6 partial mapping genes:
#     YDL227C near telomere
#     YMR106C middle of chromosome arm
#     YNL322C near telomere and missing genes, suggesting GAP but could also be a fragment deletion.
#     YOR244W middle of chromosome arm
#     YOR245C middle of chromosome arm

# %% [markdown]
# ### merge mRNA and gene data to get information on the type of issue in ORF

# %%
mRNA_df = annotation.filter_feature_of_type(['mRNA'])
mRNA_attr = mRNA_df.attributes_to_columns()
mRNA_attr.columns
# Out:
# Index(['seq_id', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase',
#        'attributes', 'ID', 'Name', 'Parent', 'conditions', 'dbxref',
#        'extra_copy_number', 'inframe_stop_codon', 'matches_ref_protein',
#        'missing_start_codon', 'missing_stop_codon', 'transcript_id',
#        'valid_ORF'],
#       dtype='object')

# %%
mRNA = mRNA_attr[['seq_id', 'start', 'end', 'ID', 'Name', 'Parent',
                  'conditions', 'extra_copy_number', 'inframe_stop_codon', 
                  'matches_ref_protein', 'missing_start_codon', 'missing_stop_codon', 
                  'transcript_id', 'valid_ORF']]

# %%
gene_attr.columns
# Out:
# Index(['seq_id', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase',
#        'attributes', 'Alias', 'ID', 'Name', 'Note', 'Ontology_term',
#        'copy_num_ID', 'coverage', 'curie', 'dbxref', 'display',
#        'extra_copy_number', 'gene', 'low_identity', 'orf_classification',
#        'partial_mapping', 'sequence_ID', 'valid_ORFs'],
#       dtype='object')

# %%
gene2 = gene_attr[['seq_id', 'start', 'end',
       'Alias', 'ID', 'Name', 'copy_num_ID', 'coverage', 'display',
       'extra_copy_number', 'gene', 'low_identity', 'orf_classification',
       'partial_mapping', 'sequence_ID', 'valid_ORFs']]

# %%
gene2.head()
# Out:
#                  seq_id  start    end  \
# 0   chrII-2_tig00004927   8297  10119
# 3   chrII-2_tig00004927  10675  10894
# 6   chrII-2_tig00004927  10985  12717
# 9   chrII-2_tig00004927  14242  14700
# 12  chrII-2_tig00004927  14660  15022
#
#                                          Alias           ID       Name  \
# 0          MAL31,MAL3T,MALT,maltose%20permease    YBR298C_1    YBR298C
# 3                                         None  YBR298C-A_1  YBR298C-A
# 6   MAL32,MAL3S,MALS,alpha-glucosidase%20MAL32    YBR299W_1    YBR299W
# 9                                         None    YGR293C_2    YGR293C
# 12                  PAU12,seripauperin%20PAU12    YGR294W_1    YGR294W
#
#     copy_num_ID coverage                                       display  \
# 0     YBR298C_1    0.986                            Maltose%20permease
# 3   YBR298C-A_1    0.990  Putative%20protein%20of%20unknown%20function
# 6     YBR299W_1    0.986           Maltase%20%28alpha-D-glucosidase%29
# 9     YGR293C_2    0.993              Dubious%20open%20reading%20frame
# 12    YGR294W_1      1.0             Protein%20of%20unknown%20function
#
#    extra_copy_number   gene low_identity orf_classification partial_mapping  \
# 0                  1  MAL31         None           Verified            None
# 3                  1   None         None    Uncharacterized            None
# 6                  1  MAL32         None           Verified            None
# 9                  2   None         None            Dubious            None
# 12                 1  PAU12         None           Verified            None
#
#    sequence_ID valid_ORFs
# 0        0.946          0
# 3        0.981          0
# 6        0.981          0
# 9        0.989          0
# 12       0.983          1

# %%
mRNA.head()
# Out:
#                  seq_id  start    end                ID            Name  \
# 1   chrII-2_tig00004927   8297  10119   YBR298C_id001_1   YBR298C_id001
# 4   chrII-2_tig00004927  10675  10894  YBR298C-A_mRNA_1  YBR298C-A_mRNA
# 7   chrII-2_tig00004927  10985  12717   YBR299W_id001_1   YBR299W_id001
# 10  chrII-2_tig00004927  14242  14700    YGR293C_mRNA_2    YGR293C_mRNA
# 13  chrII-2_tig00004927  14660  15022   YGR294W_id001_1   YGR294W_id001
#
#          Parent conditions extra_copy_number inframe_stop_codon  \
# 1     YBR298C_1        GAL                 1               None
# 4   YBR298C-A_1       None                 1               None
# 7     YBR299W_1        GAL                 1               None
# 10    YGR293C_2       None                 2               True
# 13    YGR294W_1        GAL                 1               None
#
#    matches_ref_protein missing_start_codon missing_stop_codon  \
# 1                False                None               True
# 4                False                None               True
# 7                False                None               True
# 10               False                None               None
# 13                True                None               None
#
#               transcript_id valid_ORF
# 1          SGD:S000288108_1     False
# 4   RefSeq:NM_001184588.1_1     False
# 7          SGD:S000288109_1     False
# 10                     None     False
# 13         SGD:S000289696_1      True

# %%
gene_mRNA = pd.merge(gene2, mRNA,  how='right', left_on='ID', right_on = 'Parent')

# %%
gene_mRNA['valid_ORF'].value_counts()
# Out:
# True     6167
# False     524
# Name: valid_ORF, dtype: int64

# %% [markdown]
# ## Inframe stop codon analysis

# %%
inframe_stop = gene_mRNA[gene_mRNA['inframe_stop_codon'] == 'True']
inframe_g = inframe_stop['Name_x']
inframe_288c = gene_s288c[gene_attr_s288c['Name'].isin(inframe_g)]
inframe_288c['lenght'] = inframe_288c['end'] - inframe_288c['start']
inframe_stop['lenght'] = inframe_stop['end_x'] - inframe_stop['start_x']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\4266080126.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inframe_288c['lenght'] = inframe_288c['end'] - inframe_288c['start']
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\4266080126.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inframe_stop['lenght'] = inframe_stop['end_x'] - inframe_stop['start_x']

# %%
inframe_stop = inframe_stop[['Name_x','copy_num_ID', 'coverage', 'lenght', 'orf_classification']]
inframe_288c = inframe_288c[['Name', 'lenght']]

inframes_comp = pd.merge(inframe_288c, inframe_stop,  how='right', left_on='Name', right_on = 'Name_x')
inframes_comp['diff'] = inframes_comp['lenght_x'] - inframes_comp['lenght_y']

inframes_comp = inframes_comp.sort_values(by='diff')
inframes_comp = inframes_comp[['Name', 'lenght_x', 'lenght_y', 'diff']]
inframes_comp.rename(columns = {'lenght_x': 'length s288c gene', 'lenght_y': 'length yps gene'}, inplace = True)
inframes_comp.to_excel('inframes.xlsx')

# %%
inframes_comp
# Out:
#        Name  length s288c gene  length yps gene    diff
# 52  YKR102W             3509.0             4118  -609.0
# 83  YPR012W              254.0              281   -27.0
# 6   YBR134W              401.0              410    -9.0
# 73  YNL269W              395.0              401    -6.0
# 76  YNL205C              422.0              425    -3.0
# ..      ...                ...              ...     ...
# 22    Q0105             7107.0             7068    39.0
# 32    Q0105             7107.0             7059    48.0
# 94  YJL222W             4649.0             4571    78.0
# 30    Q0050             2504.0             1901   603.0
# 29    Q0045            12883.0             9003  3880.0
#
# [96 rows x 4 columns]

# %% [markdown]
# ## Add genes with inframe stop codon as having a valid ORF

# %%
gene_mRNA.head()
# Out:
#               seq_id_x  start_x  end_x  \
# 0  chrII-2_tig00004927     8297  10119
# 1  chrII-2_tig00004927    10675  10894
# 2  chrII-2_tig00004927    10985  12717
# 3  chrII-2_tig00004927    14242  14700
# 4  chrII-2_tig00004927    14660  15022
#
#                                         Alias         ID_x     Name_x  \
# 0         MAL31,MAL3T,MALT,maltose%20permease    YBR298C_1    YBR298C
# 1                                        None  YBR298C-A_1  YBR298C-A
# 2  MAL32,MAL3S,MALS,alpha-glucosidase%20MAL32    YBR299W_1    YBR299W
# 3                                        None    YGR293C_2    YGR293C
# 4                  PAU12,seripauperin%20PAU12    YGR294W_1    YGR294W
#
#    copy_num_ID coverage                                       display  \
# 0    YBR298C_1    0.986                            Maltose%20permease
# 1  YBR298C-A_1    0.990  Putative%20protein%20of%20unknown%20function
# 2    YBR299W_1    0.986           Maltase%20%28alpha-D-glucosidase%29
# 3    YGR293C_2    0.993              Dubious%20open%20reading%20frame
# 4    YGR294W_1      1.0             Protein%20of%20unknown%20function
#
#   extra_copy_number_x  ...          Name_y       Parent conditions  \
# 0                   1  ...   YBR298C_id001    YBR298C_1        GAL
# 1                   1  ...  YBR298C-A_mRNA  YBR298C-A_1       None
# 2                   1  ...   YBR299W_id001    YBR299W_1        GAL
# 3                   2  ...    YGR293C_mRNA    YGR293C_2       None
# 4                   1  ...   YGR294W_id001    YGR294W_1        GAL
#
#   extra_copy_number_y inframe_stop_codon matches_ref_protein  \
# 0                   1               None               False
# 1                   1               None               False
# 2                   1               None               False
# 3                   2               True               False
# 4                   1               None                True
#
#   missing_start_codon  missing_stop_codon            transcript_id valid_ORF
# 0                None                True         SGD:S000288108_1     False
# 1                None                True  RefSeq:NM_001184588.1_1     False
# 2                None                True         SGD:S000288109_1     False
# 3                None                None                     None     False
# 4                None                None         SGD:S000289696_1      True
#
# [5 rows x 30 columns]

# %%
gene_mRNA.loc[gene_mRNA['inframe_stop_codon'] == 'True', 'valid_ORF'] = "True"

# %%
gene_mRNA['valid_ORF'].value_counts()
# Out:
# True     6263
# False     428
# Name: valid_ORF, dtype: int64

# %% [markdown]
# # kick out duplicated genes who have a valid version

# %%
gene_mRNA_valid = gene_mRNA[gene_mRNA['valid_ORF'] == 'True' ]
gene_mRNA_unvalid = gene_mRNA[gene_mRNA['valid_ORF'] == 'False']

valid_list = set(gene_mRNA_valid['Name_x'])
unvalid_list = set(gene_mRNA_unvalid['Name_x'])
dupl_val_unval = valid_list & unvalid_list

# 39 genes have 1 duplicated unvalid version I can forget about
len(dupl_val_unval)
# Out:
# 39

# %%
# We are kicking out 39 genes 
gene_mRNA_unvalid = gene_mRNA_unvalid[~gene_mRNA_unvalid['Name_x'].isin(list(dupl_val_unval))]

# %% [markdown]
# ### Focus on Verified unvalid (missing start or stop codon)

# %%
gene_mRNA_verified = gene_mRNA[gene_mRNA['orf_classification']== 'Verified']
gene_mRNA_verified_unvalid = gene_mRNA_unvalid[gene_mRNA_unvalid['orf_classification']== 'Verified']

# %%
gene_mRNA_verified_unvalid.drop_duplicates(subset=['Name_x'], inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\4212071888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gene_mRNA_verified_unvalid.drop_duplicates(subset=['Name_x'], inplace=True)

# %%
gene_mRNA_verified_unvalid['missing_stop_codon'].value_counts()
# Out:
# True    85
# Name: missing_stop_codon, dtype: int64

# %%
gene_mRNA_verified_unvalid['missing_start_codon'].value_counts()
# Out:
# True    17
# Name: missing_start_codon, dtype: int64

# %%
gene_mRNA_verified_unvalid[gene_mRNA_verified_unvalid['missing_start_codon'] == 'True'].to_excel('missing_start.xlsx')
gene_mRNA_verified_unvalid[gene_mRNA_verified_unvalid['missing_stop_codon'] == 'True'].to_excel('missing_stop.xlsx')

# %%
gene_mRNA_verified_unvalid['missing_stop_codon'].value_counts()
# Out:
# True    85
# Name: missing_stop_codon, dtype: int64

# %%
gene_mRNA_verified_unvalid['missing_start_codon'].value_counts()
# Out:
# True    17
# Name: missing_start_codon, dtype: int64

# %% [markdown]
# ## Unvalid ORFs to add to valid genes (because essential or valid ORF in y22 Liftoff)

# %%
gene_to_add = []
with open('missing_stop_start_genes_to_add.txt', 'r')as file:
    for l in file:
        gene_to_add.append(l.strip('\n'))

# %%
gene_mRNA.loc[gene_mRNA['Name_x'].isin(gene_to_add), 'valid_ORF'] = "True"

# %% [markdown]
# # Add Missing genes that have illumina sequencing values
# We insured that those are still on the same chromosome by insuring that disomes RPKM values are two times higher in the rest of the strains. More details: C:\Users\user\Documents\yps1009_nanopore_genomeSeq\LIFTOFF\IGV\James_illumiaReads.

# %%
miss_illumina = pd.read_excel('missing_genes_v5_illuminaReads.xlsx', index_col=1)

# %%
del miss_illumina['Unnamed: 0.1']
del miss_illumina['Unnamed: 21']

# %%
miss_illumina = miss_illumina[miss_illumina['AVG rpmk Disome'] > 0]

# %%
miss_illumina = lat_to_arabic_S288(miss_illumina)

# %%
miss_illumina.columns
# Out:
# Index(['seq_id', 'start', 'end', 'Name', 'gene', 'Alias', 'Note',
#        'Ontology_term', 'strand', 'phase', 'curie', 'orf_classification',
#        'display', 'Chromosome', 'Blast', 'rpkm sum', 'no illumina reads',
#        'AVG rpmk Disome', 'AVG rpkm all but Dis'],
#       dtype='object')

# %%
gene_mRNA.columns
# Out:
# Index(['seq_id_x', 'start_x', 'end_x', 'Alias', 'ID_x', 'Name_x',
#        'copy_num_ID', 'coverage', 'display', 'extra_copy_number_x', 'gene',
#        'low_identity', 'orf_classification', 'partial_mapping', 'sequence_ID',
#        'valid_ORFs', 'seq_id_y', 'start_y', 'end_y', 'ID_y', 'Name_y',
#        'Parent', 'conditions', 'extra_copy_number_y', 'inframe_stop_codon',
#        'matches_ref_protein', 'missing_start_codon', 'missing_stop_codon',
#        'transcript_id', 'valid_ORF'],
#       dtype='object')

# %%
# Recall all valid genes
gene_mRNA_valid = gene_mRNA[gene_mRNA['valid_ORF'] == 'True']

# %%
gene_mRNA_valid = gene_mRNA_valid[['seq_id_x', 'start_x', 'end_x', 'Alias', 'ID_x', 'Name_x',
       'copy_num_ID', 'coverage', 'display', 'extra_copy_number_x', 'gene', 
       'low_identity', 'orf_classification', 'partial_mapping', 'sequence_ID', 'valid_ORF']]
gene_mRNA_valid.columns = gene_mRNA_valid.columns.str.strip('_x')

# %%
gene_mRNA_valid = lat_to_arabic(gene_mRNA_valid)

# %%
miss_illumina.head()
# Out:
#             seq_id   start     end     Name   gene  \
# Unnamed: 0
# 9420        chrVII  249869  252738  YGL137W  SEC27
# 9426        chrVII  252897  253859  YGL136C   MRM2
# 9434        chrVII  255663  256964  YGL134W  PCL10
# 9438        chrVII  257707  261501  YGL133W   ITC1
# 9441        chrVII  261580  261915  YGL132W    NaN
#
#                                                         Alias  \
# Unnamed: 0
# 9420                         SEC27,coatomer%20subunit%20beta'
# 9426        MRM2,21S%20rRNA%20%28uridine2791-2'-O%29%20met...
# 9434                                                    PCL10
# 9438                                                     ITC1
# 9441                                                      NaN
#
#                                                          Note  \
# Unnamed: 0
# 9420        Essential beta'-coat protein of the COPI coato...
# 9426        Mitochondrial 2' O-ribose methyltransferase%3B...
# 9434        Pho85p cyclin%3B recruits%2C activates%2C and ...
# 9438        Subunit of ATP-dependent Isw2p-Itc1p chromatin...
# 9441        Dubious open reading frame%3B unlikely to enco...
#
#                                                 Ontology_term strand phase  \
# Unnamed: 0
# 9420        GO:0006888,GO:0006890,GO:0008298,GO:0030126,GO...      +     .
# 9426        GO:0005739,GO:0008650,GO:0008650,GO:0008650,GO...      -     .
# 9434        GO:0000079,GO:0000307,GO:0016538,GO:0045719,GO...      +     .
# 9438        GO:0003674,GO:0005634,GO:0006348,GO:0008623,GO...      +     .
# 9441              GO:0003674,GO:0005575,GO:0008150,SO:0000704      +     .
#
#                      curie orf_classification  \
# Unnamed: 0
# 9420        SGD:S000003105           Verified
# 9426        SGD:S000003104           Verified
# 9434        SGD:S000003102           Verified
# 9438        SGD:S000003101           Verified
# 9441        SGD:S000003100            Dubious
#
#                                                       display  Chromosome  \
# Unnamed: 0
# 9420        Essential beta'-coat protein of the COPI coatomer           7
# 9426              Mitochondrial 2' O-ribose methyltransferase           7
# 9434                                            Pho85p cyclin           7
# 9438        Subunit of ATP-dependent Isw2p-Itc1p chromatin...           7
# 9441                               Dubious open reading frame           7
#
#               Blast     rpkm sum  no illumina reads  AVG rpmk Disome  \
# Unnamed: 0
# 9420        No hits  1839.993915              False        75.560709
# 9426        No hits  2084.380818              False        58.191421
# 9434        No hits  1916.747909              False        64.940069
# 9438        No hits  1882.690663              False        71.756721
# 9441        No hits  2015.775295              False        59.302206
#
#             AVG rpkm all but Dis
# Unnamed: 0
# 9420                   34.172246
# 9426                   41.147003
# 9434                   36.821947
# 9438                   35.459195
# 9441                   39.523699

# %%
gene_mRNA_valid = gene_mRNA_valid.append(miss_illumina)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\3215699702.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gene_mRNA_valid = gene_mRNA_valid.append(miss_illumina)

# %%
gene_mRNA_valid = gene_mRNA_valid[['seq_id', 'start', 'end', 'Alias', 'ID', 'Name', 'copy_num_ID', 'orf_classification',
       'coverage', 'display', 'extra_copy_number', 'gene', 'low_identity', 'Chromosome', 'valid_ORF', 'sequence_ID']]

# %%
gene_mRNA.columns
# Out:
# Index(['seq_id_x', 'start_x', 'end_x', 'Alias', 'ID_x', 'Name_x',
#        'copy_num_ID', 'coverage', 'display', 'extra_copy_number_x', 'gene',
#        'low_identity', 'orf_classification', 'partial_mapping', 'sequence_ID',
#        'valid_ORFs', 'seq_id_y', 'start_y', 'end_y', 'ID_y', 'Name_y',
#        'Parent', 'conditions', 'extra_copy_number_y', 'inframe_stop_codon',
#        'matches_ref_protein', 'missing_start_codon', 'missing_stop_codon',
#        'transcript_id', 'valid_ORF'],
#       dtype='object')

# %%
gene_mRNA_valid.shape
# Out:
# (6321, 16)

# %%
gene_mRNA_valid['orf_classification'].value_counts()
# Out:
# Verified           5175
# Uncharacterized     578
# Dubious             566
# Name: orf_classification, dtype: int64

# %%
gene_mRNA_valid_sh = gene_mRNA_valid[['Name', 'gene', 'Chromosome', 'orf_classification']]

# %%
gene_mRNA_valid_sh.to_csv('yps1009_genes_final.txt', sep = '\t', index= False)

# %% [markdown]
# # Count Verified, Dubious and Uncharacterized Genes

# %%
gene_mRNA_verified = gene_mRNA_valid[gene_mRNA_valid['orf_classification'] == 'Verified']
gene_mRNA_dubious = gene_mRNA_valid[gene_mRNA_valid['orf_classification'] == 'Dubious']
gene_mRNA_uncharacterized = gene_mRNA_valid[gene_mRNA_valid['orf_classification'] == 'Uncharacterized']

# %%
verified_count = gene_mRNA_verified['Chromosome'].value_counts().to_frame()
verified_count = verified_count.rename(columns = {'Chromosome': 'yps1009 verified genes'})

dubious_count = gene_mRNA_dubious['Chromosome'].value_counts().to_frame()
dubious_count = dubious_count.rename(columns = {'Chromosome': 'yps1009 dubious genes'})

uncharacterized_count = gene_mRNA_uncharacterized['Chromosome'].value_counts().to_frame()
uncharacterized_count = uncharacterized_count.rename(columns = {'Chromosome': 'yps1009 uncharacterized genes'})

# %%
FEATS = FEATS.join(verified_count)
FEATS = FEATS.join(dubious_count)
FEATS = FEATS.join(uncharacterized_count)

# %%
FEATS.columns
# Out:
# Index(['S288C ARS', 'yps1009 ARS', 'S288C ltr', 'yps1009 ltr', 'S288C ncRNA',
#        'yps1009 ncRNA', 'S288C snRNA', 'yps1009 snRNA', 'yps1009 LTR RetroP',
#        'S288C snoRNA', 'yps1009 snoRNA', 'S288C tRNA', 'yps1009 tRNA',
#        'yps1009 verified genes', 'yps1009 dubious genes',
#        'yps1009 uncharacterized genes'],
#       dtype='object')

# %%
FEATS_yps = FEATS[['yps1009 verified genes', 'yps1009 dubious genes',
       'yps1009 uncharacterized genes', 'yps1009 ARS', 'yps1009 ltr', 'yps1009 ncRNA', 'yps1009 LTR RetroP', 'yps1009 snoRNA',
        'yps1009 tRNA', 'yps1009 rRNA', 'yps1009 snRNA']]

# %%
FEATS_yps.columns = FEATS_yps.columns.str.replace('yps1009 ', '')

# %%
FEATS_yps['Total Features'] = FEATS_yps.sum(axis=1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\4281676088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FEATS_yps['Total Features'] = FEATS_yps.sum(axis=1)

# %%
FEATS_yps.columns
# Out:
# Index(['verified genes', 'dubious genes', 'uncharacterized genes', 'ARS',
#        'ltr', 'ncRNA', 'LTR RetroP', 'snoRNA', 'tRNA', 'rRNA', 'snRNA',
#        'Total Features'],
#       dtype='object')

# %%
FEATS_yps.to_csv('yps1009_v5_features_per_chromosome.csv', index = True)

# %% [markdown]
# # Check small contigs that looks like duplicated region from the same chromosome

# %%
gene_mRNA[gene_mRNA['seq_id_x'] == 'chrII-2_tig00004927']
# Out:
#               seq_id_x  start_x  end_x  \
# 0  chrII-2_tig00004927     8297  10119
# 1  chrII-2_tig00004927    10675  10894
# 2  chrII-2_tig00004927    10985  12717
# 3  chrII-2_tig00004927    14242  14700
# 4  chrII-2_tig00004927    14660  15022
# 5  chrII-2_tig00004927    15948  17085
# 6  chrII-2_tig00004927    17693  17829
#
#                                         Alias         ID_x     Name_x  \
# 0         MAL31,MAL3T,MALT,maltose%20permease    YBR298C_1    YBR298C
# 1                                        None  YBR298C-A_1  YBR298C-A
# 2  MAL32,MAL3S,MALS,alpha-glucosidase%20MAL32    YBR299W_1    YBR299W
# 3                                        None    YGR293C_2    YGR293C
# 4                  PAU12,seripauperin%20PAU12    YGR294W_1    YGR294W
# 5                                        COS6    YGR295C_1    YGR295C
# 6                                        None  YHL048C-A_1  YHL048C-A
#
#    copy_num_ID coverage                                            display  \
# 0    YBR298C_1    0.986                                 Maltose%20permease
# 1  YBR298C-A_1    0.990       Putative%20protein%20of%20unknown%20function
# 2    YBR299W_1    0.986                Maltase%20%28alpha-D-glucosidase%29
# 3    YGR293C_2    0.993                   Dubious%20open%20reading%20frame
# 4    YGR294W_1      1.0                  Protein%20of%20unknown%20function
# 5    YGR295C_1    0.993  Endosomal%20protein%20involved%20in%20turnover...
# 6  YHL048C-A_1    0.992       Putative%20protein%20of%20unknown%20function
#
#   extra_copy_number_x  ...          Name_y       Parent conditions  \
# 0                   1  ...   YBR298C_id001    YBR298C_1        GAL
# 1                   1  ...  YBR298C-A_mRNA  YBR298C-A_1       None
# 2                   1  ...   YBR299W_id001    YBR299W_1        GAL
# 3                   2  ...    YGR293C_mRNA    YGR293C_2       None
# 4                   1  ...   YGR294W_id001    YGR294W_1        GAL
# 5                   1  ...    YGR295C_mRNA    YGR295C_1       None
# 6                   1  ...  YHL048C-A_mRNA  YHL048C-A_1       None
#
#   extra_copy_number_y inframe_stop_codon matches_ref_protein  \
# 0                   1               None               False
# 1                   1               None               False
# 2                   1               None               False
# 3                   2               True               False
# 4                   1               None                True
# 5                   1               None               False
# 6                   1               None               False
#
#   missing_start_codon  missing_stop_codon            transcript_id valid_ORF
# 0                None                True         SGD:S000288108_1     False
# 1                None                True  RefSeq:NM_001184588.1_1     False
# 2                None                True         SGD:S000288109_1     False
# 3                None                None                     None      True
# 4                None                None         SGD:S000289696_1      True
# 5                None                True  RefSeq:NM_001181424.1_1     False
# 6                None                True  RefSeq:NM_001184650.1_1     False
#
# [7 rows x 30 columns]

# %% [markdown]
# # Loading illumina seq RPKM from James
# The idea is to see whether RPKM of supposedly duplicated region have a higher read counts

# %%
rpkm = pd.read_csv('James_220427_KC5T7-RPKM.results', sep = '\t', index_col=0)
samples = pd.read_csv('YPS1009-Disomes_GenomicSeq.txt', sep = '\t')
dic = {}
for ind, row in samples.iterrows():
    code = row['Next-Gen Gasch #'].replace(' ', '-')
    dic[code] = row['Strain']

# %%
for c in list(rpkm.columns):
    cs, t = c.split('_')
    rpkm = rpkm.rename(columns={c: dic[cs]})

# %%
rpkm_Eupl = rpkm.filter(like="Euploid", axis=1)
rpkm_Eupl['Median'] = rpkm_Eupl.median(axis=1)
#filter 0 and low detection genes
rpkm_Eupl = rpkm_Eupl[rpkm_Eupl['Median'] > 5]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16892\2898711814.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rpkm_Eupl['Median'] = rpkm_Eupl.median(axis=1)

# %% [markdown]
# ## now check these contigs that are partially mapped to other contigs

# %%
import numpy as np

# %%
chr2_2_genes = list(gene_mRNA[gene_mRNA['seq_id_x'] == 'chrII-2_tig00004927']['Name_x'])
chr2_genes = list(gene_mRNA[gene_mRNA['seq_id_x'] == 'chrII_tig00000010']['Name_x'])

ch2_rp = rpkm_Eupl[rpkm_Eupl.index.isin(chr2_genes)]
ch2_dupl_rp = rpkm_Eupl[rpkm_Eupl.index.isin(chr2_2_genes)]

# %%
np.median(ch2_rp['Median'])
# Out:
# 39.75553585341481

# %%
np.median(ch2_dupl_rp['Median'])
# Out:
# 35.73805739723673

# %% [markdown]
# ## Chromosome 12

# %%
chr12_2_genes = list(gene_mRNA[gene_mRNA['seq_id_x'] == 'chrXII-2_tig00004934']['Name_x'])
chr12_genes = list(gene_mRNA[gene_mRNA['seq_id_x'] == 'chrXII_tig00000020']['Name_x'])

ch12_rp = rpkm_Eupl[rpkm_Eupl.index.isin(chr12_genes)]
ch12_dupl_rp = rpkm_Eupl[rpkm_Eupl.index.isin(chr12_2_genes)]

# %%
print('Chr12: ', np.median(ch12_rp['Median']))
print('Chr12 short contig: ', np.median(ch12_dupl_rp['Median']))
# Out:
# Chr12:  39.05192975088535
# Chr12 short contig:  38.5105917963216
