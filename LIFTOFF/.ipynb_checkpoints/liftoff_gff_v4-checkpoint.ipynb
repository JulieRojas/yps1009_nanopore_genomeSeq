# %%
# from BCBio.GFF import GFFExaminer

# %% [markdown]
# https://gffpandas.readthedocs.io/en/latest/tutorial.html

# %%
import gffpandas.gffpandas as gffpd
import pandas as pd

# %%
annotation = gffpd.read_gff3('YPS1009_S288C_v4_polished.gff')
annot_s288c = gffpd.read_gff3('saccharomyces_cerevisiae_R64-3.gff')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\gffpandas\gffpandas.py:32: DtypeWarning: Columns (1,2,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_table(self._gff_file, comment='#',

# %%
annotation.df['type'].value_counts()
# Out:
# CDS                                7178
# gene                               6707
# mRNA                               6707
# noncoding_exon                      493
# tRNA_gene                           321
# tRNA                                321
# transposable_element_gene            99
# transposable_element                 99
# snoRNA                               77
# snoRNA_gene                          77
# plus_1_translational_frameshift      47
# five_prime_UTR_intron                24
# ncRNA_gene                           23
# ncRNA                                23
# snRNA_gene                            6
# snRNA                                 6
# uORF                                  6
# telomeric_repeat                      3
# intein_encoding_region                1
# Name: type, dtype: int64

# %%
annot_s288c.df['type'].value_counts()
# Out:
# mRNA                                  11119
# CDS                                    7066
# gene                                   6607
# ARS                                     543
# noncoding_exon                          489
# long_terminal_repeat                    384
# intron                                  378
# tRNA                                    299
# tRNA_gene                               299
# ARS_consensus_sequence                  196
# transposable_element_gene                91
# transposable_element                     91
# region                                   78
# snoRNA_gene                              77
# snoRNA                                   77
# telomere                                 64
# LTR_retrotransposon                      50
# plus_1_translational_frameshift          47
# X_element                                32
# centromere                               32
# telomeric_repeat                         31
# X_element_combinatorial_repeat           28
# rRNA                                     24
# rRNA_gene                                24
# five_prime_UTR_intron                    24
# ncRNA                                    23
# ncRNA_gene                               23
# Y_prime_element                          19
# chromosome                               17
# centromere_DNA_Element_III               16
# centromere_DNA_Element_II                16
# centromere_DNA_Element_I                 16
# pseudogene                               12
# blocked_reading_frame                    12
# uORF                                     11
# internal_transcribed_spacer_region        8
# external_transcribed_spacer_region        8
# origin_of_replication                     8
# matrix_attachment_site                    8
# snRNA                                     6
# snRNA_gene                                6
# silent_mating_type_cassette_array         4
# X_region                                  3
# Y_region                                  3
# non_transcribed_region                    3
# Z1_region                                 3
# W_region                                  2
# Z2_region                                 2
# mating_type_region                        2
# intein_encoding_region                    2
# recombination_enhancer                    1
# telomerase_RNA                            1
# telomerase_RNA_gene                       1
# Name: type, dtype: int64

# %%
sgd_s288c = pd.read_csv('chr_features_s288c.csv', index_col=0)

# %%
sgd_s288c.sum()
# Out:
# Verified ORF                                                              5208
# long terminal repeat                                                       384
# ARS                                                                        352
# tRNA gene                                                                  275
# transposable element gene                                                   91
# snoRNA gene                                                                 77
# LTR retrotransposon                                                         50
# rRNA gene                                                                   22
# ncRNA gene                                                                  22
# Total Features                                                            7944
# Chromosome Length (bp)       230,218813,184316,6201,531,933576,874270,1611,...
# dtype: object

# %%
CDS_df = annotation.filter_feature_of_type(['CDS'])

# %%
TE_df_2 = annotation.filter_feature_of_type(['transposable_element'])

# %%
TE_df = annotation.filter_feature_of_type(['transposable_element_gene'])
sno_df = annotation.filter_feature_of_type(['snoRNA_gene'])
tRNA_df = annotation.filter_feature_of_type(['tRNA_gene'])
gene_df = annotation.filter_feature_of_type(['gene'])

# %%
CDS_attr = CDS_df.attributes_to_columns()

# %%
CDS_attr.columns
# Out:
# Index(['seq_id', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase',
#        'attributes', 'ID', 'Name', 'Parent', 'extra_copy_number',
#        'orf_classification', 'protein_id'],
#       dtype='object')

# %%
mRNA_df = annotation.filter_feature_of_type(['mRNA'])
mRNA_attr = mRNA_df.attributes_to_columns()

# %%
mRNA_attr['valid_ORF'].value_counts()
# Out:
# True     6177
# False     530
# Name: valid_ORF, dtype: int64

# %%
gene_attr = gene_df.attributes_to_columns()
gene = gene_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'gene', 'low_identity', 'orf_classification',
       'partial_mapping', 'sequence_ID', 'valid_ORFs']]

# %%
gene_attr['valid_ORFs'].value_counts()
# so valid_ORFs in gene does count itself and I should look carefully at the 439 genes with no valid ORF
# Out:
# 1    6175
# 0     530
# Name: valid_ORFs, dtype: int64

# %%
TE_attr = TE_df.attributes_to_columns()
sno_attr = sno_df.attributes_to_columns()
tRNA_attr = tRNA_df.attributes_to_columns()

# %%
tRNA_attr.columns
# Out:
# Index(['seq_id', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase',
#        'attributes', 'Alias', 'ID', 'Name', 'Note', 'Ontology_term',
#        'copy_num_ID', 'coverage', 'curie', 'dbxref', 'display',
#        'extra_copy_number', 'gene', 'sequence_ID'],
#       dtype='object')

# %%
TE = TE_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'sequence_ID', 'valid_ORFs']]

sno = sno_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'gene', 'sequence_ID']]

tRNA = tRNA_attr[['seq_id', 'start', 'end', 'Name',  'Alias',  'Note', 'Ontology_term', 'score', 'strand', 'phase',
       'copy_num_ID', 'coverage', 'curie', 'display', 'extra_copy_number', 'gene', 'sequence_ID']]

# %%
# This code just convert the chromosome numbering to integer and remove mitochondrial genes.
def lat_to_arabic(DF):
    Latin_to_arabic = {'I': 1, 'II':2, 'III':3, 'IV':4, 'V':5, 'VI':6, 'VII':7, 'VIII':8, 'IX':9, 'X':10,
                      'XI':11, 'XII':12, 'XIII':13, 'XIV':14, 'XV':15, 'XVI':16, 'Mito': 'mitoch', 'MANY': 7}
    seq_id = DF['seq_id']
    ch = []
    contig = []
    for i in seq_id:
        chrom, cont = i.split('_')
        contig.append(cont)
        chrom = chrom.replace('chr', '')
        if '-' in chrom:
            chrom, e = chrom.split('-')
        ch.append(Latin_to_arabic[chrom])
    DF['Chromosome'] = ch
    DF['Contig'] = contig
    return DF

# %%
gene = lat_to_arabic(gene)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_32584\3764198105.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_32584\3764198105.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig

# %%
TE = lat_to_arabic(TE)
sno = lat_to_arabic(sno)
tRNA = lat_to_arabic(tRNA)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_32584\3764198105.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_32584\3764198105.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig
# C:\Users\user\AppData\Local\Temp\ipykernel_32584\3764198105.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_32584\3764198105.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig
# C:\Users\user\AppData\Local\Temp\ipykernel_32584\3764198105.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Chromosome'] = ch
# C:\Users\user\AppData\Local\Temp\ipykernel_32584\3764198105.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Contig'] = contig

# %%
gene.head()
# Out:
#                  seq_id  start    end       Name  \
# 0   chrII-2_tig00004927   8297  10119    YBR298C
# 3   chrII-2_tig00004927  10675  10894  YBR298C-A
# 6   chrII-2_tig00004927  10985  12717    YBR299W
# 9   chrII-2_tig00004927  14242  14700    YGR293C
# 12  chrII-2_tig00004927  14660  15022    YGR294W
#
#                                          Alias  \
# 0          MAL31,MAL3T,MALT,maltose%20permease
# 3                                         None
# 6   MAL32,MAL3S,MALS,alpha-glucosidase%20MAL32
# 9                                         None
# 12                  PAU12,seripauperin%20PAU12
#
#                                                  Note  \
# 0   Maltose%20permease%3B%20high-affinity%20maltos...
# 3   Putative%20protein%20of%20unknown%20function%3...
# 6   Maltase%20%28alpha-D-glucosidase%29%3B%20induc...
# 9   Dubious%20open%20reading%20frame%3B%20unlikely...
# 12  Protein%20of%20unknown%20function%3B%20member%...
#
#                                         Ontology_term score strand phase  ...  \
# 0         GO:0000017,GO:0005352,GO:0071944,SO:0000704     .      -     .  ...
# 3         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .  ...
# 6   GO:0000025,GO:0004575,GO:0005886,GO:0005987,GO...     .      +     .  ...
# 9         GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      -     .  ...
# 12        GO:0003674,GO:0005575,GO:0008150,SO:0000704     .      +     .  ...
#
#                                          display extra_copy_number   gene  \
# 0                             Maltose%20permease                 1  MAL31
# 3   Putative%20protein%20of%20unknown%20function                 1   None
# 6            Maltase%20%28alpha-D-glucosidase%29                 1  MAL32
# 9               Dubious%20open%20reading%20frame                 2   None
# 12             Protein%20of%20unknown%20function                 1  PAU12
#
#    low_identity orf_classification partial_mapping sequence_ID valid_ORFs  \
# 0          None           Verified            None       0.946          0
# 3          None    Uncharacterized            None       0.981          0
# 6          None           Verified            None       0.981          0
# 9          None            Dubious            None       0.989          0
# 12         None           Verified            None       0.983          1
#
#    Chromosome       Contig
# 0           2  tig00004927
# 3           2  tig00004927
# 6           2  tig00004927
# 9           2  tig00004927
# 12          2  tig00004927
#
# [5 rows x 23 columns]

# %%
def clean20(DF):
    note = DF['Note']
    dis = DF['display']
    clean = []
    display = []
    for n in note:
        clean.append(n.replace('%20', ' '))
    for d in dis:
        display.append(str(d).replace('%20', ' '))
    DF['Note'] = clean
    DF['display'] = display
    return DF

# %%
gene = clean20(gene)
TE = clean20(TE)
sno = clean20(sno)
tRNA = clean20(tRNA)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_32584\741321415.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['Note'] = clean
# C:\Users\user\AppData\Local\Temp\ipykernel_32584\741321415.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF['display'] = display

# %% [markdown]
# # TE

# %%
TE['seq_id'].value_counts()
# Out:
# chrMANY_tig00000038     54
# chrXII-2_tig00004934    14
# chrIV_tig00000001       12
# chrV_tig00000015         8
# chrII_tig00000010        2
# chrVI_tig00004938        2
# chrXV_tig00000007        2
# chrIII_tig00004936       1
# chrI_tig00000033         1
# chrVIII_tig00000017      1
# chrXVI-2_tig00000040     1
# chrX_tig00001098         1
# Name: seq_id, dtype: int64

# %%
TE['Chromosome'].value_counts()
# Out:
# 7     54
# 12    14
# 4     12
# 5      8
# 2      2
# 6      2
# 15     2
# 3      1
# 1      1
# 8      1
# 16     1
# 10     1
# Name: Chromosome, dtype: int64

# %%
TE['valid_ORFs'].value_counts()
# Out:
# 1    61
# 0    38
# Name: valid_ORFs, dtype: int64

# %%
sum(sgd_s288c['transposable element gene'])
# Out:
# 91

# %%
TE_count = TE['Chromosome'].value_counts().to_frame()
TE_count = TE_count.join(sgd_s288c['transposable element gene'])
TE_count = TE_count.rename(columns = {'Chromosome': 'yps1009 TE', 'transposable element gene': 's288c TE'})

# %%
TE_count
# Out:
#     yps1009 TE  s288c TE
# 7           54        10
# 12          14         8
# 4           12        17
# 5            8         4
# 2            2         6
# 6            2         2
# 15           2         8
# 3            1         2
# 1            1         2
# 8            1         4
# 16           1         9
# 10           1         6

# %% [markdown]
# # snoRNA

# %%
sno_count = sno['Chromosome'].value_counts().to_frame()
sno_count = sno_count.join(sgd_s288c['snoRNA gene'])
sno_count = sno_count.rename(columns = {'Chromosome': 'yps1009 snoRNA', 'snoRNA gene': 's288c snoRNA'})

# %%
sno_count
# Out:
#     yps1009 snoRNA  s288c snoRNA
# 13              13            13
# 15              11            11
# 12               7             7
# 7                6             6
# 16               6             6
# 5                5             5
# 14               5             5
# 11               5             5
# 10               5             5
# 3                4             4
# 4                4             4
# 2                2             2
# 8                2             2
# 9                1             1
# 1                1             1

# %% [markdown]
# # tRNA

# %%
tRNA_count = tRNA['Chromosome'].value_counts().to_frame()
tRNA_count = tRNA_count.join(sgd_s288c['tRNA gene'])
tRNA_count = tRNA_count.rename(columns = {'Chromosome': 'yps1009 tRNA', 'tRNA gene': 's288c tRNA'})

# %%
tRNA
# Out:
#                    seq_id   start     end       Name                Alias  \
# 201    chrIII_tig00004936   82917   82988  YNCC0001C         tE%28UUC%29C
# 207    chrIII_tig00004936   84660   84773  YNCC0002W   SUP53,tL%28CAA%29C
# 287    chrIII_tig00004936  117379  117450  YNCC0004C    SUF2,tP%28AGG%29C
# 293    chrIII_tig00004936  121186  121259  YNCC0005W         tN%28GUU%29C
# 296    chrIII_tig00004936  121186  121259  YNCN0003W        tN%28GUU%29N1
# ...                   ...     ...     ...        ...                  ...
# 21819    chrX_tig00001098  516144  516214  YNCJ0024W  SUF23,tG%28GCC%29J2
# 21831    chrX_tig00001098  522533  522604  YNCJ0025W    HSX1,tR%28CCU%29J
# 21837    chrX_tig00001098  525148  525219  YNCJ0026W        tD%28GUC%29J4
# 21843    chrX_tig00001098  526596  526684  YNCJ0027C   SUP4,tY%28GUA%29J2
# 21984    chrX_tig00001098  601545  601645  YNCJ0029W         tL%28UAG%29J
#
#                                                     Note  \
# 201    Glutamine tRNA %28tRNA-Glu%29%2C predicted by ...
# 207    Leucine tRNA %28tRNA-Leu%29%2C predicted by tR...
# 287    Proline tRNA %28tRNA-Pro%29%2C predicted by tR...
# 293    Asparagine tRNA %28tRNA-Asn%29%2C predicted by...
# 296    Asparagine tRNA %28tRNA-Asn%29%2C predicted by...
# ...                                                  ...
# 21819  Glycine tRNA %28tRNA-Gly%29%3B can mutate to s...
# 21831  Arginine tRNA %28tRNA-Arg%29%2C predicted by t...
# 21837  Aspartate tRNA %28tRNA-Asp%29%2C predicted by ...
# 21843  Tyrosine tRNA %28tRNA-Tyr%29%2C predicted by t...
# 21984  Leucine tRNA %28tRNA-Leu%29%2C predicted by tR...
#
#                                            Ontology_term score strand phase  \
# 201          GO:0005829,GO:0006414,GO:0030533,SO:0000704     .
# # GENE

# %%
gene.columns
# Out:
# Index(['seq_id', 'start', 'end', 'Name', 'Alias', 'Note', 'Ontology_term',
#        'score', 'strand', 'phase', 'copy_num_ID', 'coverage', 'curie',
#        'display', 'extra_copy_number', 'gene', 'low_identity',
#        'orf_classification', 'partial_mapping', 'sequence_ID', 'valid_ORFs',
#        'Chromosome', 'Contig'],
#       dtype='object')

# %%
gene = gene[['Name', 'Chromosome', 'Contig', 'start', 'end', 'Alias', 'Note', 'Ontology_term',
       'coverage', 'curie', 'display', 'extra_copy_number',
       'gene', 'low_identity', 'orf_classification', 'partial_mapping',
       'sequence_ID', 'valid_ORFs']]

# %%
gene['orf_classification'].value_counts()
# Out:
# Verified           5249
# Uncharacterized     737
# Dubious             719
# Name: orf_classification, dtype: int64

# %%
dubious = gene[gene['orf_classification'] == 'Dubious']
dubious['valid_ORFs'].value_counts()
# Out:
# 1    524
# 0    195
# Name: valid_ORFs, dtype: int64

# %%
uncharacterized = gene[gene['orf_classification'] == 'Uncharacterized']
uncharacterized['valid_ORFs'].value_counts()
# Out:
# 1    564
# 0    173
# Name: valid_ORFs, dtype: int64

# %% [markdown]
# # Verified ORF

# %%
verified = gene[gene['orf_classification'] == 'Verified']

# %%
verified['valid_ORFs'].value_counts()
# Out:
# 1    5087
# 0     162
# Name: valid_ORFs, dtype: int64

# %%
verified.columns
# Out:
# Index(['Name', 'Chromosome', 'Contig', 'start', 'end', 'Alias', 'Note',
#        'Ontology_term', 'coverage', 'curie', 'display', 'extra_copy_number',
#        'gene', 'low_identity', 'orf_classification', 'partial_mapping',
#        'sequence_ID', 'valid_ORFs'],
#       dtype='object')

# %%
verified_valid = verified[verified['valid_ORFs'] == '1']
verified_unvalid = verified[verified['valid_ORFs'] == '0']

verified_valid_count = verified_valid['Chromosome'].value_counts().to_frame()
verified_valid_count = verified_valid_count.rename(columns={'Chromosome': 'Number valid genes'})
verified_unvalid_count = verified_unvalid['Chromosome'].value_counts().to_frame()
verified_unvalid_count = verified_unvalid_count.rename(columns={'Chromosome': 'Number unvalid genes'})

# %%
verified_unvalid.head(2)
# Out:
#       Name Chromosome       Contig  start    end  \
# 0  YBR298C          2  tig00004927   8297  10119
# 6  YBR299W          2  tig00004927  10985  12717
#
#                                         Alias  \
# 0         MAL31,MAL3T,MALT,maltose%20permease
# 6  MAL32,MAL3S,MALS,alpha-glucosidase%20MAL32
#
#                                                 Note  \
# 0  Maltose permease%3B high-affinity maltose tran...
# 6  Maltase %28alpha-D-glucosidase%29%3B inducible...
#
#                                        Ontology_term coverage           curie  \
# 0        GO:0000017,GO:0005352,GO:0071944,SO:0000704    0.986  SGD:S000000502
# 6  GO:0000025,GO:0004575,GO:0005886,GO:0005987,GO...    0.986  SGD:S000000503
#
#                              display extra_copy_number   gene low_identity  \
# 0                   Maltose permease                 1  MAL31         None
# 6  Maltase %28alpha-D-glucosidase%29                 1  MAL32         None
#
#   orf_classification partial_mapping sequence_ID valid_ORFs
# 0           Verified            None       0.946          0
# 6           Verified            None       0.981          0

# %%
unval_dic = {}
for ind, row in verified_unvalid.iterrows():
    if row['Chromosome'] in unval_dic:
        unval_dic[row['Chromosome']] = unval_dic[row['Chromosome']] + [row['Name']]
    else:
        unval_dic[row['Chromosome']] = [row['Name']]

# %%
verified_sum = verified_valid_count.join(verified_unvalid_count)

# %%
tmp = []
for ind in verified_sum.index:
    tmp.append(unval_dic[ind])

# %%
verified_sum['unvalid genes'] = tmp

# %%
verifiedS288C = pd.read_excel('verified_orf_s288c.xlsx')
verifiedS288C.set_index("Gene.secondaryIdentifier", inplace = True)

# %%
# This code just convert the chromosome numbering to integer and remove mitochondrial genes.
Latin_to_arabic = {'I': 1, 'II':2, 'III':3, 'IV':4, 'V':5, 'VI':6, 'VII':7, 'VIII':8, 'IX':9, 'X':10,
                  'XI':11, 'XII':12, 'XIII':13, 'XIV':14, 'XV':15, 'XVI':16, 'mt': 'mitoch'}
chLat = verifiedS288C['Gene.chromosome.primaryIdentifier']
ch = []
for chrom in chLat:
    chrom = chrom.replace('chr', '')
    ch.append(Latin_to_arabic[chrom])
verifiedS288C['S288C Chromosome'] = ch

# %%
tmp = []
count = []
for Ch in verified_sum.index:
    s288 = verifiedS288C[verifiedS288C['S288C Chromosome'] == Ch]
    yps = verified[verified['Chromosome'] == Ch]
    tmp.append(list(set(s288.index) - set(yps['Name'])))
    count.append(len(list(set(s288.index) - set(yps['Name']))))

# %%
verified_sum['Number of missing genes'] = count
verified_sum['Missing verified genes'] = tmp

# %%
verified_sum
# Out:
#         Number valid genes  Number unvalid genes  \
# 4                      673                     9
# 15                     467                    14
# 7                      457                     5
# 12                     432                    13
# 16                     405                     8
# 13                     394                     8
# 2                      360                     7
# 14                     326                    18
# 10                     316                    12
# 11                     291                    12
# 5                      249                     5
# 8                      232                     5
# 9                      178                    10
# 3                      130                     6
# 6                       97                     5
# 1                       76                     6
# mitoch                   4                    19
#
#                                             unvalid genes  \
# 4       [YDL247W, YNL331C, YDL227C, YDL080C, YDL039C, ...
# 15      [YOR388C, YOR249C, YOR244W, YOR245C, YCR106W, ...
# 7           [YGL243W, YGL131C, YAR027W, YGR140W, YBR298C]
# 12      [YGL263W, YLL063C, YLL057C, YLL052C, YLR119W, ...
# 16      [YOR394W, YPL282C, YMR323W, YPL274W, YPL255W, ...
# 13      [YDL248W, YJR161C, YML118W, YMR019W, YMR104C, ...
# 2       [YBR298C, YBR299W, YGR295C, YBR031W, YBR073W, ...
# 14      [YNL322C, YNL318C, YNL317W, YNL316C, YNL315C, ...
# 10      [YJL222W, YJL219W, YJL222W, YJL217W, YJL077C, ...
# 11      [YKR102W, YKR103W, YKR104W, YKR105C, YKL161C, ...
# 5           [YLR466W, YBL111C, YEL069C, YER106W, YER170W]
# 8           [YHL043W, YHR032W, YHR175W, YHR185C, YAR071W]
# 9       [YIL173W, YJL222W, YIL172C, YIL169C, YIL164C, ...
# 3       [YCL073C, YKR105C, YCL067C, YCR039C, YCR073C, ...
# 6           [YFR055W, YCR107W, YFR012W, YFR026C, YFR055W]
# 1       [YAL063C, YAL059W, YAL032C, YAR020C, YAR031W, ...
# mitoch  [Q0105, Q0110, Q0115, Q0120, Q0140, Q0250, Q02...
#
#         Number of missing genes  \
# 4                             5
# 15                            6
# 7                            11
# 12                            9
# 16                            5
# 13                            5
# 2                             3
# 14                           15
# 10                            5
# 11                            2
# 5                             0
# 8                             4
# 9                             0
# 3                             5
# 6                             5
# 1                             2
# mitoch                        1
#
#                                    Missing verified genes
# 4           [YDR385W, YDR542W, YDL248W, YDR545W, YDL244W]
# 15      [YOR133W, YOR247W, YOR390W, YOR394W, YOR255W, ...
# 7       [YGR294W, YGR200C, YGL133W, YGL136C, YGL051W, ...
# 12      [YLR132C, YLR160C, YLR466W, YLR461W, YLR157C, ...
# 16          [YPL283C, YPR204W, YPL281C, YPL279C, YPL280W]
# 13          [YMR323W, YMR322C, YMR105C, YMR325W, YML132W]
# 2                           [YBL108C-A, YBR302C, YBL111C]
# 14      [YNL329C, YNL332W, YNL333W, YNL328C, YNR076W, ...
# 10          [YJR159W, YJR161C, YJR160C, YJR158W, YJL223C]
# 11                                     [YKL224C, YKR106W]
# 5                                                      []
# 8                    [YHR216W, YHL048W, YHR215W, YHR211W]
# 9                                                      []
# 3           [YCL069W, YCR107W, YCR104W, YCR106W, YCR105W]
# 6           [YFL060C, YFL058W, YFL062W, YFL059W, YFL061W]
# 1                                      [YAL068C, YAR027W]
# mitoch                                            [Q0160]

# %%
verified_sum.sum
# Out:
# Number valid genes                                                      5087
# Number unvalid genes                                                     162
# unvalid genes              [YDL247W, YNL331C, YDL227C, YDL080C, YDL039C, ...
# Number of missing genes                                                   83
# Missing verified genes     [YDR385W, YDR542W, YDL248W, YDR545W, YDL244W, ...
# dtype: object

# %%
verified_sum.to_excel('verified_genes_summary.xlsx')

# %% [markdown]
# # Blast

# %%
# Import Biopython tools for running local BLASTX
from Bio.Blast.Applications import NcbiblastnCommandline

# %% [markdown]
# # Chromosome IV
# [YDR385W, YDR542W, YDL248W, YDR545W, YDL244W]

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/S288C_YDR038C_ENA5_genomic.fsa', out='Blast_results/YDR038C.tab', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/S288C_YDR039C_ENA2_genomic.fsa', out='Blast_results/YDR039C.tab', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)
# Out:
# STDOUT:
# STDERR:

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/S288C_YDR545W_YRF1-1_genomic.fsa', out='Blast_results/YDR545W.tab', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)
# Out:
# STDOUT:
# STDERR:

# %%
verified[verified['Name'] == 'YDR545W']
# Out:
#          Name Chromosome       Contig  start   end  \
# 9902  YDR545W          5  tig00000015    680  6415
#
#                                                   Alias  \
# 9902  YRF1-1,Y'%20element%20ATP-dependent%20helicase...
#
#                                                    Note  \
# 9902  Helicase encoded by the Y' element of subtelom...
#
#                                     Ontology_term coverage           curie  \
# 9902  GO:0000722,GO:0003678,GO:0005634,SO:0000704    0.999  SGD:S000002953
#
#                                                 display extra_copy_number  \
# 9902  Helicase encoded by the Y' element of subtelom...                 0
#
#         gene low_identity orf_classification partial_mapping sequence_ID  \
# 9902  YRF1-1         None           Verified            None       0.924
#
#      valid_ORFs
# 9902          1

# %% [markdown]
# Chromosome 4: 2 near centromere, 1 at the very end of teleomere
# at centromere: ENA2 and ENA5 : next to each other, Na(+)-exporting P-type ATPase ENA2
# ENA5 align with 90% identity to contig tig00000001 IV
# ENA2 align to exactly the same region of contig IV, with 90% identity, duplication in s288C?
#
# YRF1 align to contig >tig00000015 on chromosome V with 97% identity, at the very end/beginning (complement?)
# Liftoff did not detect YRF1 on chromosome V.
#
# Is it a valid ORF, is there easy tool to check that?

# %% [markdown]
# # Chromosome I

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/S288C_YAL063C_FLO9_genomic.fsa', out='Blast_results/YAL063C.tab', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/S288C_YAR027W_UIP3_genomic.fsa', out='Blast_results/YAR027W.tab', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)
# Out:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:

# %% [markdown]
# FLO9:
# 2 matches: score    e-val
# tig00000033 I 2691    0.0  12 gap   86% identity
# tig00000017 VIII  1718    0.0  57 gap
#
# UIP3:
# 2 matches
# tig00000033 I  233     3e-61  87% identity 6 gap alignment without stop codon at the end.
# tig00004928 VII  171     3e-42  82% 6 gap, alignment finish with stop codon

# %% [markdown]
# # Chromosome II

# %%
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/S288C_YBL108C-A_PAU9_genomic.fsa', out='Blast_results/YBL108C.tab', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/S288C_YBL111C_YBL111C_genomic.fsa', out='Blast_results/YBL111C.tab', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)
cmd_blastn = NcbiblastnCommandline(query= 'fasta_file/S288C_YBR298C_MAL31_genomic.fsa', out='Blast_results/YBR298C.tab', evalue=0.001, db= 'YPS1009_DB/YPS1009_DB')
stdout, stderr = cmd_blastn()
# Check STDOUT, STDERR
print("STDOUT: %s" % stdout)
print("STDERR: %s" % stderr)
# Out:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:
# STDOUT:
# STDERR:

# %%
verified[verified['Name'] == 'YBL111C']
# Out:
#           Name Chromosome       Contig  start   end Alias  \
# 10046  YBL111C          5  tig00000015   3147  6415  None
#
#                                                     Note  \
# 10046  Helicase-like protein encoded within the telom...
#
#                                      Ontology_term coverage           curie  \
# 10046  GO:0003674,GO:0005739,GO:0008150,SO:0000704    0.977  SGD:S000002151
#
#                                                  display extra_copy_number  \
# 10046  Helicase-like protein encoded within the telom...                 0
#
#        gene low_identity orf_classification partial_mapping sequence_ID  \
# 10046  None         None           Verified            None       0.957
#
#       valid_ORFs
# 10046          0

# %% [raw]
# The 3 genes missing are all in subtelomeric regions (Mal31 in the long arm telomere, the 2 others in the short arm teleomere)
# MAL31, 2 alignment
# tig00004928 VII  2968    0.0 96% identity, 6 GAP, finish by stop codon, LIFTOFF IDENTIFIED IT ON CHR 7
# tig00004927 II  2839    0.0  95% identity, 26 GAP, spread through sequence, finish by stop codon.
#
# PAU9: small gene (129 bp) with a lots of 100% identity hits, Liftoff only annotated it twice on chromosome 6 (2 different contigs),
# even though also perfect match on chromosomes 7, 8, 9, 10,1 why only on 6? syntheny?
# Sequences producing significant alignments:                          (Bits)  Value
#
# tig00004938 VI                                                        239     1e-63
# tig00004937 VI                                                        239     1e-63
# tig00004934 XII                                                       239     1e-63
# tig00004933 XII                                                       239     1e-63
# tig00001099 X                                                         239     1e-63
# tig00000033 I                                                         239     1e-63
# tig00000023 IX                                                        239     1e-63
# tig00000020 XII                                                       239     1e-63
# tig00000017 VIII                                                      239     1e-63
# tig00000001 IV                                                        239     1e-63
# tig00000038 VII                                                       233     5e-62
# tig00000015 V                                                         233     5e-62
# tig00004936 III                                                       228     3e-60
# tig00001098 X                                                         228     3e-60
# tig00004932 XI                                                        222     1e-58
# tig00000010 II                                                        222     1e-58
# tig00004928 VII                                                       206     1e-53
# tig00004927 II                                                        206     1e-53
#
# YBL111C: not detected by liftoff on chr5
# tig00000015 V  1991    0.0 98% identity 1GAP, finish by stop codon

# %% [markdown]
# # Duplicated genes???

# %%
# Many duplicated genes in this version
gene_attr['extra_copy_number'].value_counts()
# Out:
# 0    6563
# 1      94
# 2      22
# 3      12
# 4       7
# 5       5
# 6       2
# Name: extra_copy_number, dtype: int64

# %%
gene_attr[gene_attr['extra_copy_number'] > '1']
# Out:
#                       seq_id   source  type   start     end score strand  \
# 9        chrII-2_tig00004927  Liftoff  gene   14242   14700     .      -
# 21       chrII-2_tig00004927  Liftoff  gene   17994   18290     .      -
# 24      chrIII-2_tig00004935  Liftoff  gene     767    1021     .      +
# 27      chrIII-2_tig00004935  Liftoff  gene    1323    2063     .      +
# 30      chrIII-2_tig00004935  Liftoff  gene    6426    8271     .      -
# 33        chrIII_tig00004936  Liftoff  gene     760    1014     .      +
# 36        chrIII_tig00004936  Liftoff  gene    1316    2055     .      +
# 651       chrIII_tig00004936  Liftoff  gene  310848  311102     .      -
# 2097       chrII_tig00000010  Liftoff  gene  789332  789467     .      +
# 2106       chrIV_tig00000001  Liftoff  gene    1219    1356     .      -
# 4835       chrIX_tig00000023  Liftoff  gene    2653    2790     .      +
# 4838       chrIX_tig00000023  Liftoff  gene    2759    2986     .      +
# 4841       chrIX_tig00000023  Liftoff  gene    3329    3525     .      -
# 5644        chrI_tig00000033  Liftoff  gene     676     975     .      +
# 6054        chrI_tig00000033  Liftoff  gene  238815  239136     .      -
# 6057     chrMANY_tig00000038  Liftoff  gene     737    1036     .      +
# 6063     chrMANY_tig00000038  Liftoff  gene    2728    2958     .      +
# 6917     chrVI-2_tig00004937  Liftoff  gene   12581   12879     .      -
# 6920     chrVIII_tig00000017  Liftoff  gene     680     934     .      +
# 7906     chrVIII_tig00000017  Liftoff  gene  522253  522633     .      -
# 9422      chrVII_tig00004928  Liftoff  gene  805604  806749     .      -
# 9425      chrVII_tig00004928  Liftoff  gene  807356  807492     .      +
# 9428      chrVII_tig00004928  Liftoff  gene  807660  807956     .      -
# 9888       chrVI_tig00004938  Liftoff  gene  298356  298655     .      -
# 11170     chrX-2_tig00001099  Liftoff  gene     642     835     .      +
# 11173     chrX-2_tig00001099  Liftoff  gene    2619    2756     .      +
# 11182     chrX-2_tig00001099  Liftoff  gene    4754    5859     .      +
# 11185     chrX-2_tig00001099  Liftoff  gene    7160   11768     .      +
# 11188     chrX-2_tig00001099  Liftoff  gene   12417   14186     .      -
# 11221    chrXI-2_tig00004931  Liftoff  gene   28713   28967     .      -
# 11224   chrXII-2_tig00004934  Liftoff  gene     699     999     .      +
# 12027   chrXII-3_tig00004933  Liftoff  gene    6551    6679     .      -
# 12030   chrXII-3_tig00004933  Liftoff  gene    7121    7351     .      +
# 12060  chrXIII-2_tig00000029  Liftoff  gene    1228    1363     .      -
# 13703    chrXIII_tig00000018  Liftoff  gene  467347  467484     .      +
# 13709    chrXIII_tig00000018  Liftoff  gene  467923  468106     .      -
# 14775     chrXII_tig00000020  Liftoff  gene  554706  554903     .      +
# 14790     chrXII_tig00000020  Liftoff  gene  557160  557459     .      -
# 16142     chrXIV_tig00004929  Liftoff  gene  728468  728695     .      -
# 16145     chrXIV_tig00004929  Liftoff  gene  728662  728801     .      -
# 16158      chrXI_tig00004932  Liftoff  gene     726     980     .      +
# 17809   chrXVI-2_tig00000040  Liftoff  gene     743     997     .      +
# 19446     chrXVI_tig00000013  Liftoff  gene  719024  719337     .      -
# 19500      chrXV_tig00000007  Liftoff  gene   24888   25351     .      +
# 20876       chrX_tig00001098  Liftoff  gene    2582    2719     .      +
# 20879       chrX_tig00001098  Liftoff  gene    2688    2915     .      +
# 20885       chrX_tig00001098  Liftoff  gene    4721    5826     .      +
# 20897       chrX_tig00001098  Liftoff  gene   13824   14287     .      +
#
#       phase                                         attributes  \
# 9         .  ID=YGR293C_2;Name=YGR293C;Ontology_term=GO:000...
# 21        .  ID=YER188C-A_3;Name=YER188C-A;Ontology_term=GO...
# 24        .  ID=YNR077C_3;Name=YNR077C;Ontology_term=GO:000...
# 27        .  ID=YCL076W_2;Name=YCL076W;Ontology_term=GO:000...
# 30        .  ID=YCL073C_2;Name=YCL073C;gene=GEX1;Alias=GEX1...
# 33        .  ID=YNR077C_2;Name=YNR077C;Ontology_term=GO:000...
# 36        .  ID=YCL076W_3;Name=YCL076W;Ontology_term=GO:000...
# 651       .  ID=YNL337W_4;Name=YNL337W;Ontology_term=GO:000...
# 2097      .  ID=YHL048C-A_6;Name=YHL048C-A;Ontology_term=GO...
# 2106      .  ID=YHL048C-A_4;Name=YHL048C-A;Ontology_term=GO...
# 4835      .  ID=YJL222W-B_4;Name=YJL222W-B;Ontology_term=GO...
# 4838      .  ID=YJL222W-A_2;Name=YJL222W-A;Ontology_term=GO...
# 4841      .  ID=YCR102W-A_3;Name=YCR102W-A;Ontology_term=GO...
# 5644      .  ID=YDR543C_4;Name=YDR543C;Ontology_term=GO:000...
# 6054      .  ID=YAL069W_2;Name=YAL069W;Ontology_term=GO:000...
# 6057      .  ID=YDR543C_2;Name=YDR543C;Ontology_term=GO:000...
# 6063      .  ID=YJL222W-A_5;Name=YJL222W-A;Ontology_term=GO...
# 6917      .  ID=YDR543C_3;Name=YDR543C;Ontology_term=GO:000...
# 6920      .  ID=YNR077C_5;Name=YNR077C;Ontology_term=GO:000...
# 7906      .  ID=YAL064W-B_2;Name=YAL064W-B;Ontology_term=GO...
# 9422      .  ID=YGR295C_2;Name=YGR295C;gene=COS6;Alias=COS6...
# 9425      .  ID=YHL048C-A_5;Name=YHL048C-A;Ontology_term=GO...
# 9428      .  ID=YER188C-A_4;Name=YER188C-A;Ontology_term=GO...
# 9888      .  ID=YDR543C_5;Name=YDR543C;Ontology_term=GO:000...
# 11170     .  ID=YCR108C_2;Name=YCR108C;Ontology_term=GO:000...
# 11173     .  ID=YJL222W-B_5;Name=YJL222W-B;Ontology_term=GO...
# 11182     .  ID=YCR102C_2;Name=YCR102C;Ontology_term=GO:000...
# 11185     .  ID=YJL222W_2;Name=YJL222W;gene=VTH2;Alias=VTH2...
# 11188     .  ID=YIL172C_2;Name=YIL172C;gene=IMA3;Alias=IMA3...
# 11221     .  ID=YNR077C_4;Name=YNR077C;Ontology_term=GO:000...
# 11224     .  ID=YDR543C_6;Name=YDR543C;Ontology_term=GO:000...
# 12027     .  ID=YBL108C-A_2;Name=YBL108C-A;gene=PAU9;Alias=...
# 12030     .  ID=YGL260W_2;Name=YGL260W;Ontology_term=GO:000...
# 12060     .  ID=YHL048C-A_2;Name=YHL048C-A;Ontology_term=GO...
# 13703     .  ID=YHL048C-A_3;Name=YHL048C-A;Ontology_term=GO...
# 13709     .  ID=YOR394C-A_2;Name=YOR394C-A;Ontology_term=GO...
# 14775     .  ID=YCR102W-A_2;Name=YCR102W-A;Ontology_term=GO...
# 14790     .  ID=YER188C-A_2;Name=YER188C-A;Ontology_term=GO...
# 16142     .  ID=YJL222W-A_3;Name=YJL222W-A;Ontology_term=GO...
# 16145     .  ID=YJL222W-B_3;Name=YJL222W-B;Ontology_term=GO...
# 16158     .  ID=YNL337W_2;Name=YNL337W;Ontology_term=GO:000...
# 17809     .  ID=YNL337W_3;Name=YNL337W;Ontology_term=GO:000...
# 19446     .  ID=YAL069W_3;Name=YAL069W;Ontology_term=GO:000...
# 19500     .  ID=YIL171W-A_2;Name=YIL171W-A;Ontology_term=GO...
# 20876     .  ID=YJL222W-B_2;Name=YJL222W-B;Ontology_term=GO...
# 20879     .  ID=YJL222W-A_4;Name=YJL222W-A;Ontology_term=GO...
# 20885     .  ID=YCR102C_3;Name=YCR102C;Ontology_term=GO:000...
# 20897     .  ID=YIL171W-A_3;Name=YIL171W-A;Ontology_term=GO...
#
#                                           Alias  ...           curie  \
# 9                                          None  ...  SGD:S000003525
# 21                                         None  ...  SGD:S000028764
# 24                                         None  ...  SGD:S000005360
# 27                                         None  ...  SGD:S000000581
# 30                 GEX1,glutathione%20exchanger  ...  SGD:S000000575
# 33                                         None  ...  SGD:S000005360
# 36                                         None  ...  SGD:S000000581
# 651                                        None  ...  SGD:S000005281
# 2097                                       None  ...  SGD:S000028829
# 2106                                       None  ...  SGD:S000028829
# 4835                                       None  ...  SGD:S000028664
# 4838                                       None  ...  SGD:S000028663
# 4841                                       None  ...  SGD:S000007231
# 5644                                       None  ...  SGD:S000002951
# 6054                                       None  ...  SGD:S000002143
# 16145                 3  None         None            Dubious            None
# 16158                 2  None         None            Dubious            None
# 17809                 3  None         None            Dubious            None
# 19446                 3  None         None            Dubious            None
# 19500                 2  None         None            Dubious            None
# 20876                 2  None         None            Dubious            None
# 20879                 4  None         None            Dubious            None
# 20885                 3  None         None    Uncharacterized            None
# 20897                 3  None         None            Dubious            None
#
#       sequence_ID valid_ORFs
# 9           0.989          0
# 21          0.943          1
# 24          0.918          1
# 27          0.981          0
# 30          0.990          0
# 33          0.918          1
# 36          0.979          0
# 651         0.949          1
# 2097        0.890          0
# 2106        0.920          0
# 4835        0.942          1
# 4838        0.947          1
# 4841        0.949          0
# 5644        0.946          0
# 6054        0.867          0
# 6057        0.936          0
# 6063        0.917          0
# 6917        0.943          0
# 6920        0.917          0
# 7906        0.934          1
# 9422        0.961          1
# 9425        0.927          0
# 9428         0.93          1
# 9888        0.936          0
# 11170       0.917          0
# 11173       0.949          1
# 11182       0.981          0
# 11185       0.972          0
# 11188       0.989          1
# 11221       0.918          1
# 11224       0.926          0
# 12027         1.0          1
# 12030       0.948          1
# 12060       0.948          0
# 13703       0.920          0
# 13709       0.822          0
# 14775       0.954          0
# 14790       0.956          1
# 16142       0.929          1
# 16145       0.921          0
# 16158       0.956          1
# 17809       0.941          1
# 19446       0.895          0
# 19500       0.956          0
# 20876       0.956          1
# 20879       0.939          0
# 20885       0.979          0
# 20897       0.952          0
#
# [48 rows x 26 columns]

# %%
gene_attr[gene_attr.duplicated(subset=['Name'], keep=False) == True]
# Out:
#                     seq_id   source  type   start     end score strand phase  \
# 0      chrII-2_tig00004927  Liftoff  gene    8297   10119     .      -     .
# 3      chrII-2_tig00004927  Liftoff  gene   10675   10894     .      -     .
# 6      chrII-2_tig00004927  Liftoff  gene   10985   12717     .      +     .
# 9      chrII-2_tig00004927  Liftoff  gene   14242   14700     .      -     .
# 12     chrII-2_tig00004927  Liftoff  gene   14660   15022     .      +     .
# ...                    ...      ...   ...     ...     ...   ...    ...   ...
# 20903     chrX_tig00001098  Liftoff  gene   17569   18158     .      +     .
# 20906     chrX_tig00001098  Liftoff  gene   18728   19322     .      +     .
# 22173     chrX_tig00001098  Liftoff  gene  712194  713216     .      -     .
# 22212     chrX_tig00001098  Liftoff  gene  720334  720468     .      +     .
# 22215     chrX_tig00001098  Liftoff  gene  720837  721026     .      -     .
#
#                                               attributes  \
# 0      ID=YBR298C_1;Name=YBR298C;gene=MAL31;Alias=MAL...
# 3      ID=YBR298C-A_1;Name=YBR298C-A;Ontology_term=GO...
# 6      ID=YBR299W_1;Name=YBR299W;gene=MAL32;Alias=MAL...
# 9      ID=YGR293C_2;Name=YGR293C;Ontology_term=GO:000...
# 12     ID=YGR294W_1;Name=YGR294W;gene=PAU12;Alias=PAU...
# ...                                                  ...
# 20903  ID=YJL218W_1;Name=YJL218W;Alias=acetyltransfer...
# 20906  ID=YJL217W_1;Name=YJL217W;gene=REE1;Alias=REE1...
# 22173  ID=YFL058W;Name=YFL058W;gene=THI5;Alias=THI5,4...
# 22212  ID=YHL048C-A;Name=YHL048C-A;Ontology_term=GO:0...
# 22215  ID=YCR108C_1;Name=YCR108C;Ontology_term=GO:000...
#
#                                                    Alias  ...           curie  \
# 0                    MAL31,MAL3T,MALT,maltose%20permease  ...  SGD:S000000502
# 3                                                   None  ...  SGD:S000028606
# 6             MAL32,MAL3S,MALS,alpha-glucosidase%20MAL32  ...  SGD:S000000503
# 9                                                   None  ...  SGD:S000003525
# 12                            PAU12,seripauperin%20PAU12  ...  SGD:S000003526
# ...                                                  ...  ...             ...
# 20903                                  acetyltransferase  ...  SGD:S000003754
# 20906                                               REE1  ...  SGD:S000003753
# 22173  THI5,4-amino-5-hydroxymethyl-2-methylpyrimidin...  ...  SGD:S000001836
# 22212                                               None  ...  SGD:S000028829
# 22215                                               None  ...  SGD:S000028536
#
#                dbxref                                            display  \
# 0      SGD:S000000502                                 Maltose%20permease
# 3      SGD:S000028606       Putative%20protein%20of%20unknown%20function
# 6      SGD:S000000503                Maltase%20%28alpha-D-glucosidase%29
# 9      SGD:S000003525                   Dubious%20open%20reading%20frame
# 12     SGD:S000003526                  Protein%20of%20unknown%20function
# ...               ...                                                ...
# 20903  SGD:S000003754  Mitochondrial%20protein%2C%20putative%20acetyl...
# 20906  SGD:S000003753  Cytoplasmic%20protein%20involved%20in%20the%20...
# 22173  SGD:S000001836  Protein%20involved%20in%20synthesis%20of%20the...
# 22212  SGD:S000028829       Putative%20protein%20of%20unknown%20function
# 22215  SGD:S000028536       Putative%20protein%20of%20unknown%20function
#
#       extra_copy_number   gene low_identity orf_classification  \
# 0                     1  MAL31         None           Verified
# 3                     1   None         None    Uncharacterized
# 6                     1  MAL32         None           Verified
# 9                     2   None         None            Dubious
# 12                    1  PAU12         None           Verified
# ...                 ...    ...          ...                ...
# 20903                 1   None         None    Uncharacterized
# 20906                 1   REE1         None           Verified
# 22173                 0   THI5         None           Verified
# 22212                 0   None         None    Uncharacterized
# 22215                 1   None         None    Uncharacterized
#
#       partial_mapping sequence_ID valid_ORFs
# 0                None       0.946          0
# 3                None       0.981          0
# 6                None       0.981          0
# 9                None       0.989          0
# 12               None       0.983          1
# ...               ...         ...        ...
# 20903            None       0.996          0
# 20906            None       0.993          0
# 22173            None       0.990          1
# 22212            None       0.955          1
# 22215            None       0.922          0
#
# [236 rows x 26 columns]

# %% [markdown]
# Duplicated genes:
#
# ATP8/Q0080: Subunit 8 of the F0 sector of mitochondrial F1F0 ATP synthase; encoded on the mitochondrial genome; ATP8 and ATP6 mRNAs are not translated in the absence of the F1 sector of ATPase
#
# OLI1/Q0130: F0-ATP synthase subunit c (ATPase-associated proteolipid); encoded on the mitochondrial genome; mutation confers oligomycin resistance; expression is specifically dependent on the nuclear genes AEP1 and AEP2 1 2 3 4
# Name Description
# OLIgomycin resistance 1
#
# Both on mitochondria so not that relevant to my project.
#
# PAU9/YBL108C-A: Protein of unknown function; member of the seripauperin multigene family encoded mainly in subtelomeric regions; SWAT-GFP and mCherry fusion proteins localize to the endoplasmic reticulum and vacuole respectively
#
# YHR213W-A: Putative protein of unknown function; identified by gene-trapping, microarray-based expression analysis, and genome-wide homology searching
